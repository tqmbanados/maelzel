# %%
from maelzel.core import *
from maelzel.scoring import enharmonics
from maelzel.scoring import Notation
logger.setLevel("DEBUG")

# %%
config = getConfig()

# %%
config['show.glissEndStemless'] = True
# Out:
# [maelzel.core:mobj.py:1830:resetImageCache:INFO] Resetting image cache

# %%
setScoreStruct(ScoreStruct('6/4, 60'))

chain = Chain([
    "4E:1:gliss",
    "4A:2:gliss=4C"
])
chain.show()
chain.play(gain=0.5)
# Out:
# [maelzel.core:playback.py:366:_playEngine:DEBUG] Starting engine maelzel.core (nchnls=2)
#
#
#
# --Csound version 6.19 (double samples) Jan 13 2024
# [commit: c53556fbbb69d14554a4a4bd91efa441a1701d70]
# libsndfile-1.2.0
# sr = 44100.0, kr = 689.062, ksmps = 64
# 0dBFS level = 1.0, A4 tuning = 442.0
# audio buffered in 256 sample-frame blocks
# reading 2048-byte blks of shorts from adc:Built-in Audio Pro: (RAW)
# writing 512 sample blks of 64-bit floats to dac:Built-in Audio Pro:
# SECTION 1:
# [maelzel.core:playback.py:86:registerPreset:DEBUG] *********** Session registered new instr: 'preset:sin'
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=1)
#     Synth(𝍪 preset:sin=501.0002 start=0.877 dur=3.000 p4=0.5 kpos=0.5 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=64 p18=0.515178 p19=1 p20=69 …)

# %%
chain = Chain([
    "4E:1:gliss",
    "4A:2:gliss",
    "4C:0"
])
chain.show()
chain.play(gain=0.5)
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=1)
#     Synth(𝍪 preset:sin=501.0004 start=17.687 dur=3.000 p4=0.5 kpos=0.5 kgain=17 idataidx_=4 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=64 p18=0.515178 p19=1 p20=69 …)

# %%
chain = Chain([
    Chord("4E 4C#", 1, gliss=True), 
    Chord("4A 5C", 2, gliss="4C# 4Eb")
])
chain.show()
chain.play(instr='tri', fade=0.1, gain=0.5)
chain.rec(instr='tri', nchnls=1, fade=0.1, gain=0.5)
# Out:
# OfflineRenderer(sr=44100)

# %%
chain = Chain([
    Chord("4G 4B", 4/3, gliss=True),
    Chord("4G- 4A", 5/3, gliss="4G+ 4Ab")
])
print(chain.events(gain=0.01))
chain.show()
chain.rec(instr='tri', fade=0.5, nchnls=1, extratime=0.5, gain=0.1)
# Out:
# [SynthEvent(delay=0, dur=3, instr=sin, gain=0.007071, chan=1, fade=(0.02, 0.02), position=0.5)
# bps       0s: 67       0.515178
#     1.33333s: 66.5     0.515178
#           3s: 67.5     0.515178
# , SynthEvent(delay=0, dur=3, instr=sin, gain=0.007071, chan=1, fade=(0.02, 0.02), position=0.5)
# bps       0s: 71       0.515178
#     1.33333s: 69       0.515178
#           3s: 68       0.515178
# ]
# OfflineRenderer(sr=44100)

# %%
ch = Chain([
    Note("4C", 2.5),
    Note("4D", 0.5),
    Chain(["4E:0.5:offset=1"])
    
], offset=1)
ch.show()
ch.dump()
#ch.play()
# Out:
# <code><span style="font-size: 85%"><b>Chain</b> - beat: 1, offset: 1, dur: 4.5</span></code><br><code><span style="color:#BBBBBB;font-size:85%">  location  beat   offset      dur         name      gliss dyn  playargs            info                </span></code><br><code><span style="color:#9090FF;font-size:85%">  0:1       1      (0)         2.5         4C        F          None                -</span></code><br><code><span style="color:#9090FF;font-size:85%">  0:3.5     3.5    (5/2)       0.5         4D        F          None                -</span></code><br><code><span style="font-size: 85%">  <b>Chain</b> - beat: 4, offset: None, dur: 1.5</span></code><br><code><span style="color:#BBBBBB;font-size:85%">    location  beat   offset      dur         name      gliss dyn  playargs            info                </span></code><br><code><span style="color:#9090FF;font-size:85%">    0:5       5      1           0.5         4E        F          None                -</span></code>

# %%
ch = Chain([
    Note("4C", 2.5),
    Note("4D", 0.5),
    Note("4E", F(2,3), offset=4), 
    Chain([Chord("4D# 4E-", 1.5)], offset=5)
], offset=1)

ch.show()
ch.dump()
# Out:
# <code><span style="font-size: 85%"><b>Chain</b> - beat: 1, offset: 1, dur: 6.5</span></code><br><code><span style="color:#BBBBBB;font-size:85%">  location  beat   offset      dur         name    gliss dyn  playargs            info                </span></code><br><code><span style="color:#9090FF;font-size:85%">  0:1       1      (0)         2.5         4C      F          None                -</span></code><br><code><span style="color:#9090FF;font-size:85%">  0:3.5     3.5    (5/2)       0.5         4D      F          None                -</span></code><br><code><span style="color:#9090FF;font-size:85%">  0:5       5      4           0.667       4E      F          None                -</span></code><br><code><span style="font-size: 85%">  <b>Chain</b> - beat: 6, offset: 5, dur: 1.5</span></code><br><code><span style="color:#BBBBBB;font-size:85%">    location  beat   offset      dur         name    gliss dyn  playargs            info                </span></code><br><code><span style="color:#9090FF;font-size:85%">    1:0       6      (0)         1.5         4D#,4E- F          None                -</span></code>

# %%
ch.flat()
# Out:
# Chain([4C:2.5♩:offset=0, 4D:0.5♩:offset=2.5, 4E:0.667♩:offset=4, ‹4D# 4E- 1.5♩ offset=5›], offset=1)

# %%
ch = Chain([
    Note("4C", 2.5, gliss=True),
    Note("4D", 0.5),
    Chord("4E 4F-", 1)
], offset=1)
ch.show()
#ch.play()

# %%
ch = Chain([
    Note("4C", dur=1, label="test"),
    Chord("4A 4B", dur=1, label="chord!")
])
ch
# Out:
# Chain([4C:1♩, ‹4A 4B 1♩›])

# %%
v = Voice([Rest(0.5), Note("C4", 0.5), "4D-/4."])
v
# Out:
# Voice([Rest:0.5♩, 4C:0.5♩, 4D-:1.5♩], offset=0)

# %%
sco = ScoreStruct(r'''
6/4, 60
5/4
3/8
5,,100
7,,72
3/16
5/16
''')
click = sco.makeClickTrack(minMeasures=3)
click.show()
click.play()
# Out:
# [maelzel.core:playback.py:86:registerPreset:DEBUG] *********** Session registered new instr: 'preset:.click'
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=32)
#     Synth(𝍪 preset:.click=503.0002 start=80.377 dur=1.000 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0 …)
#     Synth(𝍪 preset:.click=503.0003 start=81.377 dur=1.000 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0 …)
#     Synth(𝍪 preset:.click=503.0004 start=82.377 dur=1.000 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0 …)
#     Synth(𝍪 preset:.click=503.0005 start=83.377 dur=1.000 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0 …)
#     Synth(𝍪 preset:.click=503.0006 start=84.377 dur=1.000 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0 …)
#     Synth(𝍪 preset:.click=503.0007 start=85.377 dur=1.000 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0 …)
#     Synth(𝍪 preset:.click=503.0008 start=86.377 dur=1.000 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0 …)
#     Synth(𝍪 preset:.click=503.0009 start=87.377 dur=1.000 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0 …)
#     Synth(𝍪 preset:.click=503.001 start=88.377 dur=1.000 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0 …)
#     Synth(𝍪 preset:.click=503.0011 start=89.377 dur=1.000 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0 …)
#     Synth(𝍪 preset:.click=503.0012 start=90.377 dur=1.000 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0 …)
#     Synth(𝍪 preset:.click=503.0013 start=91.377 dur=0.500 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0 …)
#     Synth(𝍪 preset:.click=503.0014 start=91.877 dur=0.500 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0 …)
#     Synth(𝍪 preset:.click=503.0015 start=92.377 dur=0.500 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0 …)
#     Synth(𝍪 preset:.click=503.0016 start=92.877 dur=0.500 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0 …)
#     Synth(𝍪 preset:.click=503.0017 start=93.377 dur=0.500 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0 …)
#     Synth(𝍪 preset:.click=503.0018 start=93.877 dur=0.500 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0 …)
#     Synth(𝍪 preset:.click=503.0019 start=94.377 dur=0.500 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0 …)
#     Synth(𝍪 preset:.click=503.002 start=94.877 dur=0.500 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0 …)
#     Synth(𝍪 preset:.click=503.0021 start=95.377 dur=0.500 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0 …)
#     Synth(𝍪 preset:.click=503.0022 start=95.877 dur=0.300 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0 …)
#     Synth(𝍪 preset:.click=503.0023 start=96.177 dur=0.300 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0 …)
#     Synth(𝍪 preset:.click=503.0024 start=96.477 dur=0.300 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0 …)
#     Synth(𝍪 preset:.click=503.0025 start=96.777 dur=0.300 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0 …)
#     Synth(𝍪 preset:.click=503.0026 start=97.077 dur=0.300 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0 …)
#     Synth(𝍪 preset:.click=503.0027 start=97.377 dur=0.300 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0 …)
#     Synth(𝍪 preset:.click=503.0028 start=97.677 dur=0.417 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0 …)
#     Synth(𝍪 preset:.click=503.0029 start=98.093 dur=0.417 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0 …)
#     Synth(𝍪 preset:.click=503.003 start=98.510 dur=0.417 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0 …)
#     Synth(𝍪 preset:.click=503.0031 start=98.927 dur=0.625 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0 …)
#     Synth(𝍪 preset:.click=503.0032 start=99.552 dur=0.417 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0 …)
#     Synth(𝍪 preset:.click=503.0033 start=99.968 dur=0.625 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0 …)

# %%
with play() as _:
    click.play(position=1)
    ch.cycle(totaldur=9.5, crop=True).play(instr='saw', gain=0.2)
_
# Out:
# [maelzel.core:event.py:1023:_canBeLinkedTo:DEBUG] Chord ‹4A 4B 1♩ offset=1 f› is tied, but 4C:1♩:offset=2 has no pitches in common
# [maelzel.core:event.py:1023:_canBeLinkedTo:DEBUG] Chord ‹4A 4B 1♩ offset=3 f› is tied, but 4C:1♩:offset=4 has no pitches in common
# [maelzel.core:event.py:1023:_canBeLinkedTo:DEBUG] Chord ‹4A 4B 1♩ offset=5 f› is tied, but 4C:1♩:offset=6 has no pitches in common
# [maelzel.core:event.py:1023:_canBeLinkedTo:DEBUG] Chord ‹4A 4B 1♩ offset=7 f› is tied, but 4C:1♩:offset=8 has no pitches in common
# [maelzel.core:playback.py:86:registerPreset:DEBUG] *********** Session registered new instr: 'preset:saw'
# Button(description='Stop', style=ButtonStyle())
# Output()
# <small><span style=""><b>SynthGroup</b></span>(synths=<code style="">47</code>)</small>
# <p><small>Instr: <strong style="color:MediumSeaGreen">preset:.click</strong> - <b>32</b> synths</small></p>
# <table style="font-size: smaller"<thead><tr><th style="text-align:left">p1</th><th style="text-align:left">start</th><th style="text-align:left">dur</th><th style="text-align:left">p4</th><th style="text-align:left">kpos</th><th style="text-align:left">kgain</th><th style="text-align:left">idataidx_</th><th style="text-align:left">inumbps</th><th style="text-align:left">ibplen</th><th style="text-align:left">ichan</th><th style="text-align:left">ifadein</th><th style="text-align:left">...</th></tr></thead><tbody><tr><td style="text-align:left">503.0034 <b>𝍪</b></td><td style="text-align:left">0.034</td><td style="text-align:left">1.000</td><td style="text-align:left">0</td><td style="text-align:left">1</td><td style="text-align:left">1</td><td style="text-align:left">17</td><td style="text-align:left">2</td><td style="text-align:left">3</td><td style="text-align:left">1</td><td style="text-align:left">...</td></tr><tr><td style="text-align:left">503.0035 <b>𝍪</b></td><td style="text-align:left">1.034</td><td style="text-align:left">1.000</td><td style="text-align:left">0</td><td style="text-align:left">1</td><td style="text-align:left">1</td><td style="text-align:left">17</td><td style="text-align:left">2</td><td style="text-align:left">3</td><td style="text-align:left">1</td><td style="text-align:left">...</td></tr><tr><td style="text-align:left">503.0036 <b>𝍪</b></td><td style="text-align:left">2.034</td><td style="text-align:left">1.000</td><td style="text-align:left">0</td><td style="text-align:left">1</td><td style="text-align:left">1</td><td style="text-align:left">17</td><td style="text-align:left">2</td><td style="text-align:left">3</td><td style="text-align:left">1</td><td style="text-align:left">...</td></tr><tr><td style="text-align:left">503.0037 <b>𝍪</b></td><td style="text-align:left">3.034</td><td style="text-align:left">1.000</td><td style="text-align:left">0</td><td style="text-align:left">1</td><td style="text-align:left">1</td><td style="text-align:left">17</td><td style="text-align:left">2</td><td style="text-align:left">3</td><td style="text-align:left">1</td><td style="text-align:left">...</td></tr><tr><td style="text-align:left">...</td></tr></tbody></table>
# <p><small>Instr: <strong style="color:MediumSeaGreen">preset:saw</strong> - <b>15</b> synths</small></p>
# <table style="font-size: smaller"<thead><tr><th style="text-align:left">p1</th><th style="text-align:left">start</th><th style="text-align:left">dur</th><th style="text-align:left">p4</th><th style="text-align:left">kpos</th><th style="text-align:left">kgain</th><th style="text-align:left">idataidx_</th><th style="text-align:left">inumbps</th><th style="text-align:left">ibplen</th><th style="text-align:left">ichan</th><th style="text-align:left">ifadein</th><th style="text-align:left">ifadeout</th><th style="text-align:left">ipchintrp_</th><th style="text-align:left">ifadekind</th><th style="text-align:left">ktransp</th><th style="text-align:left">klag</th><th style="text-align:left">kcutoffratio</th><th style="text-align:left">kfilterq</th><th style="text-align:left">19</th><th style="text-align:left">20</th><th style="text-align:left">21</th><th style="text-align:left">22</th><th style="text-align:left">23</th><th style="text-align:left">...</th></tr></thead><tbody><tr><td style="text-align:left">504.0002 <b>𝍪</b></td><td style="text-align:left">0.034</td><td style="text-align:left">1.000</td><td style="text-align:left">0</td><td style="text-align:left">0.5</td><td style="text-align:left">0.2</td><td style="text-align:left">19</td><td style="text-align:left">2</td><td style="text-align:left">3</td><td style="text-align:left">1</td><td style="text-align:left">0.02</td><td style="text-align:left">0.02</td><td style="text-align:left">0</td><td style="text-align:left">1</td><td style="text-align:left">0</td><td style="text-align:left">0.1</td><td style="text-align:left">0</td><td style="text-align:left">3</td><td style="text-align:left">0</td><td style="text-align:left">60</td><td style="text-align:left">0.51518</td><td style="text-align:left">1</td><td style="text-align:left">...</td></tr><tr><td style="text-align:left">504.0003 <b>𝍪</b></td><td style="text-align:left">1.034</td><td style="text-align:left">1.000</td><td style="text-align:left">0</td><td style="text-align:left">0.5</td><td style="text-align:left">0.14142</td><td style="text-align:left">19</td><td style="text-align:left">2</td><td style="text-align:left">3</td><td style="text-align:left">1</td><td style="text-align:left">0.02</td><td style="text-align:left">0.02</td><td style="text-align:left">0</td><td style="text-align:left">1</td><td style="text-align:left">0</td><td style="text-align:left">0.1</td><td style="text-align:left">0</td><td style="text-align:left">3</td><td style="text-align:left">0</td><td style="text-align:left">69</td><td style="text-align:left">0.51518</td><td style="text-align:left">1</td><td style="text-align:left">...</td></tr><tr><td style="text-align:left">504.0004 <b>𝍪</b></td><td style="text-align:left">1.034</td><td style="text-align:left">1.000</td><td style="text-align:left">0</td><td style="text-align:left">0.5</td><td style="text-align:left">0.14142</td><td style="text-align:left">19</td><td style="text-align:left">2</td><td style="text-align:left">3</td><td style="text-align:left">1</td><td style="text-align:left">0.02</td><td style="text-align:left">0.02</td><td style="text-align:left">0</td><td style="text-align:left">1</td><td style="text-align:left">0</td><td style="text-align:left">0.1</td><td style="text-align:left">0</td><td style="text-align:left">3</td><td style="text-align:left">0</td><td style="text-align:left">71</td><td style="text-align:left">0.51518</td><td style="text-align:left">1</td><td style="text-align:left">...</td></tr><tr><td style="text-align:left">504.0005 <b>𝍪</b></td><td style="text-align:left">2.034</td><td style="text-align:left">1.000</td><td style="text-align:left">0</td><td style="text-align:left">0.5</td><td style="text-align:left">0.2</td><td style="text-align:left">19</td><td style="text-align:left">2</td><td style="text-align:left">3</td><td style="text-align:left">1</td><td style="text-align:left">0.02</td><td style="text-align:left">0.02</td><td style="text-align:left">0</td><td style="text-al ...

# %%
from maelzel.core import *
ch = Chain([Note("4A", 2, gliss=True), Note("4G", 1, gliss=True)])
print(ch.events())
ch.play()
# Out:
# [SynthEvent(delay=0, dur=3, instr=sin, gain=1, chan=1, fade=(0.02, 0.02), position=0.5)
# bps       0s: 69       0.515178
#           2s: 67       0.515178
#           3s: 67       0.515178
# ]
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=1)
#     Synth(𝍪 preset:sin=501.0005 start=120.017 dur=3.000 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=69 p18=0.515178 p19=2 p20=67 …)

# %%
ch2 = Chain([Chord("4F 4A", 2, gliss=True), Chord("4F 4Ab", 3, gliss="4F# 4G-")])
ch2.show()
ch2.play(instr='tri', fade=0.15, sustain=0.15)
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=2)
#     Synth(𝍪 preset:tri=502.0006 start=130.855 dur=5.150 p4=0.5 kpos=0.707107 kgain=19 idataidx_=4 inumbps=3 ibplen=1 ichan=0.15 ifadein=0.15 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 kcutoffratio=3 kfilterq=0 p19=65 p20=0.515178 p21=2 p22=65 …)
#     Synth(𝍪 preset:tri=502.0007 start=130.855 dur=5.150 p4=0.5 kpos=0.707107 kgain=19 idataidx_=4 inumbps=3 ibplen=1 ichan=0.15 ifadein=0.15 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 kcutoffratio=3 kfilterq=0 p19=69 p20=0.515178 p21=2 p22=68 …)

# %%
from maelzel.core import *
session = playback.playSession()
session.defInstr('reverb', r'''
|kfeedback=0.85|
a1, a2 monitor
aL, aR  reverbsc a1, a2, kfeedback, 12000, sr, 0.5, 1
outch 1, aL - a1, 2, aR - a2 
''')
chain = Chain([Note(m, 0.25) for m in range(36, 108)])
with play() as p:
    chain.play(position=1, instr='.piano', sustain=-0.1)
    chain.transpose(3).play(position=0, instr='.piano', sustain=-0.1)
    chain.transpose(7).play(position=1, instr='.piano', sustain=-0.1)
    chain.transpose(12).play(position=0, instr='.piano', sustain=-0.1)
    session.sched('reverb', 0, dur=200, priority=2, args={'kfeedback':0.7})
p
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# <small><span style=""><b>SynthGroup</b></span>(synths=<code style="">289</code>)</small>
# <p><small>Instr: <strong style="color:MediumSeaGreen">preset:.piano</strong> - <b>288</b> synths</small></p>
# <table style="font-size: smaller"<thead><tr><th style="text-align:left">p1</th><th style="text-align:left">start</th><th style="text-align:left">dur</th><th style="text-align:left">p4</th><th style="text-align:left">kpos</th><th style="text-align:left">kgain</th><th style="text-align:left">idataidx_</th><th style="text-align:left">inumbps</th><th style="text-align:left">ibplen</th><th style="text-align:left">ichan</th><th style="text-align:left">ifadein</th><th style="text-align:left">ifadeout</th><th style="text-align:left">ipchintrp_</th><th style="text-align:left">ifadekind</th><th style="text-align:left">ktransp</th><th style="text-align:left">ipitchlag</th><th style="text-align:left">17</th><th style="text-align:left">18</th><th style="text-align:left">19</th><th style="text-align:left">20</th><th style="text-align:left">...</th></tr></thead><tbody><tr><td style="text-align:left">505.1378 <b>𝍪</b></td><td style="text-align:left">0.021</td><td style="text-align:left">0.250</td><td style="text-align:left">0</td><td style="text-align:left">1</td><td style="text-align:left">1</td><td style="text-align:left">17</td><td style="text-align:left">2</td><td style="text-align:left">3</td><td style="text-align:left">1</td><td style="text-align:left">0.02</td><td style="text-align:left">0.02</td><td style="text-align:left">0</td><td style="text-align:left">1</td><td style="text-align:left">0</td><td style="text-align:left">0.1</td><td style="text-align:left">0</td><td style="text-align:left">36</td><td style="text-align:left">0.51518</td><td style="text-align:left">...</td></tr><tr><td style="text-align:left">505.1379 <b>𝍪</b></td><td style="text-align:left">0.271</td><td style="text-align:left">0.250</td><td style="text-align:left">0</td><td style="text-align:left">1</td><td style="text-align:left">1</td><td style="text-align:left">17</td><td style="text-align:left">2</td><td style="text-align:left">3</td><td style="text-align:left">1</td><td style="text-align:left">0.02</td><td style="text-align:left">0.02</td><td style="text-align:left">0</td><td style="text-align:left">1</td><td style="text-align:left">0</td><td style="text-align:left">0.1</td><td style="text-align:left">0</td><td style="text-align:left">37</td><td style="text-align:left">0.51518</td><td style="text-align:left">...</td></tr><tr><td style="text-align:left">505.138 <b>𝍪</b></td><td style="text-align:left">0.521</td><td style="text-align:left">0.250</td><td style="text-align:left">0</td><td style="text-align:left">1</td><td style="text-align:left">1</td><td style="text-align:left">17</td><td style="text-align:left">2</td><td style="text-align:left">3</td><td style="text-align:left">1</td><td style="text-align:left">0.02</td><td style="text-align:left">0.02</td><td style="text-align:left">0</td><td style="text-align:left">1</td><td style="text-align:left">0</td><td style="text-align:left">0.1</td><td style="text-align:left">0</td><td style="text-align:left">38</td><td style="text-align:left">0.51518</td><td style="text-align:left">...</td></tr><tr><td style="text-align:left">505.1381 <b>𝍪</b></td><td style="text-align:left">0.771</td><td style="text-align:left">0.250</td><td style="text-align:left">0</td><td style="text-align:left">1</td><td style="text-align:left">1</td><td style="text-align:left">17</td><td style="text-align:left">2</td><td style="text-align:left">3</td><td style="text-align:left">1</td><td style="text-align:left">0.02</td><td style="text-align:left">0.02</td><td style="text-align:left">0</td><td style="text-align:left">1</td><td style="text-align:left">0</td><td style="text-align:left">0.1</td><td style="text-align:left">0</td><td style="text-align:left">39</td><td style="text-align:left">0.51518</td><td style="text-align:left">...</td></tr><tr><td style="text-align:left">...</td></tr></tbody></table>
# <p><small>Instr: <strong style="color:MediumSeaGreen">reverb</strong> - <b>1</b> synths</small></p>
# <table style="font-size: smaller"<thead><tr><th style="text-align:left">p1</th><th style="text-align:left">start</th><th style="text-align:left">dur</th><th style="text-align:left">p4</th><th style="text-align:left">kfeedback</th></tr></thead><tbody><tr><td style="text-align:left">1001.0009 <b>𝍪</b></td><td style="text-align:left">0.021</td><td style="text-align:left">200.000</td><td style="text-align:left">0</td><td style="text-align:left">0.7</td></tr></tbody></table>

# %%
session
# Out:
# Session(maelzel.core, synths=0)

# %%
from maelzel.core import *
from csoundengine.event import Event
import csoundengine as ce
session = playSession()
session.defInstr('reverb', r'''
|kfeedback=0.85|
a1, a2 monitor
aL, aR  reverbsc a1, a2, kfeedback, 12000, sr, 0.5, 1
outch 1, aL - a1, 2, aR - a2
''')
session.defInstr('sin', r'''
|imidi=60, iamp=0.01|
a1 oscili iamp, mtof(imidi)
a1 *= linsegr(0, 0.5, 1, 2, 0)
outch 1, a1
''')
play(
    Chord("4C 4E", 7, offset=1).events(position=0.5),
    Note("4C#", 6, offset=1.5),  # No customization,
    Event('sin', delay=0.1, dur=3, args={'imidi': 61.33, 'iamp':0.02}),
    Event('reverb', dur=10, args={'kfeedback': 0.8}, priority=2),
    
)
# Out:
# --Csound version 6.19 (double samples) Jan 13 2024
# [commit: c53556fbbb69d14554a4a4bd91efa441a1701d70]
# libsndfile-1.2.0
# sr = 44100.0, kr = 689.062, ksmps = 64
# 0dBFS level = 1.0, A4 tuning = 442.0
# audio buffered in 256 sample-frame blocks
# reading 2048-byte blks of shorts from adc:Built-in Audio Pro: (RAW)
# writing 512 sample blks of 64-bit floats to dac:Built-in Audio Pro:
# SECTION 1:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=5)
#     Synth(𝍪 preset:sin=501.0002 start=2.050 dur=7.000 p4=0.5 kpos=0.707107 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=60 p18=0.515178 p19=7 p20=60 …)
#     Synth(𝍪 preset:sin=501.0003 start=2.050 dur=7.000 p4=0.5 kpos=0.707107 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=64 p18=0.515178 p19=7 p20=64 …)
#     Synth(𝍪 preset:sin=501.0004 start=2.550 dur=6.000 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=61 p18=0.515178 p19=6 p20=61 …)
#     Synth(𝍪 reverb=1001.0002 start=1.050 dur=10.000 p4=0.8)
#     Synth(𝍪 sin=502.0002 start=1.150 dur=3.000 p4=61.33 imidi=0.02)

# %%
playSession()
# Out:
# Button(description='Stop Synths', style=ButtonStyle())
# Output()
# Session(maelzel.core, synths=5)

# %%
from maelzel.core import *
ch = Chain([
    Note(60, dur=0.5, gliss=True),
    Note(65, 1, gliss=True),
    Note(63, 1, gliss=67),
    Chord("4D 4F", 1)
])
ch.show()
ch.play(instr='saw', gain=0.1, position=0.5)
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=3)
#     Synth(𝍪 preset:saw=503.0008 start=97.535 dur=2.500 p4=0.5 kpos=0.1 kgain=19 idataidx_=4 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 kcutoffratio=3 kfilterq=0 p19=60 p20=0.515178 p21=0.5 p22=65 …)
#     Synth(𝍪 preset:saw=503.0009 start=100.035 dur=1.000 p4=0.5 kpos=0.0707107 kgain=19 idataidx_=2 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 kcutoffratio=3 kfilterq=0 p19=62 p20=0.515178 p21=1 p22=62 …)
#     Synth(𝍪 preset:saw=503.001 start=100.035 dur=1.000 p4=0.5 kpos=0.0707107 kgain=19 idataidx_=2 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 kcutoffratio=3 kfilterq=0 p19=65 p20=0.515178 p21=1 p22=65 …)

# %%
from maelzel.core import *
ch = Chain([
    Note(60, dur=0.5, gliss=True),
    Note(67, dur=0, gliss=True),
    Note(65, 1, gliss=True),
    Note(63, 1, gliss=67),
    Chord("4D 4F", 1)
])
ch.show()
ch.play(instr='saw', gain=0.1, position=0.5)
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=3)
#     Synth(𝍪 preset:saw=503.0014 start=132.690 dur=2.500 p4=0.5 kpos=0.1 kgain=19 idataidx_=5 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 kcutoffratio=3 kfilterq=0 p19=60 p20=0.515178 p21=0.428571 p22=67 …)
#     Synth(𝍪 preset:saw=503.0015 start=135.190 dur=1.000 p4=0.5 kpos=0.0707107 kgain=19 idataidx_=2 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 kcutoffratio=3 kfilterq=0 p19=62 p20=0.515178 p21=1 p22=62 …)
#     Synth(𝍪 preset:saw=503.0016 start=135.190 dur=1.000 p4=0.5 kpos=0.0707107 kgain=19 idataidx_=2 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 kcutoffratio=3 kfilterq=0 p19=65 p20=0.515178 p21=1 p22=65 …)

# %%
from maelzel.core import *
ch = Chain([
    Note(60, dur=0, gliss=True),
    Note(65, 1, gliss=True),
    Chord("4D 4F", 1)
])
ch.show()
# ch.events()
ch.play(instr='saw', gain=0.1, position=0.5)
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=3)
#     Synth(𝍪 preset:saw=503.0023 start=191.657 dur=2.000 p4=0.5 kpos=0.1 kgain=19 idataidx_=4 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 kcutoffratio=3 kfilterq=0 p19=60 p20=0.515178 p21=0.0714286 p22=65 …)
#     Synth(𝍪 preset:saw=503.0024 start=192.657 dur=1.000 p4=0.5 kpos=0.0707107 kgain=19 idataidx_=2 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 kcutoffratio=3 kfilterq=0 p19=62 p20=0.515178 p21=1 p22=62 …)
#     Synth(𝍪 preset:saw=503.0025 start=192.657 dur=1.000 p4=0.5 kpos=0.0707107 kgain=19 idataidx_=2 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 kcutoffratio=3 kfilterq=0 p19=62 p20=0.515178 p21=1 p22=62 …)

# %%
from maelzel.core import *
ch = Chain([
    Note(60, dur=0.5, gliss=True),
    Note(65, 1, tied=True),
    Note(65, 1, gliss=67)
])
ch.show()
ch.play(instr='saw', gain=0.1)
# ch.events()
#ch.play(instr='saw', gain=0.1, position=0.5)
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=1)
#     Synth(𝍪 preset:saw=503.0026 start=195.418 dur=2.500 p4=0.5 kpos=0.1 kgain=19 idataidx_=4 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 kcutoffratio=3 kfilterq=0 p19=60 p20=0.515178 p21=0.5 p22=65 …)

# %%
from maelzel.core import *
ch = Chain([
    Note("4D", 2, tied=True).addSpanner('<'),
    Note("4D", 0.5, dynamic='mf').addSymbol('articulation', 'accent')
])
ch.show()

# %%
from maelzel.core import *
ch = Chain([
    Note("4D", 1, tied=True),
    Chord("4D 4F", 1.5, amp=0.1, tied=True),
    Chord("4D 4F", 2).setPlay(fade=(0, 2))
])
ch.show()
print(ch.events())
ch.play()
# Out:
# [SynthEvent(delay=0, dur=4.5, instr=sin, gain=1, chan=1, fade=(0.02, 0.02), position=0.5)
# bps       0s: 62       0.515178
#           1s: 62       0.1
#         2.5s: 62       0.515178
#         4.5s: 62       0.515178
# , SynthEvent(delay=1, dur=3.5, instr=sin, gain=0.7071, chan=1, fade=(0.02, 0.02), position=0.5)
# bps       0s: 65       0.1
#         1.5s: 65       0.515178
#         3.5s: 65       0.515178
# ]
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=2)
#     Synth(𝍪 preset:sin=501.0032 start=325.781 dur=4.500 p4=0.5 kpos=1 kgain=17 idataidx_=4 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=62 p18=0.515178 p19=1 p20=62 …)
#     Synth(𝍪 preset:sin=501.0033 start=326.781 dur=3.500 p4=0.5 kpos=0.707107 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=65 p18=0.1 p19=1.5 p20=65 …)

# %%
from maelzel.core import *
ch = Chain([
    Note("4D", 1, tied=False, amp=0.1),
    Note("4D", 2, tied=True, amp=0.5).setPlay(fade=(0, 1)),
])
ch.play()
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=2)
#     Synth(𝍪 preset:sin=501.0042 start=418.754 dur=1.000 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=62 p18=0.1 p19=1 p20=62 …)
#     Synth(𝍪 preset:sin=501.0043 start=419.754 dur=2.000 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0 ifadein=1 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=62 p18=0.5 p19=2 p20=62 …)

# %%
from maelzel.core import *
ch = Chain([
    Chord("4D 4F", 1/3, tied=True),
    Chord("4D 4F", 1.5, dynamic='mf'),
    # Chord("4D 4F", 1)
])
ch.show()
ch.scoringEvents()
#print(ch.events())
#ch.play()
# Out:
# csoundengine.magic extension loaded
# Magics available: %csound, %%csound, %%definstr
# [«0.000:0.333 tiedNext [4D 4F]», «0.333:1.833 tiedPrev [4D 4F] mf»]

# %%
from maelzel.core import *

ch = Chain([
    Chord("4D 4F", 1, gliss=True),
    Chord("4F 4Ab", 1.5, dynamic='mf'),
])

ch.play()
ch.events()
# Out:
# --Csound version 6.18 (double samples) Dec 11 2022
# [commit: 470942b7d015b1fa100f577ec28d46ee7c753ef6]
# libsndfile-1.0.31
# sr = 44100.0, kr = 689.062, ksmps = 64
# 0dBFS level = 1.0, A4 tuning = 442.0
# audio buffered in 256 sample-frame blocks
# reading 1024-byte blks of shorts from adc:system:capture (RAW)
# writing 512 sample blks of 64-bit floats to dac:system:playback
# SECTION 1:
# [SynthEvent(delay=0, dur=2.5, gain=1, chan=1, fade=(0.02, 0.02), instr=_piano)
#  bps 0.000s: 62       0.515178
#      1.000s: 65       0.515178
#      2.500s: 65       0.515178,
#  SynthEvent(delay=0, dur=2.5, gain=1, chan=1, fade=(0.02, 0.02), instr=_piano)
#  bps 0.000s: 65       0.515178
#      1.000s: 68       0.515178
#      2.500s: 68       0.515178]

# %%
from maelzel.core import *

ch = Chain([
    Chord("4D 4F", 2, tied=True, dynamic='p').addSymbol('articulation', 'tenuto'),
    Chord("4D 4F", 1, gliss=True).addSpanner('<'),
    Chord("4F 4Ab", 1.5, dynamic='mf').addSymbol('articulation', 'accent'),
    # Chord("4D 4F", 1)
])
ch.show()
ch.setPlay(instr='saw', gain=0.05, args={'kfreqratio': 10})

ch.play()
ch.events(fade=0.5)
# Out:
# [SynthEvent(delay=0, dur=4.5, gain=0.05, chan=1, fade=(0.5, 0.5), instr=saw, args={'kfreqratio': 10})
#  bps 0.000s: 62       0.515178
#      2.000s: 62       0.515178
#      3.000s: 65       0.515178
#      4.500s: 65       0.515178,
#  SynthEvent(delay=0, dur=4.5, gain=0.05, chan=1, fade=(0.5, 0.5), instr=saw, args={'kfreqratio': 10})
#  bps 0.000s: 65       0.515178
#      2.000s: 65       0.515178
#      3.000s: 68       0.515178
#      4.500s: 68       0.515178]

# %%
ch = Chain(["4C:1:offset=0.5", "4D:0.5"], offset=2)
ch
# Out:
# Chain([4C:1♩:offset=0.5, 4D:0.5♩], offset=2.0)

# %%
# %timeit v = ch.asVoice()
# v
# Out:
# 28.2 µs ± 786 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
from maelzel.core import *
n = Note(60, dur=1)

# %%
n.setPlay(sustain=3)
n.events()
# Out:
# playargs PlayArgs(delay=0, chan=1, gain=1.0, fade=0.02, instr=_piano, pitchinterpol=linear, fadeshape=cos, priority=1, position=-1, sustain=0, transpose=0)
# [SynthEvent(delay=0, dur=1, gain=1, chan=1, fade=(0.02, 0.02), instr=_piano, sustain=3)
#  bps 0.000s: 60 0.515178
#      1.000s: 60 0.515178]

# %%
n.events(sustain=3)
# Out:
# playargs PlayArgs(delay=0, chan=1, gain=1.0, fade=0.02, instr=_piano, pitchinterpol=linear, fadeshape=cos, priority=1, position=-1, sustain=3, transpose=0)
# [SynthEvent(delay=0, dur=1, gain=1, chan=1, fade=(0.02, 0.02), instr=_piano, sustain=3)
#  bps 0.000s: 60 0.515178
#      1.000s: 60 0.515178]

# %%
n.play()
# Out:
# playargs PlayArgs(delay=0, chan=1, gain=1.0, fade=0.02, instr=_piano, pitchinterpol=linear, fadeshape=cos, priority=1, position=-1, sustain=0, transpose=0)
# --Csound version 6.19 (double samples) Dec 20 2022
# [commit: cd2cbc6494d1cefaaa357abf7c94e54e4d2e2868]
# libsndfile-1.0.31
# sr = 44100.0, kr = 689.062, ksmps = 64
# 0dBFS level = 1.0, A4 tuning = 442.0
# audio buffered in 256 sample-frame blocks
# reading 1024-byte blks of shorts from adc:system:capture (RAW)
# writing 512 sample blks of 64-bit floats to dac:system:playback
# SECTION 1:
# Resolve pfields:
# apply sustain
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=1)
#     Synth(𝍪 preset._piano:501.0002, p4=0 idataidx_:5=15 inumbps:6=3 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 p15=0 p16=60 ...)
