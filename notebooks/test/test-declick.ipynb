# %%
from maelzel.core import *

# %%
n = Note(60.5, 2)

# %%
ev = n.play(instr='sin', fade=(0.1, 0.05), fadeshape='cos')
ev.stop(1)
ev
# Out:
# --Csound version 6.19 (double samples) Oct 30 2023
# [commit: 79e5d31bea441e5289073319ab2b1e42d01814b9]
# libsndfile-1.2.0
# sr = 48000.0, kr = 750.000, ksmps = 64
# 0dBFS level = 1.0, A4 tuning = 442.0
# audio buffered in 512 sample-frame blocks
# reading 4096-byte blks of shorts from adc:Built-in Audio Pro: (RAW)
# writing 1024 sample blks of 64-bit floats to dac:Built-in Audio Pro:
# SECTION 1:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=1)
#     Synth(▶ preset:sin=501.0002 start=0.885 dur=2.000 p4=0 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0.1 ifadeout=0.05 ipchintrp_=0 ifadekind=1 ktransp=0 klag=0.1 p17=0 p18=60.5 p19=0.515178 p20=2 …)

# %%
n = Note(60.5, 10)
ev = n.play(instr='.piano', fade=(0., 0.05), fadeshape='cos')
ev.set(ktransp=0.5, delay=1)
ev.stop(4)
ev
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=1)
#     Synth(▶ preset:.piano=502.001 start=51.561 dur=10.000 p4=0 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 ifadeout=0.05 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 p17=0 p18=60.5 p19=0.515178 …)

# %%
getPreset('.piano')
# Out:
# Preset: .piano  (Default piano sound)
#     routing=True, properties={'sfpath': PosixPath('/home/em/dev/python/maelzel/maelzel/data/sf2/SalC5Light2.sf2')}
#   init: iSfTable_ sfloadonce "/home/em/dev/python/maelzel/maelzel/data/sf2/SalC5Light2.sf2"
#   |ktransp=0.0, ipitchlag=0.1|
#
#   ipresetidx sfPresetIndex "/home/em/dev/python/maelzel/maelzel/data/sf2/SalC5Light2.sf2", 0, 0
#   inote0_ = round(p(idataidx_ + 1))
#   ivel_ = p(idataidx_ + 2) * 127
#   kpitch2 = lag:k(kpitch+ktransp, ipitchlag)
#   aout1, aout2 sfplay ivel_, inote0_, kamp/16384, mtof:k(kpitch2), ipresetidx, 1
#
#   epilogue:
#     turnoffWhenSilent aout1

# %%
n = Note(60.5, 6)
with render() as r:
    ev = n.play(instr='.piano', fade=(0, 0.02), fadeshape='cos')
    ev.stop(1.5)
    ev.automate('position', (0, 0, 1, 1))
    ev2 = Note(61, 3, offset=1.5).play(instr='.piano')
    ev2.automate('transpose', (1, 0, 1.5, 1))
r
# Out:
# OfflineRenderer(sr=44100)

# %%
r.openLastOutfile()
# Out:
# '/home/em/.local/share/maelzel/recordings/rec-2023-11-06T15:18:13.162.wav'
# QSocketNotifier: Can only be used with threads started with QThread
# kf.service.services: KApplicationTrader: mimeType "x-scheme-handler/file" not found
# Gtk-Message: 15:20:36.081: Failed to load module "appmenu-gtk-module"
# mhWaveEdit: playing file as 48000 Hz, float, Stereo
# mhWaveEdit: playing file as 48000 Hz, float, Stereo

# %%
n.play(declick=0.2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 n.play(declick=0.2)
#
# File ~/dev/python/maelzel/maelzel/core/mobj.py:1331, in MObj.play(self, instr, delay, args, gain, chan, pitchinterpol, fade, fadeshape, position, skip, end, whenfinished, sustain, workspace, transpose, config, display, declick, **kwargs)
#    1314 elif workspace is None:
#    1315     workspace = Workspace.active
#    1317 events = self.events(delay=delay,
#    1318                      chan=chan,
#    1319                      fade=fade,
#    1320                      gain=gain,
#    1321                      instr=instr,
#    1322                      pitchinterpol=pitchinterpol,
#    1323                      fadeshape=fadeshape,
#    1324                      args=args,
#    1325                      position=position,
#    1326                      sustain=sustain,
#    1327                      workspace=workspace,
#    1328                      skip=skip,
#    1329                      end=end,
#    1330                      transpose=transpose,
# -> 1331                      declick=declick
#    1332                      **kwargs)
#    1334 if not events:
#    1335     group = csoundengine.synth.SynthGroup([playback._dummySynth()])
#
# TypeError: unsupported operand type(s) for ** or pow(): 'float' and 'dict'

# %%
getPreset('sin').getInstr()
# Out:
# Instr(preset:sin, position(kpos):5=0, gain(kgain):6=0, idataidx_:7=0, inumbps:8=0, ibplen:9=0, ichan:10=0, ifadein:11=0, ifadeout:12=0, ipchintrp_:13=0, ifadekind:14=0, ideclick:15=0, ktransp:16=0, klag:17=0.1)
