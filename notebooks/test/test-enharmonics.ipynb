# %%
from maelzel.core import *
from maelzel.scoring import enharmonics
from maelzel import scoring
cfg = getConfig()
cfg['.enharmonic.debug'] = True

# %%
enharmonics.bestChordSpelling(("4A", "4A#"))
# Out:
# ('4A', '4Bb')

# %%
ch = Chord("4a 4Bb")
ch2 = ch.scoringEvents()[0]
print(ch2)
ch2.fixedNotenames
# Out:
# «[4A 4A#] 0:1 1♩»

# %%
ch
# Out:
# Single notation, «[4A 4A#] 0:1 1♩», fixed to ('4A', '4Bb')
# ‹4A 4Bb 1♩›

# %%
ch3 = scoring.makeChord(("4a", "4Bb"), 1)
ch3.fixedNotenames

# %%
n = Note("4Eb!")
n
# Out:
# Single notation, «4Eb 0:1 1♩», fixed to ('4Eb',)
# 4Eb:1♩

# %%
ch = Chord("4f 4g#!")
ch
# Out:
# Single notation, «[4F 4G#] 0:1 1♩», fixed to ('4F', '4G#')
# ‹4F 4G# 1♩›

# %%
Chord("4a 4a+")
# Out:
# Single notation, «[4A 4A+] 0:1 1♩», fixed to ('4A', '4Bb-')
# ‹4A 4Bb- 1♩›

# %%
ch = Chain([
    "4c",
    "4c+",
    "4e",
    "4eb",
    "4d+"
])
ch
# Out:
# Spelling: 4C 4C+ 4E 4D#, penalty= 0.4201, intervalPenalty=0.1765, groupPenalty=0, chordPenalty=0
# Spelling: 4C 4C+ 4E 4Eb, penalty= 0.8402, intervalPenalty=0.7059, groupPenalty=0, chordPenalty=0
# Spelling: 4C 4Db- 4E 4D#, penalty= 3.227, intervalPenalty=4.412, groupPenalty=6, chordPenalty=0
# Spelling: 4C 4Db- 4E 4Eb, penalty= 3.515, intervalPenalty=6.353, groupPenalty=6, chordPenalty=0
# DEBUG: Enharmonic spelling - orig. ['4C', '4C+', '4E', '4D#'], horizontal solution=['4C', '4C+', '4E', '4D#']
# Single notation, «4D+ 0:1 1♩», fixed to ('4D+',)
# Chain([4C:1♩, 4C+:1♩, 4E:1♩, 4D#:1♩, 4D+:1♩])

# %%
ch = Chain([
    "4c/16",
    "4c+/16",
    "4e/16",
    "4eb!/16",
    "4d+/16"
])
ch
# Out:
# Spelling: 4C 4C+ 4E 4Eb 4D+, penalty= 0.8402, intervalPenalty=0.7059, groupPenalty=0, chordPenalty=0
# Spelling: 4C 4Db- 4E 4Eb 4D+, penalty= 2.552, intervalPenalty=6.353, groupPenalty=0.1596, chordPenalty=0
# Spelling: 4C 4C+ 4E 4Eb 4Eb-, penalty= 2.726, intervalPenalty=1.588, groupPenalty=5.84, chordPenalty=0
# Spelling: 4C 4Db- 4E 4Eb 4Eb-, penalty= 4.072, intervalPenalty=8.647, groupPenalty=7.931, chordPenalty=0
# DEBUG: Enharmonic spelling - orig. ['4C', '4C+', '4E', '4Eb', '4D+'], horizontal solution=['4C', '4C+', '4E', '4Eb', '4D+']
# Chain([4C:0.25♩, 4C+:0.25♩, 4E:0.25♩, 4Eb:0.25♩, 4D+:0.25♩])

# %%
ch = Chain([
    "4c#!/16",
    "4c+75/16",
    "4e/16",
    "4eb+25/16",
    "4d+/16"
])
ch
# Out:
# Spelling: 4C# 4C#-25 4E 4D#> 4D+, penalty= 1.732, intervalPenalty=3, groupPenalty=0, chordPenalty=0
# Spelling: 4C# 4C#-25 4E 4Eb+25 4D+, penalty= 1.792, intervalPenalty=3, groupPenalty=0.211, chordPenalty=0
# Spelling: 4C# 4C#-25 4E 4Eb+25 4Eb-, penalty= 4.359, intervalPenalty=12, groupPenalty=7.005, chordPenalty=0
# DEBUG: Enharmonic spelling - orig. ['4C#', '4Db<', '4E', '4D#>', '4D+'], horizontal solution=['4C#', '4C#-25', '4E', '4D#>', '4D+']
# Chain([4C#:0.25♩, 4Db<:0.25♩, 4E:0.25♩, 4D#>:0.25♩, 4D+:0.25♩])

# %%
from maelzel.core import *
c = getConfig()
c['.enharmonic.debug'] = True

ch = Chain([
    "3b,4eb,4g#/16",
    "4c#,4e,4f#/16",
    "4e+/16",
    "4eb16",
    "4d+/16"
])
ch
# Out:
# Spelling: 4G# 4F# 4E+ 4D# 4D+, penalty= 0.07976, intervalPenalty=0.006362, groupPenalty=0, chordPenalty=0
# Spelling: 4Ab 4Gb 4F- 4Eb 4D+, penalty= 0.2717, intervalPenalty=0, groupPenalty=0, chordPenalty=0.07383
# Spelling: 4Ab 4F# 4E+ 4D# 4D+, penalty= 0.6278, intervalPenalty=0.3821, groupPenalty=0, chordPenalty=0.01193
# Spelling: 4Ab 4Gb 4F- 4Eb 4Eb-, penalty= 0.6873, intervalPenalty=0.006362, groupPenalty=0.3922, chordPenalty=0.07383
# Spelling: 4Ab 4Gb 4F- 4D# 4D+, penalty= 0.9185, intervalPenalty=0.7699, groupPenalty=0, chordPenalty=0.07383
# Spelling: 4Ab 4Gb 4E+ 4D# 4D+, penalty= 0.9185, intervalPenalty=0.7699, groupPenalty=0, chordPenalty=0.07383
# Spelling: 4G# 4F# 4F- 4Eb 4D+, penalty= 1.396, intervalPenalty=1.949, groupPenalty=0, chordPenalty=0
# Spelling: 4G# 4F# 4E+ 4Eb 4D+, penalty= 1.396, intervalPenalty=1.949, groupPenalty=0, chordPenalty=0
# Spelling: 4G# 4Gb 4F- 4Eb 4D+, penalty= 1.544, intervalPenalty=2.358, groupPenalty=0, chordPenalty=0.0264
# Spelling: 4G# 4F# 4F- 4Eb 4Eb-, penalty= 1.603, intervalPenalty=2.178, groupPenalty=0.3922, chordPenalty=0
# Spelling: 4G# 4Gb 4F- 4Eb 4Eb-, penalty= 1.74, intervalPenalty=2.609, groupPenalty=0.3922, chordPenalty=0.0264
# Spelling: 4Ab 4F# 4F- 4Eb 4D+, penalty= 1.937, intervalPenalty=3.742, groupPenalty=0, chordPenalty=0.01193
# Spelling: 4Ab 4F# 4E+ 4Eb 4D+, penalty= 1.937, intervalPenalty=3.742, groupPenalty=0, chordPenalty=0.01193
# Spelling: 4Ab 4F# 4F- 4Eb 4Eb-, penalty= 2.112, intervalPenalty=4.056, groupPenalty=0.3922, chordPenalty=0.01193
# Spelling: 4Ab 4Gb 4E+ 4Eb 4D+, penalty= 2.21, intervalPenalty=4.812, groupPenalty=0, chordPenalty=0.07383
# Spelling: 4G# 4F# 4F- 4D# 4D+, penalty= 2.273, intervalPenalty=5.168, groupPenalty=0, chordPenalty=0
# Spelling: 4G# 4Gb 4E+ 4D# 4D+, penalty= 2.418, intervalPenalty=5.822, groupPenalty=0, chordPenalty=0.0264
# Spelling: 4G# 4Gb 4F- 4D# 4D+, penalty= 2.418, intervalPenalty=5.822, groupPenalty=0, chordPenalty=0.0264
# Spelling: 4Ab 4F# 4F- 4D# 4D+, penalty= 2.814, intervalPenalty=7.906, groupPenalty=0, chordPenalty=0.01193
# Spelling: 4G# 4Gb 4E+ 4Eb 4D+, penalty= 3.733, intervalPenalty=13.91, groupPenalty=0, chordPenalty=0.0264
# Spelling: 4G# 4F# 4E+ 4Eb 4Eb-, penalty= 4.066, intervalPenalty=2.178, groupPenalty=14.36, chordPenalty=0
# Spelling: 4Ab 4F# 4E+ 4Eb 4Eb-, penalty= 4.292, intervalPenalty=4.056, groupPenalty=14.36, chordPenalty=0.01193
# Spelling: 4Ab 4Gb 4E+ 4Eb 4Eb-, penalty= 4.427, intervalPenalty=5.168, groupPenalty=14.36, chordPenalty=0.07383
# Spelling: 4G# 4Gb 4E+ 4Eb 4Eb-, penalty= 5.375, intervalPenalty=14.51, groupPenalty=14.36, chordPenalty=0.0264
# DEBUG: Enharmonic spelling - orig. ['4G#', '4F#', '4E+', '4D#', '4D+'], horizontal solution=['4G#', '4F#', '4E+', '4D#', '4D+']
# DEBUG: Enharmonic spelling - chord «[3B 4D# 4G#] 0:0.25 1/4♩» - previous slots state:
#
#        chords fixed slots:
# DEBUG: Enharmonic spelling - chord «[3B 4D# 4G#] 0:0.25 1/4♩» - solution: ('3B', '4D#', '4G#')
#        fixed slots: G#
#        variants: [('3B', '4D#', '4G#'), ('3B', '4Eb', '4G#')]
# DEBUG: Enharmonic spelling - chord «[4C# 4E 4F#] 0.25:0.5 1/4♩» - previous slots state:
#        D#, G#
#        chords fixed slots: D#, G#
# DEBUG: Enharmonic spelling - chord «[4C# 4E 4F#] 0.25:0.5 1/4♩» - solution: ('4C#', '4E', '4F#')
#        fixed slots: D#, F#, G#
#        variants: [('4C#', '4E', '4F#'), ('4Db', '4E', '4F#')]
# Chain([‹3B 4D# 4G# 0.25♩›, ‹4C# 4E 4F# 0.25♩›, 4E+:0.25♩, 4D#:1♩, 4D+:0.25♩])

# %%
ch = Chord("3f 3b 4D# 4Ab!", dur=2, dynamic='mf', gliss='4c 4c# 4E 4Gb')
ch
# Out:
# Spelling: 4Ab 4Gb, penalty= 0.2365, intervalPenalty=0, groupPenalty=0, chordPenalty=0.05592
# Spelling: 4Ab 4F#, penalty= 1.417, intervalPenalty=2, groupPenalty=0, chordPenalty=0.009035
# DEBUG: Enharmonic spelling - orig. ['4Ab', '4F#'], horizontal solution=['4Ab', '4Gb']
# DEBUG: Enharmonic spelling - chord «[3B 4D# 4Ab]gliss 0:2 2♩ mf» - previous slots state:
#
#        chords fixed slots:
# DEBUG: Enharmonic spelling - chord «[3B 4D# 4Ab]gliss 0:2 2♩ mf» - solution: ('3B', '4Eb', '4Ab')
#        fixed slots: Ab
#        variants: [('3B', '4Eb', '4Ab'), ('3B', '4D#', '4Ab')]
# DEBUG: Enharmonic spelling - chord «[4C# 4E 4Gb] 2:grace properties={'.clefHint': {0: 'treble', 1: 'treble', 2: 'treble'}}» - previous slots state:
#        Eb, Ab
#        chords fixed slots: Eb, Ab
# DEBUG: Enharmonic spelling - chord «[4C# 4E 4Gb] 2:grace properties={'.clefHint': {0: 'treble', 1: 'treble', 2: 'treble'}}» - solution: ('4Db', '4E', '4Gb')
#        fixed slots: Eb, Gb, Ab
#        variants: [('4Db', '4E', '4Gb'), ('4C#', '4E', '4Gb')]
# Spelling: 3F 4C, penalty= 0, intervalPenalty=0, groupPenalty=0, chordPenalty=0
# DEBUG: Enharmonic spelling - orig. ['3F', '4C'], horizontal solution=['3F', '4C']
# ‹3F 3B 4Eb 4Ab 2♩ gliss=4C,4C#,4E,4F# mf›

# %%
ch = Chain([
    "3f,3b,4D#,4Ab!:2",
    "4c,4c#,4E,4Gb/4"
])
ch
# Out:
# Spelling: 4Ab 4Gb, penalty= 0.5889, intervalPenalty=0, groupPenalty=0, chordPenalty=0.3468
# Spelling: 4Ab 4F#, penalty= 1.483, intervalPenalty=2, groupPenalty=0, chordPenalty=0.2002
# DEBUG: Enharmonic spelling - orig. ['4Ab', '4F#'], horizontal solution=['4Ab', '4Gb']
# DEBUG: Enharmonic spelling - chord «[3F 3B 4D# 4Ab] 0:2 2♩» - previous slots state:
#
#        chords fixed slots:
# DEBUG: Enharmonic spelling - chord «[3F 3B 4D# 4Ab] 0:2 2♩» - solution: ('3F', '3B', '4Eb', '4Ab')
#        fixed slots: Ab
#        variants: [('3F', '3B', '4Eb', '4Ab'), ('3F', '3B', '4D#', '4Ab')]
# DEBUG: Enharmonic spelling - chord «[4C 4C# 4E 4Gb] 2:3 1♩» - previous slots state:
#        Eb, Ab
#        chords fixed slots: Eb, Ab
# DEBUG: Enharmonic spelling - chord «[4C 4C# 4E 4Gb] 2:3 1♩» - solution: ('4C', '4Db', '4E', '4Gb')
#        fixed slots: Eb, Gb, Ab
#        variants: [('4C', '4Db', '4E', '4Gb'), ('4C', '4C#', '4E', '4Gb')]
# Chain([‹3F 3B 4Eb 4Ab 2♩›, ‹4C 4Db 4E 4Gb 1♩›])

# %%
ch = Chain([
    "4C:0.5",
    "4D:1",
    "4E:0.5",
    "4D#,4E-"
    
])
ch
# Out:
# Spelling: 4C 4D 4E 4E-, penalty= 1.414, intervalPenalty=2, groupPenalty=0, chordPenalty=0
# Spelling: 4C 4D 4E 4D#+, penalty= 2.005, intervalPenalty=0, groupPenalty=4, chordPenalty=0.02
# DEBUG: Enharmonic spelling - orig. ['4C', '4D', '4E', '4E-'], horizontal solution=['4C', '4D', '4E', '4E-']
# DEBUG: Enharmonic spelling - chord «[4D# 4E-] 2:3 1♩» - previous slots state:
#
#        chords fixed slots:
# DEBUG: Enharmonic spelling - chord «[4D# 4E-] 2:3 1♩» - solution: ('4D#', '4E-')
#        fixed slots: E-
#        variants: [('4D#', '4E-'), ('4Eb', '4E-')]
# Chain([4C:0.5♩, 4D:1♩, 4E:0.5♩, ‹4D# 4E- 1♩›])

# %%
ch.play(instr='sin')
# Out:
# --Csound version 6.18 (double samples) Dec  2 2022
# [commit: ac38f27d1c5d6ee0cacc1bc719e96be3a2d93a15]
# libsndfile-1.0.31
# sr = 44100.0, kr = 689.062, ksmps = 64
# 0dBFS level = 1.0, A4 tuning = 442.0
# audio buffered in 256 sample-frame blocks
# reading 1024-byte blks of shorts from adc:system:capture (RAW)
# writing 512 sample blks of 64-bit floats to dac:system:playback
# SECTION 1:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=5)
#     Synth(𝍪 preset.sin:501.0002, p4=0 idataidx_:5=17 inumbps:6=2 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 p17=0 p18=60 p19=0.515178 p20=0.5 ...)
#     Synth(𝍪 preset.sin:501.0003, p4=0 idataidx_:5=17 inumbps:6=2 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 p17=0 p18=62 p19=0.515178 p20=1 ...)
#     Synth(𝍪 preset.sin:501.0004, p4=0 idataidx_:5=17 inumbps:6=2 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 p17=0 p18=64 p19=0.515178 p20=0.5 ...)
#     Synth(𝍪 preset.sin:501.0005, p4=0 idataidx_:5=17 inumbps:6=2 ibplen:7=3 igain:8=0.707107 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 p17=0 p18=63 p19=0.515178 p20=1 ...)
#     Synth(𝍪 preset.sin:501.0006, p4=0 idataidx_:5=17 inumbps:6=2 ibplen:7=3 igain:8=0.707107 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 p17=0 p18=63.5 p19=0.515178 p20=1 ...)
