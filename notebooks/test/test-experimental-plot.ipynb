# %%
# %matplotlib qt
# Out:
# QSocketNotifier: Can only be used with threads started with QThread

# %%
from maelzel.core import *
from maelzel.core import _plot

# %%
s = Score([
    Voice(r'''
      3F+,3A:1
      4C+:1
      4Db:0.5
      4D-:1:gliss
      6Gb-!,4A
    ''')
])

# %%
_plot.plotVoices(s.voices, accidentalColor=(0.1, 0.1, 0.1, 1), accidentalSize=20, eventStartLineWidth=3, chordLink=False, eventHeight=1.3)
