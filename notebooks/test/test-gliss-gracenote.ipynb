# %%
from maelzel.snd import features
from maelzel.snd.audiosample import Sample
import matplotlib.pyplot as plt
from maelzel.snd import playback
from maelzel.snd import vamptools
from pitchtools import *
from maelzel.transcribe import mono
from maelzel.core import *
from maelzel import scoring
from emlib.iterlib import *
from math import *

#%matplotlib qt
#%load_ext line_profiler

# %%
ch = Chain("""
    C4:1
    4D:1
    4E:1
""")
ch[1].setPlay(sustain=0.5)
ch.play(sustain=0.1, fade=(0, 0.1))
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=3)
#     Synth(𝍪 preset:.piano=501.0033 start=142.931 dur=1.100 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0 ifadein=0.1 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=60 p18=0.515178 p19=1 …)
#     Synth(𝍪 preset:.piano=501.0034 start=143.931 dur=1.500 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0 ifadein=0.1 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=62 p18=0.515178 p19=1 …)
#     Synth(𝍪 preset:.piano=501.0035 start=144.931 dur=1.100 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0 ifadein=0.1 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=64 p18=0.515178 p19=1 …)

# %%
ch = Chain([
    "4C:1:gliss:mf:downbow",
    "4G:0",
    "4G:1:gliss",
    "4C:0:():stemless"
])
ch[0].setPlay(glisstime=0.01)
ch[2].setPlay(glisstime=0.01)
ch.addSpanner('slur')
# ch.rec("~/tmp/gliss.flac", instr='saw', extratime=1, pitchinterpol='linear', nchnls=1)
ch
# Out:
# Chain([4C:1♩:gliss=True:symbols=[Articulation(kind=downbow), Slur(anchor=ref(Note), kind=start, linetype=solid, partnerSpanner=ref(Slur), uuid=37ylfvr2)], 4G, 4G:1♩:gliss=True, 4C:symbols=[Notehead(parenthesis=True), Stem(hidden=True), Slur(anchor=ref(Note), kind=end, linetype=solid, partnerSpanner=ref(Slur), uuid=37ylfvr2)]])

# %%
ch.play(skip=0.8)
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=2)
#     Synth(𝍪 preset:.piano=501.0038 start=180.158 dur=0.200 p4=0.5 kpos=1 kgain=17 idataidx_=4 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=60 p18=0.343838 p19=0.118571 …)
#     Synth(𝍪 preset:.piano=501.0039 start=180.358 dur=1.000 p4=0.5 kpos=1 kgain=17 idataidx_=4 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=67 p18=0.343838 p19=0.918571 …)

# %%
from maelzel.core import *
setTempo(60)
ch = Chain("""
    C4-:0.5
    4D+,4Eb:0.5
    4E-:0.5
    4F-:0.5
""")
ch2 = ch.cycle(totaldur=20)
for i, ev in enumerate(ch2):
    if i%3 == 0:
        ev.gliss = True
    if i%5 == 0:
        ev.gliss = False
        ev.setPlay(end=ev.dur*0.25, fade=(0.005, 0.05))
        ev.addSymbol('staccato')
    if i%7 == 0:
        ev.dur = ev.dur * F(3, 2)
    if i%11 == 0:
        ev.dur = ev.dur / 2
        
ch2.show()
ch2.play(instr='sin')

# TODO: revise rules to break syncopations
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=43)
#     Synth(𝍪 preset:sin=501.0217 start=322.462 dur=0.125 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0.005 ifadein=0.05 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=59.5 p18=0.515178 p19=0.125 p20=59.5 …)
#     Synth(𝍪 preset:sin=501.0218 start=322.837 dur=0.500 p4=0.5 kpos=0.707107 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=62.5 p18=0.515178 p19=0.5 p20=62.5 …)
#     Synth(𝍪 preset:sin=501.0219 start=322.837 dur=0.500 p4=0.5 kpos=0.707107 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=63 p18=0.515178 p19=0.5 p20=63 …)
#     Synth(𝍪 preset:sin=501.022 start=323.337 dur=0.500 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=63.5 p18=0.515178 p19=0.5 p20=63.5 …)
#     Synth(𝍪 preset:sin=501.0221 start=323.837 dur=1.000 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=64.5 p18=0.515178 p19=0.5 p20=59.5 …)
#     Synth(𝍪 preset:sin=501.0222 start=324.837 dur=0.125 p4=0.5 kpos=0.707107 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0.005 ifadein=0.05 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=62.5 p18=0.515178 p19=0.125 p20=62.5 …)
#     Synth(𝍪 preset:sin=501.0223 start=324.837 dur=0.125 p4=0.5 kpos=0.707107 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0.005 ifadein=0.05 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=63 p18=0.515178 p19=0.125 p20=63 …)
#     Synth(𝍪 preset:sin=501.0224 start=325.337 dur=1.250 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=63.5 p18=0.515178 p19=0.5 p20=64.5 …)
#     Synth(𝍪 preset:sin=501.0225 start=326.587 dur=0.500 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=59.5 p18=0.515178 p19=0.5 p20=59.5 …)
#     Synth(𝍪 preset:sin=501.0226 start=327.087 dur=0.625 p4=0.5 kpos=0.707107 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=62.5 p18=0.515178 p19=0.5 p20=63.5 …)
#     Synth(𝍪 preset:sin=501.0227 start=327.087 dur=0.500 p4=0.5 kpos=0.707107 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=63 p18=0.515178 p19=0.5 p20=63.5 …)
#     Synth(𝍪 preset:sin=501.0228 start=328.087 dur=0.250 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=64.5 p18=0.515178 p19=0.25 p20=64.5 …)
#     Synth(𝍪 preset:sin=501.0229 start=328.337 dur=1.000 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=59.5 p18=0.515178 p19=0.5 p20=63 …)
#     Synth(𝍪 preset:sin=501.023 start=328.837 dur=0.500 p4=0.5 kpos=0.707107 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=62.5 p18=0.515178 p19=0.5 p20=62.5 …)
#     Synth(𝍪 preset:sin=501.0231 start=328.837 dur=0.500 p4=0.5 kpos=0.707107 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=62.5 p18=0.515178 p19=0.5 p20=62.5 …)
#     Synth(𝍪 preset:sin=501.0232 start=329.337 dur=0.750 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=63.5 p18=0.515178 p19=0.75 p20=63.5 …)
#     Synth(𝍪 preset:sin=501.0233 start=330.087 dur=0.125 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0.005 ifadein=0.05 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=64.5 p18=0.515178 p19=0.125 p20=64.5 …)
#     Synth(𝍪 preset:sin=501.0234 start=330.587 dur=0.500 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=59.5 p18=0.515178 p19=0.5 p20=59.5 …)
#     Synth(𝍪 preset:sin=501.0235 start=331.087 dur=0.500 p4=0.5 kpos=0.707107 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=62.5 p18=0.515178 p19=0.5 p20=62.5 …)
#     Synth(𝍪 preset:sin=501.0236 start=331.087 dur=0.500 p4=0.5 kpos=0.707107 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=63 p18=0.515178 p19=0.5 p20=63 …)
#     Synth(𝍪 preset:sin=501.0237 start=331.587 dur=1.000 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=63.5 p18=0.515178 p19=0.5 p20=64.5 …)
#     Synth(𝍪 preset:sin=501.0238 start=332.587 dur=0.125 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0.005 ifadein=0.05 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=59.5 p18=0.515178 p19=0.125 p20=59.5 …)
#     Synth(𝍪 preset:sin=501.0239 start=333.087 dur=1.000 p4=0.5 kpos=0.707107 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=62.5 p18=0.515178 p19=0.75 p20=63.5 …)
#     Synth(𝍪 preset:sin=501.024 start=333.087 dur=0.750 p4=0.5 kpos=0.707107 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=63 p18=0.515178 p19=0.75 p20=63.5 …)
#     Synth(𝍪 preset:sin=501.0241 start=334.087 dur=0.500 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=64.5 p18=0.515178 p19=0.5 p20=64.5 …)
#     Synth(𝍪 preset:sin=501.0242 start=334.587 dur=0.625 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=59.5 p18=0.515178 p19=0.5 p20=63 …)
#     Synth(𝍪 preset:sin=501.0243 start=335.087 dur=0.125 p4=0.5 kpos=0.707107 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0.005 ifadein=0.05 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=62.5 p18=0.515178 p19=0.125 p20=62.5 …)
#     Synth(𝍪 preset:sin=501.0244 start=335.087 dur=0.125 p4=0.5 kpos=0.707107 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0.005 ifadein=0.05 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=62.5 p18=0.515178 p19=0.125 p20=62.5 …)
#     Synth(𝍪 preset:sin=501.0245 start=335.587 dur=0.500 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=63.5 p18=0.515178 p19=0.5 p20=63.5 …)
#     Synth(𝍪 preset:sin=501.0246 start=336.087 dur=1.250 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=64.5 p18=0.515178 p19=0.5 p20=59.5 …)
#     Synth(𝍪 preset:sin=501.0247 start=337.337 dur=0.500 p4=0.5 kpos=0.707107 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=62.5 p18=0.515178 p19=0.5 p20=62.5 …)
#     Synth(𝍪 preset:sin=501.0248 start=337.337 dur=0.500 p4=0.5 kpos=0.707107 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=63 p18=0.515178 p19=0.5 p20=63 …)
#     Synth(𝍪 preset:sin=501.0249 start=337.837 dur=0.125 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0.005 ifadein=0.05 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=63.5 p18=0.515178 p19=0.125 p20=63.5 …)
#     Synth(𝍪 preset:sin=501.025 start=338.337 dur=0.500 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=64.5 p18=0.515178 p19=0.5 p20=64.5 …)
#     Synth(𝍪 preset:sin=501.0251 start=338.837 dur=0.500 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=59.5 p18=0.515178 p19=0.5 p20=59.5 …)
#     Synth(𝍪 preset:sin=501.0252 start=339.337 dur=0.750 p4=0.5 kpos=0.707107 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=62.5 p18=0.515178 p19=0.25 p20=63.5 …)
#     Synth(𝍪 preset:sin=501.0253 start=339.337 dur=0.250 p4=0.5 kpos=0.707107 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=63 p18=0.515178 p19=0.25 p20=63.5 …)
#     Synth(𝍪 preset:sin=501.0254 start=340.087 dur=0.125 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0.005 ifadein=0.05 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=64.5 p18=0.515178 p19=0.125 p20=64.5 …)
#     Synth(𝍪 preset:sin=501.0255 start=340.837 dur=1.000 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=59.5 p18=0.515178 p19=0.5 p20=63 …)
#     Synth(𝍪 preset:sin=501.0256 start=341.337 dur=0.500 p4=0.5 kpos=0.707107 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=62.5 p18=0.515178 p19=0.5 p20=62.5 …)
#     Synth(𝍪 preset:sin=501.0257 start=341.337 dur=0.500 p4=0.5 kpos=0.707107 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=62.5 p18=0.515178 p19=0.5 p20=62.5 …)
#     Synth(𝍪 preset:sin=501.0258 start=341.837 dur=0.500 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=63.5 p18=0.515178 p19=0.5 p20=63.5 …)
#     Synth(𝍪 preset:sin=501.0259 start=342.337 dur=0.500 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=64.5 p18=0.515178 p19=0.5 p20=64.5 …)

# %%
ch2.play(instr='saw')
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=50)
#     Synth(𝍪 preset:saw:502.0084, p4=0 idataidx_:5=19 inumbps:6=2 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 kcutoffratio:17=0 kfilterq:18=3 p19=0 p20=59.5 p21=0.515178 p22=0.25 ...)
#     Synth(𝍪 preset:saw:502.0085, p4=0 idataidx_:5=19 inumbps:6=2 ibplen:7=3 igain:8=0.707107 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 kcutoffratio:17=0 kfilterq:18=3 p19=0 p20=62.5 p21=0.515178 p22=0.5 ...)
#     Synth(𝍪 preset:saw:502.0086, p4=0 idataidx_:5=19 inumbps:6=2 ibplen:7=3 igain:8=0.707107 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 kcutoffratio:17=0 kfilterq:18=3 p19=0 p20=63 p21=0.515178 p22=0.5 ...)
#     Synth(𝍪 preset:saw:502.0087, p4=0 idataidx_:5=19 inumbps:6=2 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 kcutoffratio:17=0 kfilterq:18=3 p19=0 p20=63.5 p21=0.515178 p22=0.5 ...)
#     Synth(𝍪 preset:saw:502.0088, p4=0 idataidx_:5=19 inumbps:6=2 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 kcutoffratio:17=0 kfilterq:18=3 p19=0 p20=64.5 p21=0.515178 p22=0.5 ...)
#     Synth(𝍪 preset:saw:502.0089, p4=0 idataidx_:5=19 inumbps:6=2 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 kcutoffratio:17=0 kfilterq:18=3 p19=0 p20=59.5 p21=0.515178 p22=0.5 ...)
#     Synth(𝍪 preset:saw:502.009, p4=0 idataidx_:5=19 inumbps:6=2 ibplen:7=3 igain:8=0.707107 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 kcutoffratio:17=0 kfilterq:18=3 p19=0 p20=62.5 p21=0.515178 p22=0.25 ...)
#     Synth(𝍪 preset:saw:502.0091, p4=0 idataidx_:5=19 inumbps:6=2 ibplen:7=3 igain:8=0.707107 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 kcutoffratio:17=0 kfilterq:18=3 p19=0 p20=63 p21=0.515178 p22=0.25 ...)
#     Synth(𝍪 preset:saw:502.0092, p4=0 idataidx_:5=19 inumbps:6=2 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 kcutoffratio:17=0 kfilterq:18=3 p19=0 p20=63.5 p21=0.515178 p22=0.5 ...)
#     Synth(𝍪 preset:saw:502.0093, p4=0 idataidx_:5=19 inumbps:6=2 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 kcutoffratio:17=0 kfilterq:18=3 p19=0 p20=64.5 p21=0.515178 p22=0.5 ...)
#     Synth(𝍪 preset:saw:502.0094, p4=0 idataidx_:5=19 inumbps:6=2 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 kcutoffratio:17=0 kfilterq:18=3 p19=0 p20=59.5 p21=0.515178 p22=0.5 ...)
#     Synth(𝍪 preset:saw:502.0095, p4=0 idataidx_:5=19 inumbps:6=2 ibplen:7=3 igain:8=0.707107 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 kcutoffratio:17=0 kfilterq:18=3 p19=0 p20=62.5 p21=0.515178 p22=0.5 ...)
#     Synth(𝍪 preset:saw:502.0096, p4=0 idataidx_:5=19 inumbps:6=2 ibplen:7=3 igain:8=0.707107 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 kcutoffratio:17=0 kfilterq:18=3 p19=0 p20=63 p21=0.515178 p22=0.5 ...)
#     Synth(𝍪 preset:saw:502.0097, p4=0 idataidx_:5=19 inumbps:6=2 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 kcutoffratio:17=0 kfilterq:18=3 p19=0 p20=63.5 p21=0.515178 p22=0.25 ...)
#     Synth(𝍪 preset:saw:502.0098, p4=0 idataidx_:5=19 inumbps:6=2 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 kcutoffratio:17=0 kfilterq:18=3 p19=0 p20=64.5 p21=0.515178 p22=0.5 ...)
#     Synth(𝍪 preset:saw:502.0099, p4=0 idataidx_:5=19 inumbps:6=2 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 kcutoffratio:17=0 kfilterq:18=3 p19=0 p20=59.5 p21=0.515178 p22=0.5 ...)
#     Synth(𝍪 preset:saw:502.01, p4=0 idataidx_:5=19 inumbps:6=2 ibplen:7=3 igain:8=0.707107 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 kcutoffratio:17=0 kfilterq:18=3 p19=0 p20=62.5 p21=0.515178 p22=0.5 ...)
#     Synth(𝍪 preset:saw:502.0101, p4=0 idataidx_:5=19 inumbps:6=2 ibplen:7=3 igain:8=0.707107 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 kcutoffratio:17=0 kfilterq:18=3 p19=0 p20=63 p21=0.515178 p22=0.5 ...)
#     Synth(𝍪 preset:saw:502.0102, p4=0 idataidx_:5=19 inumbps:6=2 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 kcutoffratio:17=0 kfilterq:18=3 p19=0 p20=63.5 p21=0.515178 p22=0.5 ...)
#     Synth(𝍪 preset:saw:502.0103, p4=0 idataidx_:5=19 inumbps:6=2 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 kcutoffratio:17=0 kfilterq:18=3 p19=0 p20=64.5 p21=0.515178 p22=0.25 ...)
#     Synth(𝍪 preset:saw:502.0104, p4=0 idataidx_:5=19 inumbps:6=2 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 kcutoffratio:17=0 kfilterq:18=3 p19=0 p20=59.5 p21=0.515178 p22=0.5 ...)
#     Synth(𝍪 preset:saw:502.0105, p4=0 idataidx_:5=19 inumbps:6=2 ibplen:7=3 igain:8=0.707107 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 kcutoffratio:17=0 kfilterq:18=3 p19=0 p20=62.5 p21=0.515178 p22=0.5 ...)
#     Synth(𝍪 preset:saw:502.0106, p4=0 idataidx_:5=19 inumbps:6=2 ibplen:7=3 igain:8=0.707107 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 kcutoffratio:17=0 kfilterq:18=3 p19=0 p20=63 p21=0.515178 p22=0.5 ...)
#     Synth(𝍪 preset:saw:502.0107, p4=0 idataidx_:5=19 inumbps:6=2 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 kcutoffratio:17=0 kfilterq:18=3 p19=0 p20=63.5 p21=0.515178 p22=0.5 ...)
#     Synth(𝍪 preset:saw:502.0108, p4=0 idataidx_:5=19 inumbps:6=2 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 kcutoffratio:17=0 kfilterq:18=3 p19=0 p20=64.5 p21=0.515178 p22=0.5 ...)
#     Synth(𝍪 preset:saw:502.0109, p4=0 idataidx_:5=19 inumbps:6=2 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 kcutoffratio:17=0 kfilterq:18=3 p19=0 p20=59.5 p21=0.515178 p22=0.25 ...)
#     Synth(𝍪 preset:saw:502.011, p4=0 idataidx_:5=19 inumbps:6=2 ibplen:7=3 igain:8=0.707107 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 kcutoffratio:17=0 kfilterq:18=3 p19=0 p20=62.5 p21=0.515178 p22=0.5 ...)
#     Synth(𝍪 preset:saw:502.0111, p4=0 idataidx_:5=19 inumbps:6=2 ibplen:7=3 igain:8=0.707107 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 kcutoffratio:17=0 kfilterq:18=3 p19=0 p20=63 p21=0.515178 p22=0.5 ...)
#     Synth(𝍪 preset:saw:502.0112, p4=0 idataidx_:5=19 inumbps:6=2 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 kcutoffratio:17=0 kfilterq:18=3 p19=0 p20=63.5 p21=0.515178 p22=0.5 ...)
#     Synth(𝍪 preset:saw:502.0113, p4=0 idataidx_:5=19 inumbps:6=2 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 kcutoffratio:17=0 kfilterq:18=3 p19=0 p20=64.5 p21=0.515178 p22=0.5 ...)
#     Synth(𝍪 preset:saw:502.0114, p4=0 idataidx_:5=19 inumbps:6=2 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 kcutoffratio:17=0 kfilterq:18=3 p19=0 p20=59.5 p21=0.515178 p22=0.5 ...)
#     Synth(𝍪 preset:saw:502.0115, p4=0 idataidx_:5=19 inumbps:6=2 ibplen:7=3 igain:8=0.707107 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 kcutoffratio:17=0 kfilterq:18=3 p19=0 p20=62.5 p21=0.515178 p22=0.25 ...)
#     Synth(𝍪 preset:saw:502.0116, p4=0 idataidx_:5=19 inumbps:6=2 ibplen:7=3 igain:8=0.707107 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 kcutoffratio:17=0 kfilterq:18=3 p19=0 p20=63 p21=0.515178 p22=0.25 ...)
#     Synth(𝍪 preset:saw:502.0117, p4=0 idataidx_:5=19 inumbps:6=2 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 kcutoffratio:17=0 kfilterq:18=3 p19=0 p20=63.5 p21=0.515178 p22=0.5 ...)
#     Synth(𝍪 preset:saw:502.0118, p4=0 idataidx_:5=19 inumbps:6=2 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 kcutoffratio:17=0 kfilterq:18=3 p19=0 p20=64.5 p21=0.515178 p22=0.5 ...)
#     Synth(𝍪 preset:saw:502.0119, p4=0 idataidx_:5=19 inumbps:6=2 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 kcutoffratio:17=0 kfilterq:18=3 p19=0 p20=59.5 p21=0.515178 p22=0.5 ...)
#     Synth(𝍪 preset:saw:502.012, p4=0 idataidx_:5=19 inumbps:6=2 ibplen:7=3 igain:8=0.707107 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 kcutoffratio:17=0 kfilterq:18=3 p19=0 p20=62.5 p21=0.515178 p22=0.5 ...)
#     Synth(𝍪 preset:saw:502.0121, p4=0 idataidx_:5=19 inumbps:6=2 ibplen:7=3 igain:8=0.707107 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 kcutoffratio:17=0 kfilterq:18=3 p19=0 p20=63 p21=0.515178 p22=0.5 ...)
#     Synth(𝍪 preset:saw:502.0122, p4=0 idataidx_:5=19 inumbps:6=2 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 kcutoffratio:17=0 kfilterq:18=3 p19=0 p20=63.5 p21=0.515178 p22=0.25 ...)
#     Synth(𝍪 preset:saw:502.0123, p4=0 idataidx_:5=19 inumbps:6=2 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 kcutoffratio:17=0 kfilterq:18=3 p19=0 p20=64.5 p21=0.515178 p22=0.5 ...)
#     Synth(𝍪 preset:saw:502.0124, p4=0 idataidx_:5=19 inumbps:6=2 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 kcutoffratio:17=0 kfilterq:18=3 p19=0 p20=59.5 p21=0.515178 p22=0.5 ...)
#     Synth(𝍪 preset:saw:502.0125, p4=0 idataidx_:5=19 inumbps:6=2 ibplen:7=3 igain:8=0.707107 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 kcutoffratio:17=0 kfilterq:18=3 p19=0 p20=62.5 p21=0.515178 p22=0.5 ...)
#     Synth(𝍪 preset:saw:502.0126, p4=0 idataidx_:5=19 inumbps:6=2 ibplen:7=3 igain:8=0.707107 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 kcutoffratio:17=0 kfilterq:18=3 p19=0 p20=63 p21=0.515178 p22=0.5 ...)
#     Synth(𝍪 preset:saw:502.0127, p4=0 idataidx_:5=19 inumbps:6=2 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 kcutoffratio:17=0 kfilterq:18=3 p19=0 p20=63.5 p21=0.515178 p22=0.5 ...)
#     Synth(𝍪 preset:saw:502.0128, p4=0 idataidx_:5=19 inumbps:6=2 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 kcutoffratio:17=0 kfilterq:18=3 p19=0 p20=64.5 p21=0.515178 p22=0.25 ...)
#     Synth(𝍪 preset:saw:502.0129, p4=0 idataidx_:5=19 inumbps:6=2 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 kcutoffratio:17=0 kfilterq:18=3 p19=0 p20=59.5 p21=0.515178 p22=0.5 ...)
#     Synth(𝍪 preset:saw:502.013, p4=0 idataidx_:5=19 inumbps:6=2 ibplen:7=3 igain:8=0.707107 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 kcutoffratio:17=0 kfilterq:18=3 p19=0 p20=62.5 p21=0.515178 p22=0.5 ...)
#     Synth(𝍪 preset:saw:502.0131, p4=0 idataidx_:5=19 inumbps:6=2 ibplen:7=3 igain:8=0.707107 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 kcutoffratio:17=0 kfilterq:18=3 p19=0 p20=63 p21=0.515178 p22=0.5 ...)
#     Synth(𝍪 preset:saw:502.0132, p4=0 idataidx_:5=19 inumbps:6=2 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 kcutoffratio:17=0 kfilterq:18=3 p19=0 p20=63.5 p21=0.515178 p22=0.5 ...)
#     Synth(𝍪 preset:saw:502.0133, p4=0 idataidx_:5=19 inumbps:6=2 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 kcutoffratio:17=0 kfilterq:18=3 p19=0 p20=64.5 p21=0.515178 p22=0.5 ...)

# %%
ch = Chain([
    "4E~:1/2", 
    "4E:1+1/3:gliss:stem(hidden=True)",
    "4F:1",
    "4G:0.5:x:mf"
])
ch[1].addSymbol(notehead='x')
ch
# Out:
# Chain([4E~:0.5♩, 4E:1.333♩:gliss=True:symbols=[Stem(hidden=True), Notehead(shape=cross)], 4F:1♩, 4G:0.5♩:symbols=[Notehead(shape=cross)]])

# %%
ch = Chain([
    "4E~:1/2", 
    "4E,4G:1+1/3:gliss",
    "4F,4Ab:0.5:gliss",
    "4G:2:gliss",
    "4E:0:notehead=():stemless",
    "4E:2:accent"
])
ch[1].addSymbol(notehead='x').addSymbol(symbols.GlissProperties(linetype='solid', color='red'))
# ch[3].addSpanner('slur', ch[4])
# ch[4].addSymbol(symbols.Stem(hidden=True))
# ch[5].

ch.write("~/tmp/gliss.ly")
ch
# Out:
# Chain([4E~:0.5♩, ‹4E 4G 1.33♩ gliss›, ‹4F 4Ab 0.5♩ gliss›, 4G:2♩:gliss=True, 4E:symbols=[Notehead(shape=normal, parenthesis=True), Stem(hidden=True)], 4E:2♩:symbols=[Articulation(kind=accent)]])

# %%
ch.play(instr='piano')
# Out:
# --Csound version 6.19 (double samples) May 26 2023
# [commit: 593ac80dd986b58f24e3d59242243ba6266edda7]
# libsndfile-1.2.0
# sr = 48000.0, kr = 750.000, ksmps = 64
# 0dBFS level = 1.0, A4 tuning = 442.0
# audio buffered in 1024 sample-frame blocks
# reading 8192-byte blks of shorts from adc:Built-in Audio Analogue Stereo: (RAW)
# writing 2048 sample blks of 64-bit floats to dac:Built-in Audio Analogue Stereo:
# SECTION 1:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=3)
#     Synth(𝍪 preset:piano:501.0002, p4=0 idataidx_:5=15 inumbps:6=6 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 p15=0 p16=64 ...)
#     Synth(𝍪 preset:piano:501.0003, p4=0 idataidx_:5=15 inumbps:6=3 ibplen:7=3 igain:8=0.707107 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 p15=0 p16=67 ...)
#     Synth(𝍪 preset:piano:501.0004, p4=0 idataidx_:5=15 inumbps:6=2 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 p15=0 p16=64 ...)

# %%
from maelzel.core import *
ch = Chain([
    "4G:2:gliss",
    "4E:0:notehead=():slur",
    "4E:2"
])
# ch[3].addSpanner('slur', ch[4])
# ch[4].addSymbol(symbols.Stem(hidden=True))
# ch[5].
ch
# Out:
# Chain([4G:2♩:gliss=True, 4E:symbols=[Notehead(shape=normal, parenthesis=True), Slur(anchor=ref(Note), kind=start, linetype=solid, uuid=16zqwk6e)], 4E:2♩])

# %%
ch.play()
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=2)
#     Synth(𝍪 preset:.piano=502.0004 start=476.083 dur=2.000 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=67 p18=0.515178 p19=1.92857 …)
#     Synth(𝍪 preset:.piano=502.0005 start=478.083 dur=2.000 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=64 p18=0.515178 p19=2 …)

# %%
ch = Chain([
    "4E~:1/2", 
    "4E:1+1/3:gliss",
    "4F:0.5:gliss",
    "4G:2:gliss",
    "4E:2:gliss",
    "4A:0.25:gliss",
    "4G#:0.25"
])
ch[1].addSymbol('notehead', 'x')
ch[3].addSpanner('slur', ch[4])
# ch[4].addSymbol(symbols.Stem(hidden=True))
# ch[5].
ch.write('~/tmp/gliss.ly')
ch
# Out:
# Chain([4E~:0.5♩, 4E:1.333♩:gliss=True:symbols=[Notehead(shape=cross)], 4F:0.5♩:gliss=True, 4G:2♩:gliss=True:symbols=[Slur(anchor=ref(Note), kind=start, linetype=solid, partnerSpanner=ref(Slur), uuid=6aut7ae3)], 4E:2♩:gliss=True:symbols=[Slur(anchor=ref(Note), kind=end, linetype=solid, partnerSpanner=ref(Slur), uuid=6aut7ae3)], 4A:0.25♩:gliss=True, 4G#:0.25♩])
# Exiting python, closing all active engines
# ... stopping maelzel.core
#  *** rtjack: connection to JACK server was lost, reconnecting...end of score.		   overall amps:  0.87944  0.87944
# 	   overall samples out of range:        0        0
# 0 errors in performance
# 3256857 1024 sample blks of 64-bit floats written to dac:Built-in Audio Pro:

# %%
ch = Chain([
    "4G:2:gliss:downbow",
    "4E:0",
    "4E:1:upbow"
])
ch.play(fade=0)
ch
# Out:
# Chain([4G:2♩:gliss=True:symbols=[Articulation(kind=downbow)], 4E, 4E:1♩:symbols=[Articulation(kind=upbow)]])
#  *** rtjack: connection to JACK server was lost, reconnecting... *** rtjack: connection to JACK server was lost, reconnecting...

# %%
ch.events()
# Out:
# [SynthEvent(delay=0, dur=1.33, gain=1, chan=1, fade=(0.02, 0.02), instr=sin)
#  bps 0.000s: 67       0.515178
#      1.262s: 64       0.515178
#      1.333s: 64       0.515178,
#  SynthEvent(delay=1.33, dur=1, gain=1, chan=1, fade=(0.02, 0.02), instr=sin)
#  bps 0.000s: 64       0.515178
#      1.000s: 64       0.515178]
