# %%
from maelzel.core import *

# %%
from maelzel.core import *

v2 = Voice(["4C#~:1", 
            "4C#:1/3",
            "4G+:3/3",
           ])
v2.show(backend='lilypond')
v2.show(backend='musicxml')
v2.write("~/tmp/1.musicxml")

# %%
from maelzel.core import *
cfg = getConfig()
cfg['quant.nestedTuplets'] = None
v2 = Voice(["4C#:1/5", 
            "4C+:3/10", 
            "4Eb,4G,4Bb!:3/5", 
           ])
v2

v2.show(backend='lilypond')
v2.show(backend='musicxml')
v2.write("~/tmp/2.musicxml")

# %%
from maelzel.core import *
v1 = Voice(["4C#:2/3:offset=1/3", 
            "4C+:2/3", 
            "4Eb:2/9", 
            "4F:1/9",
            ], name='foo')

cfg = getConfig()
cfg['quant.nestedTuplets'] = None


v1.show(backend='lilypond')
v1.show(backend='musicxml')

# %%
v3 = Voice(["4C#:2/9", 
            "4C+:2/9", 
            "4Eb:2/9", 
            "4F:2/3",
            "4G:2/3"
            ])
v3.show()
v3.show(backend='musicxml')

# %%
v4 = Voice(["4C#:2/9", 
            "4C+:2/9", 
            "4Eb:2/9", 
            "4F:2/3",
            "4G:2/9",
            "4A:2/9",
            "4B:2/9",
            
            ])
v4.show()
v4.show(backend='musicxml')

# %% [markdown]
# ## Dynamics

# %%
from maelzel.core import *
from maelzel.scoring import rendermusicxml

v = Voice([
    Note("4C", 1, dynamic='ff').addSpanner(">"),
    Note("4D", 0.5),
    Chord(("4E", "4A"), 1, dynamic='p')
])
v.show()
v.show(backend='musicxml')

# %% [markdown]
# ## Spanners

# %% [markdown]
# ### slurs

# %%
from maelzel.core import *
from maelzel.scoring import rendermusicxml

v = Voice([
    Note("4C", 1, dynamic='ff'),
    Note("4D", 0.5),
    Chord(("4E", "4A"), 1, dynamic='p')
])
v[0].addSpanner('slur', v[2])
v.show()
v.show(backend='musicxml')

# %%
from maelzel.core import *

v = Voice([
    Note("4C", 1, dynamic='ff'),
    Note("4D", 0.5),
    Chord(("4E", "4A"), 1, dynamic='p')
])
v[0].addSpanner('trill', v[2])
v.show()
v.show(backend='musicxml')
v.write('~/tmp/trill.musicxml')

# %%
from maelzel.core import *

v = Voice([
    Note("4C", 1, dynamic='ff'),
    Note("4D", 0.5),
    Chord(("4E", "4A"), 1, dynamic='p'),
    Chord(("4C", "4F"), 1, dynamic='p'),
    
])
v[0].addSpanner('bracket', v[2])
v.show()
v.show(backend='musicxml')
v.write('~/tmp/bracket.musicxml')

# %%
from maelzel.core import *

v = Voice([
    Note("4C", 1, dynamic='ff'),
    Note("4D", 0.5),
    Chord(("4F", "4A"), 1),
    Chord(("4D", "4F"), 1, dynamic='p'),
    
])
v[0].addSpanner(symbols.Hairpin('>'), v[3])
v.show()
v.show(backend='musicxml')
v.write('~/tmp/linespan.musicxml')

# %% [markdown]
# ## Gracenotes

# %%
from maelzel.core import *
from maelzel.scoring import rendermusicxml

v = Voice([
    Note("4E", 0),
    Note("4F", 0),
    Note("4C", 1),
    Chord("4D,4G", 0),
    
    Chord(("4E", "4A"), 1)
])
v.show()
v.show(backend='musicxml')

# %% [markdown]
# ## Glissando

# %%
from maelzel.core import *
from maelzel.scoring import rendermusicxml

v = Voice([
    Note("4C", 1, gliss=True),
    Note("4D", 1),
    Chord(("4E", "4A"), 1, gliss=('4F', '4G')),
    Note("4C", 1)
])
v.show()
v.show(backend='musicxml')
# Out:
# [maelzel.core:mobj.py:1726 - _renderObject] rendering parts with backend: lilypond
# [maelzel.scoring:quant.py:2196 - _mergeSiblings] Nodes can merge:
#     Node(1/1,
#   «0.000:1.000 1/1♩ 4C gliss»
# )
#     Node(1/1,
#   «1.000:2.000 1/1♩ 4D»
# )
# [maelzel.scoring:quant.py:2200 - _mergeSiblings] mergeSiblings: Node(1/1,
#   «0.000:1.000 1/1♩ 4C gliss»
#   «1.000:2.000 1/1♩ 4D»
# ) cannot merge with Node(1/1,
#   «2.000:3.000 1/1♩ [4E 4A] gliss»
# ): no need to extend node over beat
# [maelzel.scoring:quant.py:2200 - _mergeSiblings] mergeSiblings: Node(1/1,
#   «2.000:3.000 1/1♩ [4E 4A] gliss»
# ) cannot merge with Node(1/1,
#   «3.000:grace [4F 4G]»
#   «3.000:4.000 1/1♩ 4C»
# ): no need to extend node over beat
# [maelzel.scoring:node.py:460 - splitAtBeatBoundary] This Node (offset: 0, end: 4) does not contain offset 0
# [maelzel.scoring:renderlily.py:1074 - write] Rendering lilypond '/tmp/tmpk9paqhh_.ly' to '/tmp/tmpk9paqhh_.png'
# [maelzel.scoring:renderlily.py:1087 - write] Found crop file /tmp/tmpk9paqhh_.cropped.png, using that as output
# [maelzel.core:mobj.py:1726 - _renderObject] rendering parts with backend: musicxml
# [maelzel.scoring:quant.py:2196 - _mergeSiblings] Nodes can merge:
#     Node(1/1,
#   «0.000:1.000 1/1♩ 4C gliss»
# )
#     Node(1/1,
#   «1.000:2.000 1/1♩ 4D»
# )
# [maelzel.scoring:quant.py:2200 - _mergeSiblings] mergeSiblings: Node(1/1,
#   «0.000:1.000 1/1♩ 4C gliss»
#   «1.000:2.000 1/1♩ 4D»
# ) cannot merge with Node(1/1,
#   «2.000:3.000 1/1♩ [4E 4A] gliss»
# ): no need to extend node over beat
# [maelzel.scoring:quant.py:2200 - _mergeSiblings] mergeSiblings: Node(1/1,
#   «2.000:3.000 1/1♩ [4E 4A] gliss»
# ) cannot merge with Node(1/1,
#   «3.000:grace [4F 4G]»
#   «3.000:4.000 1/1♩ 4C»
# ): no need to extend node over beat
# [maelzel.scoring:node.py:460 - splitAtBeatBoundary] This Node (offset: 0, end: 4) does not contain offset 0
# [maelzel.scoring:rendermusicxml.py:1078 - callMuseScore] Rendering musicxml via MuseScore. Args: ['/home/em/.local/bin/musescore', '-o', '/tmp/tmpo5dpjcpj.png', '--force', '--image-resolution', '200', '--trim-image', '20', '/tmp/tmpx1057qbc.musicxml']

# %%
from maelzel.core import *
from maelzel.scoring.common import logger as sclogger

logger.setLevel('DEBUG')
sclogger.setLevel('DEBUG')



v = Voice([
    Rest("1/5"),
    Note("4C:2/3"),
    Note("4D", 0.5),
])
# v.show()

v.show(backend='musicxml')
# v.write('~/tmp/foo.musicxml')
# Out:
# [maelzel.core:mobj.py:1726 - _renderObject] rendering parts with backend: musicxml
# [maelzel.scoring:quant.py:2200 - _mergeSiblings] mergeSiblings: Node(1/1,
#   Node(5/4,
#     «0.000:0.200 1/5♩ 5/4 rest»
#     «0.200:0.500 3/10♩ 5/4 4C tiedNext»
#   )
#   «0.500:0.875 3/8♩ 4C tiedPrev»
#   «0.875:1.000 1/8♩ 4D tiedNext»
# ) cannot merge with Node(11/8,
#   «1.000:1.364 4/11♩ 11/8 4D tiedPrev»
#   «1.364:2.000 7/11♩ 11/8 rest»
# ): not same durRatio
# [maelzel.scoring:quant.py:2200 - _mergeSiblings] mergeSiblings: Node(11/8,
#   «1.000:1.364 4/11♩ 11/8 4D tiedPrev»
#   «1.364:2.000 7/11♩ 11/8 rest»
# ) cannot merge with Node(1/1,
#   «2.000:3.000 1/1♩ rest»
# ): not same durRatio
# [maelzel.scoring:quant.py:2196 - _mergeSiblings] Nodes can merge:
#     Node(1/1,
#   «2.000:3.000 1/1♩ rest»
# )
#     Node(1/1,
#   «3.000:4.000 1/1♩ rest»
# )
# [maelzel.scoring:node.py:460 - splitAtBeatBoundary] This Node (offset: 0, end: 4) does not contain offset 0
# [maelzel.scoring:rendermusicxml.py:715 - _renderNode] Starting tuplet (5, 4) at «0.000:0.200 1/5♩ 5/4 rest»
# [maelzel.scoring:rendermusicxml.py:715 - _renderNode] Starting tuplet (11, 8) at «1.000:1.364 4/11♩ 11/8 4D tiedPrev»
# [maelzel.scoring:rendermusicxml.py:1079 - callMuseScore] Rendering musicxml via MuseScore. Args: ['/home/em/.local/bin/musescore', '-o', '/tmp/tmpx712v2ju.png', '--force', '--image-resolution', '200', '--trim-image', '20', '/tmp/tmpn5ocl4qv.musicxml']

# %% [markdown]
# ## Articulations

# %%
from maelzel.core import *
from maelzel.scoring import rendermusicxml
from maelzel.core import symbols

v = Voice([
    Note("4C", 0.5).addSymbol(articulation='accent'),
    Note("4D", 0.5).addSymbol(articulation='staccato'),
    Note("4D", 5/8).addSymbol(symbols.Articulation('marcato', color='#ff0000')),
    Note("4D", 3/8).addSymbol('upbow'),
    Chord("4E,4G", 0.5).addSymbol('downbow'),
    Note("4F", 0.5).addSymbol(articulation='flageolet'),
    Chord("4C,4E,4G", 0.5).addSymbol(articulation='arpeggio').addSymbol(symbols.Breath())
])
v.show()
v.show(backend='musicxml')
v.write('~/tmp/articulations.musicxml')

# %% [markdown]
# ## Text

# %%
from maelzel.core import *
from maelzel.scoring import rendermusicxml
from maelzel.core import symbols

v = Voice([
    Note("4C", 0.5).addText('foo', placement='above'),
    Note("4D", 0.5).addText('enclosed', box='rectangle'),
    Note("4E", 0.5).addText('italic', italic=True),
    Note("4F", 0.5).addText('bold', weight='bold'),
    Note("4G", 0.5).addText('italic+bold', italic=True, weight='bold'),
    
    
    
    
])
v.show(backend='lilypond')
v.show(backend='musicxml')

# %% [markdown]
# ## Score Structure

# %%
from maelzel.core import *
from maelzel.scoring import rendermusicxml
from maelzel.core import symbols

struct = ScoreStruct(r'''
3/4, 72, label=my label, barline=double
7/8, barline=dashed
5/16, rehearsalmark=A
3/8
7/8
4/4
''')

v = Voice([
    "4C:0.5:offset=8",
    "4D:0.75"
])
  
score = Score(voices=[v], scorestruct=struct)
score.show(backend='lilypond')
score.show(backend='musicxml')

# %% [markdown]
# ## Noteheads

# %%
from maelzel.core import *

v = Voice([
    Note("4C:0.5").addSymbol(notehead='square'),
    Note("4D:0.5").addSymbol(notehead='harmonic'),
    Note("4Eb:0.5").addSymbol(symbols.Notehead('rhombus', color='red', size=2)).addSymbol(symbols.Accidental(parenthesis=True)),
    Note("4F:0.5").addSymbol(symbols.Harmonic('4th')),
    Note("4G:0.5").addSymbol(symbols.Notehead(hidden=True)),
    Note("4A:0.5").addSymbol(symbols.Notehead(parenthesis=True)),

])

v.show()
v.show(backend='musicxml')

# %% [markdown]
# ## Tremolos

# %%
from maelzel.core import *

v = Voice([
    Note("4C:0.5"),
    Note("4D:2").addSymbol(symbols.Tremolo(nummarks=2, relative=False)),
    Note("4A:0.5").addSymbol(symbols.Notehead(parenthesis=True)),

])

v.show()
v.show(backend='musicxml')
v.write('~/tmp/trem.musicxml')

# %% [markdown]
# ## Render via musicxml

# %%
from maelzel.core import *
from maelzel.scoring import rendermusicxml
from maelzel.core import symbols

v = Voice([
    Note("4C:0.5").addSymbol(notehead='square').addSymbol(symbols.Ornament('trill')),
    Note("4D:0.5").addSymbol(notehead='harmonic').addSymbol('>'),
    Note("4Eb:0.5").addSymbol(symbols.Notehead('rhombus', color='#FF0000', size=2)).addSymbol(symbols.Accidental(parenthesis=True, color='blue')),
    Note("4F:0.5").addSymbol(symbols.Harmonic('4th')),
    Note("4G:0.5").addSymbol(symbols.Notehead(hidden=True)).addText("hidden"),
    Note("4A:0.5").addSymbol(symbols.Notehead(parenthesis=True)).addSymbol(symbols.Ornament('prall')),
    Note("4B:0.5").addSymbol(symbols.Tremolo(nummarks=3))
])

v.show()
v.show(backend='musicxml')
v.write('~/tmp/test.musicxml')
