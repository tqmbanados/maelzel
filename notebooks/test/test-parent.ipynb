# %%
from maelzel.core import *
from maelzel.scoring import logger as sclogger

cfg = getConfig()
cfg['quant.debug'] = False
sclogger.setLevel('DEBUG')

# %%
from maelzel.core import *
chain = Chain([
    "4C,4E:1:offset=0.5",
    "4D:1:mf:label=bar:gliss=4g",
     Chain(["4F:1/3", "4F:2/3"])
])

for ev, offset in chain.eventsWithOffset():
    print(ev, ev.offset, offset)

chain
# Out:
# ‹4C 4E 1♩ offset=0.5› 1/2 1/2
# 4D:1♩:gliss=4G None 3/2
# 4F:0.333♩ None 5/2
# 4F:0.667♩ None 17/6
# Chain([‹4C 4E 1♩ offset=0.5›, 4D:1♩:gliss=4G, Chain([4F:0.333♩, 4F:0.667♩])])

# %%
n = Note("4D", dur=1, offset=0.5, gliss="4G")
n.show()
# n.quantizedScore().dump()

# %%
n = chain[1]
n.show()
n.dump()
# n.play(start=n.absoluteOffset())
# Out:
# 4D:1♩:gliss=4G

# %%
chain.fillGaps()
chain.dump()
chain.removeRedundantOffsets()
# chain.stack()
chain.dump()
chain
# Out:
# <code><span style="font-size: 85%"><b>Chain</b> - beat: 0, offset: None, dur: 3.5</span></code><br><code><span style="color:#BBBBBB;font-size:85%">  location  beat   offset      dur         name  gliss dyn  playargs            info                </span></code><br><code><span style="color:#9090FF;font-size:85%">  0:0       0      (0)         0.5         Rest  F          None                -</span></code><br><code><span style="color:#9090FF;font-size:85%">  0:0.5     0.5    0.5         1           4C,4E F          None                -</span></code><br><code><span style="color:#9090FF;font-size:85%">  0:1.5     1.5    (3/2)       1           4D    67.0  mf   None                label: bar</span></code><br><code><span style="font-size: 85%">  <b>Chain</b> - beat: 5/2, offset: None, dur: 1</span></code><br><code><span style="color:#BBBBBB;font-size:85%">    location  beat   offset      dur         name      gliss dyn  playargs            info                </span></code><br><code><span style="color:#9090FF;font-size:85%">    0:2.5     2.5    (0)         0.333       4F        F          None                -</span></code><br><code><span style="color:#9090FF;font-size:85%">    0:2.833   2.833  (1/3)       0.667       4F        F          None                -</span></code>
# <code><span style="font-size: 85%"><b>Chain</b> - beat: 0, offset: None, dur: 3.5</span></code><br><code><span style="color:#BBBBBB;font-size:85%">  location  beat   offset      dur         name  gliss dyn  playargs            info                </span></code><br><code><span style="color:#9090FF;font-size:85%">  0:0       0      (0)         0.5         Rest  F          None                -</span></code><br><code><span style="color:#9090FF;font-size:85%">  0:0.5     0.5    (1/2)       1           4C,4E F          None                -</span></code><br><code><span style="color:#9090FF;font-size:85%">  0:1.5     1.5    (3/2)       1           4D    67.0  mf   None                label: bar</span></code><br><code><span style="font-size: 85%">  <b>Chain</b> - beat: 5/2, offset: None, dur: 1</span></code><br><code><span style="color:#BBBBBB;font-size:85%">    location  beat   offset      dur         name      gliss dyn  playargs            info                </span></code><br><code><span style="color:#9090FF;font-size:85%">    0:2.5     2.5    (0)         0.333       4F        F          None                -</span></code><br><code><span style="color:#9090FF;font-size:85%">    0:2.833   2.833  (1/3)       0.667       4F        F          None                -</span></code>
# Chain([Rest:0.5♩, ‹4C 4E 1♩›, 4D:1♩:gliss=4G, Chain([4F:0.333♩, 4F:0.667♩])])

# %%
flat = chain.flat()
flat.removeRedundantOffsets()
flat.dump()
flat
# Out:
# <code><span style="font-size: 85%"><b>Chain</b> - beat: 0, offset: None, dur: 3.5</span></code><br><code><span style="color:#BBBBBB;font-size:85%">  location  beat   offset      dur         name  gliss dyn  playargs            info                </span></code><br><code><span style="color:#9090FF;font-size:85%">  0:0       0      (0)         0.5         Rest  F          None                -</span></code><br><code><span style="color:#9090FF;font-size:85%">  0:0.5     0.5    (1/2)       1           4C,4E F          None                -</span></code><br><code><span style="color:#9090FF;font-size:85%">  0:1.5     1.5    (3/2)       1           4D    67.0  mf   None                label: bar</span></code><br><code><span style="color:#9090FF;font-size:85%">  0:2.5     2.5    (5/2)       0.333       4F    F          None                -</span></code><br><code><span style="color:#9090FF;font-size:85%">  0:2.833   2.833  (17/6)      0.667       4F    F          None                -</span></code>
# Chain([Rest:0.5♩, ‹4C 4E 1♩›, 4D:1♩:gliss=4G, 4F:0.333♩, 4F:0.667♩])

# %%
ch = Chain([
    '4C:0.5', 
    '4D:0.5:label=foo', 
    Chain(['4E:1:offset=0.5'])
], offset=0.5)
ch.show()

# %%
n = ch[0]
n
# Out:
# 4C:0.5♩

# %%
struct = ScoreStruct(r'''
2/4, 60
2/4, 120
3/4, 72
''')

# %%
notes = [Note(m, 0.25) for m in range(60, 84)]
sc = Chain(notes, offset=1)
notes2 = [Note(m, 0.5) for m in range(60, 72)]
sc2 = Chain(notes2)
sc.append(sc2)
# sc.stack()
with struct:
    # sc.play()
    sc.asVoice().show()

# %%
sc.flat().show()
with struct:
    sc.flat().show()

# %%
sco = Score(scorestruct=struct)

notes = [Note(m, 0.25) for m in range(60, 84)]
scale = Chain(notes)
sco.append(scale.asVoice())
sco.append(scale.asVoice().timeShift(0.25))
sco.append(scale.asVoice().timeShift(1/2))
sco.append(scale.asVoice().timeShift(3/4))
sco
# Out:
# Score(4 voices)

# %%
sco[0][0].setPlay(instr='saw', gain=0.1, position=0)
sco[0][3].setPlay(instr='saw', gain=0.1, position=1)
sco.setPlay(position=0.5)
# Out:
# Score(4 voices)

# %%
sco[0][0].parent
# Out:
# Voice([4C:0.25♩, 4C#:0.25♩, 4D:0.25♩, 4D#:0.25♩, 4E:0.25♩, 4F:0.25♩, 4F#:0.25♩, 4G:0.25♩, 4G#:0.25♩, 4A:0.25♩, …], offset=0)

# %%
sco.play(gain=0.2, sustain=0.1)
# Out:
# --Csound version 6.19 (double samples) Jan 13 2024
# [commit: c53556fbbb69d14554a4a4bd91efa441a1701d70]
# libsndfile-1.2.0
# sr = 44100.0, kr = 689.062, ksmps = 64
# 0dBFS level = 1.0, A4 tuning = 442.0
# audio buffered in 256 sample-frame blocks
# reading 2048-byte blks of shorts from adc:Built-in Audio Pro: (RAW)
# writing 512 sample blks of 64-bit floats to dac:Built-in Audio Pro:
# SECTION 1:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=96)
#     Synth(𝍪 preset:saw=501.0002 start=1.185 dur=0.350 p4=0 kpos=0.1 kgain=19 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 kcutoffratio=3 kfilterq=0 p19=60 p20=0.515178 p21=0.25 p22=60 …)
#     Synth(𝍪 preset:sin=502.0002 start=1.435 dur=0.350 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=61 p18=0.515178 p19=0.25 p20=61 …)
#     Synth(𝍪 preset:sin=502.0003 start=1.685 dur=0.350 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=62 p18=0.515178 p19=0.25 p20=62 …)
#     Synth(𝍪 preset:saw=501.0003 start=1.935 dur=0.350 p4=1 kpos=0.1 kgain=19 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 kcutoffratio=3 kfilterq=0 p19=63 p20=0.515178 p21=0.25 p22=63 …)
#     Synth(𝍪 preset:sin=502.0004 start=2.185 dur=0.350 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=64 p18=0.515178 p19=0.25 p20=64 …)
#     Synth(𝍪 preset:sin=502.0005 start=2.435 dur=0.350 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=65 p18=0.515178 p19=0.25 p20=65 …)
#     Synth(𝍪 preset:sin=502.0006 start=2.685 dur=0.350 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=66 p18=0.515178 p19=0.25 p20=66 …)
#     Synth(𝍪 preset:sin=502.0007 start=2.935 dur=0.350 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=67 p18=0.515178 p19=0.25 p20=67 …)
#     Synth(𝍪 preset:sin=502.0008 start=3.185 dur=0.225 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=68 p18=0.515178 p19=0.125 p20=68 …)
#     Synth(𝍪 preset:sin=502.0009 start=3.310 dur=0.225 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=69 p18=0.515178 p19=0.125 p20=69 …)
#     Synth(𝍪 preset:sin=502.001 start=3.435 dur=0.225 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=70 p18=0.515178 p19=0.125 p20=70 …)
#     Synth(𝍪 preset:sin=502.0011 start=3.560 dur=0.225 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=71 p18=0.515178 p19=0.125 p20=71 …)
#     Synth(𝍪 preset:sin=502.0012 start=3.685 dur=0.225 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=72 p18=0.515178 p19=0.125 p20=72 …)
#     Synth(𝍪 preset:sin=502.0013 start=3.810 dur=0.225 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=73 p18=0.515178 p19=0.125 p20=73 …)
#     Synth(𝍪 preset:sin=502.0014 start=3.935 dur=0.225 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=74 p18=0.515178 p19=0.125 p20=74 …)
#     Synth(𝍪 preset:sin=502.0015 start=4.060 dur=0.225 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=75 p18=0.515178 p19=0.125 p20=75 …)
#     Synth(𝍪 preset:sin=502.0016 start=4.185 dur=0.308 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=76 p18=0.515178 p19=0.208333 p20=76 …)
#     Synth(𝍪 preset:sin=502.0017 start=4.393 dur=0.308 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=77 p18=0.515178 p19=0.208333 p20=77 …)
#     Synth(𝍪 preset:sin=502.0018 start=4.602 dur=0.308 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=78 p18=0.515178 p19=0.208333 p20=78 …)
#     Synth(𝍪 preset:sin=502.0019 start=4.810 dur=0.308 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=79 p18=0.515178 p19=0.208333 p20=79 …)
#     Synth(𝍪 preset:sin=502.002 start=5.018 dur=0.308 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=80 p18=0.515178 p19=0.208333 p20=80 …)
#     Synth(𝍪 preset:sin=502.0021 start=5.227 dur=0.308 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=81 p18=0.515178 p19=0.208333 p20=81 …)
#     Synth(𝍪 preset:sin=502.0022 start=5.435 dur=0.308 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=82 p18=0.515178 p19=0.208333 p20=82 …)
#     Synth(𝍪 preset:sin=502.0023 start=5.643 dur=0.308 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=83 p18=0.515178 p19=0.208333 p20=83 …)
#     Synth(𝍪 preset:sin=502.0024 start=1.435 dur=0.350 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=60 p18=0.515178 p19=0.25 p20=60 …)
#     Synth(𝍪 preset:sin=502.0025 start=1.685 dur=0.350 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=61 p18=0.515178 p19=0.25 p20=61 …)
#     Synth(𝍪 preset:sin=502.0026 start=1.935 dur=0.350 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=62 p18=0.515178 p19=0.25 p20=62 …)
#     Synth(𝍪 preset:sin=502.0027 start=2.185 dur=0.350 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=63 p18=0.515178 p19=0.25 p20=63 …)
#     Synth(𝍪 preset:sin=502.0028 start=2.435 dur=0.350 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=64 p18=0.515178 p19=0.25 p20=64 …)
#     Synth(𝍪 preset:sin=502.0029 start=2.685 dur=0.350 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=65 p18=0.515178 p19=0.25 p20=65 …)
#     Synth(𝍪 preset:sin=502.003 start=2.935 dur=0.350 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=66 p18=0.515178 p19=0.25 p20=66 …)
#     Synth(𝍪 preset:sin=502.0031 start=3.185 dur=0.225 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=67 p18=0.515178 p19=0.125 p20=67 …)
#     Synth(𝍪 preset:sin=502.0032 start=3.310 dur=0.225 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=68 p18=0.515178 p19=0.125 p20=68 …)
#     Synth(𝍪 preset:sin=502.0033 start=3.435 dur=0.225 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=69 p18=0.515178 p19=0.125 p20=69 …)
#     Synth(𝍪 preset:sin=502.0034 start=3.560 dur=0.225 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=70 p18=0.515178 p19=0.125 p20=70 …)
#     Synth(𝍪 preset:sin=502.0035 start=3.685 dur=0.225 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=71 p18=0.515178 p19=0.125 p20=71 …)
#     Synth(𝍪 preset:sin=502.0036 start=3.810 dur=0.225 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=72 p18=0.515178 p19=0.125 p20=72 …)
#     Synth(𝍪 preset:sin=502.0037 start=3.935 dur=0.225 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=73 p18=0.515178 p19=0.125 p20=73 …)
#     Synth(𝍪 preset:sin=502.0038 start=4.060 dur=0.225 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=74 p18=0.515178 p19=0.125 p20=74 …)
#     Synth(𝍪 preset:sin=502.0039 start=4.185 dur=0.308 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=75 p18=0.515178 p19=0.208333 p20=75 …)
#     Synth(𝍪 preset:sin=502.004 start=4.393 dur=0.308 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=76 p18=0.515178 p19=0.208333 p20=76 …)
#     Synth(𝍪 preset:sin=502.0041 start=4.602 dur=0.308 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=77 p18=0.515178 p19=0.208333 p20=77 …)
#     Synth(𝍪 preset:sin=502.0042 start=4.810 dur=0.308 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=78 p18=0.515178 p19=0.208333 p20=78 …)
#     Synth(𝍪 preset:sin=502.0043 start=5.018 dur=0.308 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=79 p18=0.515178 p19=0.208333 p20=79 …)
#     Synth(𝍪 preset:sin=502.0044 start=5.227 dur=0.308 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=80 p18=0.515178 p19=0.208333 p20=80 …)
#     Synth(𝍪 preset:sin=502.0045 start=5.435 dur=0.308 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=81 p18=0.515178 p19=0.208333 p20=81 …)
#     Synth(𝍪 preset:sin=502.0046 start=5.643 dur=0.308 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=82 p18=0.515178 p19=0.208333 p20=82 …)
#     Synth(𝍪 preset:sin=502.0047 start=5.852 dur=0.308 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=83 p18=0.515178 p19=0.208333 p20=83 …)
#     Synth(𝍪 preset:sin=502.0048 start=1.685 dur=0.350 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=60 p18=0.515178 p19=0.25 p20=60 …)
#     Synth(𝍪 preset:sin=502.0049 start=1.935 dur=0.350 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=61 p18=0.515178 p19=0.25 p20=61 …)
#     Synth(𝍪 preset:sin=502.005 start=2.185 dur=0.350 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=62 p18=0.515178 p19=0.25 p20=62 …)
#     Synth(𝍪 preset:sin=502.0051 start=2.435 dur=0.350 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=63 p18=0.515178 p19=0.25 p20=63 …)
#     Synth(𝍪 preset:sin=502.0052 start=2.685 dur=0.350 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=64 p18=0.515178 p19=0.25 p20=64 …)
#     Synth(𝍪 preset:sin=502.0053 start=2.935 dur=0.350 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=65 p18=0.515178 p19=0.25 p20=65 …)
#     Synth(𝍪 preset:sin=502.0054 start=3.185 dur=0.225 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=66 p18=0.515178 p19=0.125 p20=66 …)
#     Synth(𝍪 preset:sin=502.0055 start=3.310 dur=0.225 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=67 p18=0.515178 p19=0.125 p20=67 …)
#     Synth(𝍪 preset:sin=502.0056 start=3.435 dur=0.225 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=68 p18=0.515178 p19=0.125 p20=68 …)
#     Synth(𝍪 preset:sin=502.0057 start=3.560 dur=0.225 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=69 p18=0.515178 p19=0.125 p20=69 …)
#     Synth(𝍪 preset:sin=502.0058 start=3.685 dur=0.225 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=70 p18=0.515178 p19=0.125 p20=70 …)
#     Synth(𝍪 preset:sin=502.0059 start=3.810 dur=0.225 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=71 p18=0.515178 p19=0.125 p20=71 …)
#     Synth(𝍪 preset:sin=502.006 start=3.935 dur=0.225 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=72 p18=0.515178 p19=0.125 p20=72 …)
#     Synth(𝍪 preset:sin=502.0061 start=4.060 dur=0.225 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=73 p18=0.515178 p19=0.125 p20=73 …)
#     Synth(𝍪 preset:sin=502.0062 start=4.185 dur=0.308 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=74 p18=0.515178 p19=0.208333 p20=74 …)
#     Synth(𝍪 preset:sin=502.0063 start=4.393 dur=0.308 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=75 p18=0.515178 p19=0.208333 p20=75 …)
#     Synth(𝍪 preset:sin=502.0064 start=4.602 dur=0.308 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=76 p18=0.515178 p19=0.208333 p20=76 …)
#     Synth(𝍪 preset:sin=502.0065 start=4.810 dur=0.308 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=77 p18=0.515178 p19=0.208333 p20=77 …)
#     Synth(𝍪 preset:sin=502.0066 start=5.018 dur=0.308 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=78 p18=0.515178 p19=0.208333 p20=78 …)
#     Synth(𝍪 preset:sin=502.0067 start=5.227 dur=0.308 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=79 p18=0.515178 p19=0.208333 p20=79 …)
#     Synth(𝍪 preset:sin=502.0068 start=5.435 dur=0.308 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=80 p18=0.515178 p19=0.208333 p20=80 …)
#     Synth(𝍪 preset:sin=502.0069 start=5.643 dur=0.308 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=81 p18=0.515178 p19=0.208333 p20=81 …)
#     Synth(𝍪 preset:sin=502.007 start=5.852 dur=0.308 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=82 p18=0.515178 p19=0.208333 p20=82 …)
#     Synth(𝍪 preset:sin=502.0071 start=6.060 dur=0.308 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=83 p18=0.515178 p19=0.208333 p20=83 …)
#     Synth(𝍪 preset:sin=502.0072 start=1.935 dur=0.350 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=60 p18=0.515178 p19=0.25 p20=60 …)
#     Synth(𝍪 preset:sin=502.0073 start=2.185 dur=0.350 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=61 p18=0.515178 p19=0.25 p20=61 …)
#     Synth(𝍪 preset:sin=502.0074 start=2.435 dur=0.350 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=62 p18=0.515178 p19=0.25 p20=62 …)
#     Synth(𝍪 preset:sin=502.0075 start=2.685 dur=0.350 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=63 p18=0.515178 p19=0.25 p20=63 …)
#     Synth(𝍪 preset:sin=502.0076 start=2.935 dur=0.350 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=64 p18=0.515178 p19=0.25 p20=64 …)
#     Synth(𝍪 preset:sin=502.0077 start=3.185 dur=0.225 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=65 p18=0.515178 p19=0.125 p20=65 …)
#     Synth(𝍪 preset:sin=502.0078 start=3.310 dur=0.225 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=66 p18=0.515178 p19=0.125 p20=66 …)
#     Synth(𝍪 preset:sin=502.0079 start=3.435 dur=0.225 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=67 p18=0.515178 p19=0.125 p20=67 …)
#     Synth(𝍪 preset:sin=502.008 start=3.560 dur=0.225 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=68 p18=0.515178 p19=0.125 p20=68 …)
#     Synth(𝍪 preset:sin=502.0081 start=3.685 dur=0.225 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=69 p18=0.515178 p19=0.125 p20=69 …)
#     Synth(𝍪 preset:sin=502.0082 start=3.810 dur=0.225 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=70 p18=0.515178 p19=0.125 p20=70 …)
#     Synth(𝍪 preset:sin=502.0083 start=3.935 dur=0.225 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=71 p18=0.515178 p19=0.125 p20=71 …)
#     Synth(𝍪 preset:sin=502.0084 start=4.060 dur=0.225 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=72 p18=0.515178 p19=0.125 p20=72 …)
#     Synth(𝍪 preset:sin=502.0085 start=4.185 dur=0.308 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=73 p18=0.515178 p19=0.208333 p20=73 …)
#     Synth(𝍪 preset:sin=502.0086 start=4.393 dur=0.308 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=74 p18=0.515178 p19=0.208333 p20=74 …)
#     Synth(𝍪 preset:sin=502.0087 start=4.602 dur=0.308 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=75 p18=0.515178 p19=0.208333 p20=75 …)
#     Synth(𝍪 preset:sin=502.0088 start=4.810 dur=0.308 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=76 p18=0.515178 p19=0.208333 p20=76 …)
#     Synth(𝍪 preset:sin=502.0089 start=5.018 dur=0.308 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=77 p18=0.515178 p19=0.208333 p20=77 …)
#     Synth(𝍪 preset:sin=502.009 start=5.227 dur=0.308 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=78 p18=0.515178 p19=0.208333 p20=78 …)
#     Synth(𝍪 preset:sin=502.0091 start=5.435 dur=0.308 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=79 p18=0.515178 p19=0.208333 p20=79 …)
#     Synth(𝍪 preset:sin=502.0092 start=5.643 dur=0.308 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=80 p18=0.515178 p19=0.208333 p20=80 …)
#     Synth(𝍪 preset:sin=502.0093 start=5.852 dur=0.308 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=81 p18=0.515178 p19=0.208333 p20=81 …)
#     Synth(𝍪 preset:sin=502.0094 start=6.060 dur=0.308 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=82 p18=0.515178 p19=0.208333 p20=82 …)
#     Synth(𝍪 preset:sin=502.0095 start=6.268 dur=0.308 p4=0.5 kpos=0.2 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=83 p18=0.515178 p19=0.208333 p20=83 …)
