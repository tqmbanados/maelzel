# %%
from maelzel.core import *
from maelzel import scoring
import logging
logger = logging.getLogger("maelzel")
logger.setLevel("DEBUG")
cfg = getConfig()

# %%
cfg['.quant.debug'] = True
cfg['.quant.debugShowNumRows']
# Out:
# 50

# %%
left = Voice([
    "4C:1/2",
    "5E-33:1/4",
    "4G+13:1/4+1/24"
])
left
# Out:
# [maelzel.scoring:quant.py:1334:quantizeMeasure:DEBUG] Measure 4/4 is not filled (events=[«4C 0:0.5 1/2♩», «5E-33 0.5:0.75 1/4♩», «4G+13 0.75:1.042 7/24♩»]). Filling gaps with silences
# [maelzel.scoring:quant.py:917:quantizeBeatBinary:DEBUG] Skipping (7,), gridError=0.19229126414207695 * 1.0 > minError=0.15530869060244548
# [maelzel.scoring:quant.py:908:quantizeBeatBinary:DEBUG] Skipping (9,), divPenalty=0.04 * 0.1 > minError=0.001
# [maelzel.scoring:quant.py:908:quantizeBeatBinary:DEBUG] Skipping (11,), divPenalty=0.1 * 0.1 > minError=0.001
# [maelzel.scoring:quant.py:917:quantizeBeatBinary:DEBUG] Skipping (1, 3), gridError=0.1553054711742189 * 1.0 > minError=0.001
# [maelzel.scoring:quant.py:908:quantizeBeatBinary:DEBUG] Skipping (1, 5), divPenalty=0.02 * 0.1 > minError=0.001
# Beat: 0 - 1 (dur: 1)
# Best 4 divisions: (quantized in 6.4ms)
# <table>
# <thead>
# <tr><th style="text-align: right;">  error</th><th>div   </th><th>snapped                                                         </th><th>slots    </th><th>info                                                                                                                                                                          </th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;"> 0.0000</td><td>(1, 2)</td><td>[«4C 0:0.5 1/2♩», «5E-33 0.5:0.75 1/4♩», «4G+13~ 0.75:1 1/4♩»]  </td><td>[0, 1, 2]</td><td>gridError=0, rhythmComplexity=0 (numNotesAcrossSubdivs=0, numTies=0), divPenalty=0 (0, divPenalty=0, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)               </td></tr>
# <tr><td style="text-align: right;"> 0.0010</td><td>(4,)  </td><td>[«4C 0:0.5 1/2♩», «5E-33 0.5:0.75 1/4♩», «4G+13~ 0.75:1 1/4♩»]  </td><td>[0, 2, 3]</td><td>gridError=0, rhythmComplexity=0 (numNotesAcrossSubdivs=0, numTies=0), divPenalty=0.01 (0.0001, divPenalty=0.01, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)    </td></tr>
# <tr><td style="text-align: right;"> 0.1553</td><td>(6,)  </td><td>[«4C 0:0.5 1/2♩», «5E-33 0.5:0.667 1/6♩», «4G+13~ 0.667:1 1/3♩»]</td><td>[0, 3, 4]</td><td>gridError=0.155, rhythmComplexity=0 (numNotesAcrossSubdivs=0, numTies=0), divPenalty=0.01 (0.0001, divPenalty=0.01, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)</td></tr>
# <tr><td style="text-align: right;"> 0.2560</td><td>(5,)  </td><td>[«4C 0:0.4 2/5♩», «5E-33 0.4:0.8 2/5♩», «4G+13~ 0.8:1 1/5♩»]    </td><td>[0, 2, 4]</td><td>gridError=0.256, rhythmComplexity=0 (numNotesAcrossSubdivs=0, numTies=0), divPenalty=0.02 (0.0002, divPenalty=0.02, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)</td></tr>
# </tbody>
# </table>
# [maelzel.scoring:quant.py:934:quantizeBeatBinary:DEBUG] Skipping (7,), totalError=0.05259406681375715 > minError=0.052556025953357156
# [maelzel.scoring:quant.py:934:quantizeBeatBinary:DEBUG] Skipping (11,), totalError=0.05533656895769696 > minError=0.052556025953357156
# [maelzel.scoring:quant.py:917:quantizeBeatBinary:DEBUG] Skipping (3,), gridError=0.052556025953357156 * 1.0 > minError=0.015154803118842179
# [maelzel.scoring:quant.py:917:quantizeBeatBinary:DEBUG] Skipping (5, 1, 1), gridError=0.044386863687026205 * 1.0 > minError=0.015154803118842179
# [maelzel.scoring:quant.py:917:quantizeBeatBinary:DEBUG] Skipping (6, 1, 1), gridError=0.026932261966345888 * 1.0 > minError=0.015154803118842179
# [maelzel.scoring:quant.py:934:quantizeBeatBinary:DEBUG] Skipping (7, 1, 1), totalError=0.015322694114466394 > minError=0.015154803118842179
# [maelzel.scoring:quant.py:917:quantizeBeatBinary:DEBUG] Skipping (9, 1, 1), gridError=0.01058570443016352 * 1.0 > minError=0.00714142842854285
# [maelzel.scoring:quant.py:917:quantizeBeatBinary:DEBUG] Skipping (4,), gridError=0.052556025953357156 * 1.0 > minError=0.00714142842854285
# [maelzel.scoring:quant.py:917:quantizeBeatBinary:DEBUG] Skipping (5, 1, 1, 1), gridError=0.017446221938578896 * 1.0 > minError=0.00714142842854285
# [maelzel.scoring:quant.py:934:quantizeBeatBinary:DEBUG] Skipping (6, 1, 1, 1), totalError=0.007348469228349534 > minError=0.00714142842854285
# [maelzel.scoring:quant.py:917:quantizeBeatBinary:DEBUG] Skipping (7, 1, 1, 1), gridError=0.013106675967822777 * 1.0 > minError=0.00714142842854285
# [maelzel.scoring:quant.py:917:quantizeBeatBinary:DEBUG] Skipping (3, 1, 1, 1, 1), gridError=0.044386863687026205 * 1.0 > minError=0.00714142842854285
# [maelzel.scoring:quant.py:908:quantizeBeatBinary:DEBUG] Skipping (5, 1, 1, 1, 1), divPenalty=0.09000000000000001 * 0.1 > minError=0.00714142842854285
# [maelzel.scoring:quant.py:917:quantizeBeatBinary:DEBUG] Skipping (3, 1, 1, 1, 1, 1), gridError=0.026932261966345888 * 1.0 > minError=0.00714142842854285
# Beat: 1 - 2 (dur: 1)
# Best 8 divisions: (quantized in 15.4ms)
# <table>
# <thead>
# <tr><th style="text-align: right;">  error</th><th>div      </th><th>snapped                                                                                                      </th><th>slots  </th><th>info                                                                                                                                                                               </th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;"> 0.0071</td><td>(8, 1, 1)</td><td>[«~4G+13 0:0.042 1/24♩», «rest 0.042:1 23/24♩»]                                                              </td><td>[0, 1] </td><td>gridError=0, rhythmComplexity=0.224 (numNotesAcrossSubdivs=1, numTies=0), divPenalty=0.01 (0.0001, divPenalty=0.01, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)     </td></tr>
# <tr><td style="text-align: right;"> 0.0152</td><td>(11, 1)  </td><td>[«~4G+13 0:0.045 1/22♩», «rest 0.045:1 21/22♩»]                                                              </td><td>[0, 1] </td><td>gridError=0.00893, rhythmComplexity=0.224 (numNotesAcrossSubdivs=1, numTies=0), divPenalty=0.1 (0.001, divPenalty=0.1, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)  </td></tr>
# <tr><td style="text-align: right;"> 0.0281</td><td>(9, 1)   </td><td>[«~4G+13 0:0.056 1/18♩», «rest 0.056:1 17/18♩»]                                                              </td><td>[0, 1] </td><td>gridError=0.0269, rhythmComplexity=0.224 (numNotesAcrossSubdivs=1, numTies=0), divPenalty=0.04 (0.0004, divPenalty=0.04, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)</td></tr>
# <tr><td style="text-align: right;"> 0.0387</td><td>(8, 1)   </td><td>[«~4G+13 0:0.062 1/16♩», «rest 0.062:1 15/16♩»]                                                              </td><td>[0, 1] </td><td>gridError=0.038, rhythmComplexity=0.224 (numNotesAcrossSubdivs=1, numTies=0), divPenalty=0.01 (0.0001, divPenalty=0.01, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0) </td></tr>
# <tr><td style="text-align: right;"> 0.0520</td><td>(7, 1)   </td><td>[«~4G+13 0:0.071 1/14♩», «rest 0.071:1 13/14♩»]                                                              </td><td>[0, 1] </td><td>gridError=0.0515, rhythmComplexity=0.224 (numNotesAcrossSubdivs=1, numTies=0), divPenalty=0.02 (0.0002, divPenalty=0.02, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)</td></tr>
# <tr><td style="text-align: right;"> 0.0526</td><td>(1,)     </td><td>[«~4G+13 0:grace properties={&#x27;.snappedGracenote&#x27;: True, &#x27;originalDuration&#x27;: Fraction(1, 24)}», «rest 0:1 1♩»]</td><td>[0, 0] </td><td>gridError=0.0526, rhythmComplexity=0 (numNotesAcrossSubdivs=0, numTies=0), divPenalty=0 (0, divPenalty=0, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)               </td></tr>
# <tr><td style="text-align: right;"> 0.0526</td><td>(2,)     </td><td>[«~4G+13 0:grace properties={&#x27;.snappedGracenote&#x27;: True, &#x27;originalDuration&#x27;: Fraction(1, 24)}», «rest 0:1 1♩»]</td><td>[0, 0] </td><td>gridError=0.0526, rhythmComplexity=0 (numNotesAcrossSubdivs=0, numTies=0), divPenalty=0 (0, divPenalty=0, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)               </td></tr>
# <tr><td style="text-align: right;"> 0.0545</td><td>(5,)     </td><td>[«~4G+13 0:grace properties={&#x27;.snappedGracenote&#x27;: True, &#x27;originalDuration&#x27;: Fraction(1, 24)}», «rest 0:1 1♩»]</td><td>[0, 0] </td><td>gridError=0.0526, rhythmComplexity=0.447 (numNotesAcrossSubdivs=0, numTies=1), divPenalty=0.02 (0.0002, divPenalty=0.02, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)</td></tr>
# </tbody>
# </table>
# [maelzel.scoring:quant.py:1605:_mergeSiblings:DEBUG] Nodes can merge:
#     Node(1/1,
#   «rest 2:3 1♩»
# )
#     Node(1/1,
#   «rest 3:4 1♩»
# )
# [maelzel.scoring:quant.py:1608:_mergeSiblings:DEBUG] ---- Merged node:
#     Node(1/1,
#   «rest 2:4 2♩»
# )
# [maelzel.scoring:node.py:647:_splitUnnecessaryNodes:DEBUG] Did not split node Node(1/1,
#   Node(1/1,
#     «4C 0:0.5 1/2♩»
#     «5E-33 0.5:0.75 1/4♩»
#     «4G+13~ 0.75:1 1/4♩»
#   )
#   Node(3/2,
#     Node(1/1,
#       «~4G+13 1:1.042 1/24♩ 3/2»
#       «rest 1.042:1.333 7/24♩ 3/2»
#     )
#     «rest 1.333:2 2/3♩ 3/2»
#   )
#   Node(1/1,
#     «rest 2:4 2♩»
#   )
# ) at 3
# [maelzel.scoring:renderlily.py:1116:write:DEBUG] Rendering lilypond '/tmp/tmpibohxxcq.ly' to '/tmp/tmpibohxxcq.png'
# DEBUG:maelzel:Rendering lilypond '/tmp/tmpibohxxcq.ly' to '/tmp/tmpibohxxcq.png'
# DEBUG:maelzel:Calling lilypond subprocess: ['/usr/bin/lilypond', '--png', '-o', '/tmp/tmpibohxxcq', '-dresolution=200', '/tmp/tmpibohxxcq.ly']
# DEBUG:maelzel:lilypond executed OK
# DEBUG:maelzel:stderr:
# DEBUG:maelzel: Changing working directory to: `/tmp'
#  Processing `/tmp/tmpibohxxcq.ly'
#  Parsing...
#  Interpreting music...
#  Preprocessing graphical objects...
#  Finding the ideal number of pages...
#  Fitting music on 1 page...
#  Drawing systems...
#  Converting to PNG...
#  Layout output to `tmpibohxxcq.cropped.eps'...
#  Converting to PNG...
#  Success: compilation successfully completed
#
# [maelzel.scoring:renderlily.py:1129:write:DEBUG] Found crop file /tmp/tmpibohxxcq.cropped.png, using that as output
# Voice([4C:0.5♩, 5E-33:0.25♩, 4G+13:0.292♩], offset=0)

# %%
left = Voice([
    "4C:1/3",
    "5E-33:1/3",
    "4G+13:1/3+1/24"
])
left
# Out:
# [maelzel.scoring:quant.py:1334:quantizeMeasure:DEBUG] Measure 4/4 is not filled (events=[«4C 0:0.333 1/3♩», «5E-33 0.333:0.667 1/3♩», «4G+13 0.667:1.042 3/8♩»]). Filling gaps with silences
# Beat: 0 - 1 (dur: 1)
# Best 2 divisions: (quantized in 590.6µs)
# <table>
# <thead>
# <tr><th style="text-align: right;">  error</th><th>div  </th><th>snapped                                                             </th><th>slots    </th><th>info                                                                                                                                                                          </th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;"> 0.0000</td><td>(3,) </td><td>[«4C 0:0.333 1/3♩», «5E-33 0.333:0.667 1/3♩», «4G+13~ 0.667:1 1/3♩»]</td><td>[0, 1, 2]</td><td>gridError=0, rhythmComplexity=0 (numNotesAcrossSubdivs=0, numTies=0), divPenalty=0 (0, divPenalty=0, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)               </td></tr>
# <tr><td style="text-align: right;"> 0.2316</td><td>(5,) </td><td>[«4C 0:0.4 2/5♩», «5E-33 0.4:0.6 1/5♩», «4G+13~ 0.6:1 2/5♩»]        </td><td>[0, 2, 3]</td><td>gridError=0.232, rhythmComplexity=0 (numNotesAcrossSubdivs=0, numTies=0), divPenalty=0.02 (0.0002, divPenalty=0.02, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)</td></tr>
# </tbody>
# </table>
# [maelzel.scoring:quant.py:934:quantizeBeatBinary:DEBUG] Skipping (7,), totalError=0.05259406681375715 > minError=0.052556025953357156
# [maelzel.scoring:quant.py:934:quantizeBeatBinary:DEBUG] Skipping (11,), totalError=0.05533656895769696 > minError=0.052556025953357156
# [maelzel.scoring:quant.py:917:quantizeBeatBinary:DEBUG] Skipping (3,), gridError=0.052556025953357156 * 1.0 > minError=0.015154803118842179
# [maelzel.scoring:quant.py:917:quantizeBeatBinary:DEBUG] Skipping (5, 1, 1), gridError=0.044386863687026205 * 1.0 > minError=0.015154803118842179
# [maelzel.scoring:quant.py:917:quantizeBeatBinary:DEBUG] Skipping (6, 1, 1), gridError=0.026932261966345888 * 1.0 > minError=0.015154803118842179
# [maelzel.scoring:quant.py:934:quantizeBeatBinary:DEBUG] Skipping (7, 1, 1), totalError=0.015322694114466394 > minError=0.015154803118842179
# [maelzel.scoring:quant.py:917:quantizeBeatBinary:DEBUG] Skipping (9, 1, 1), gridError=0.01058570443016352 * 1.0 > minError=0.00714142842854285
# [maelzel.scoring:quant.py:917:quantizeBeatBinary:DEBUG] Skipping (4,), gridError=0.052556025953357156 * 1.0 > minError=0.00714142842854285
# [maelzel.scoring:quant.py:917:quantizeBeatBinary:DEBUG] Skipping (5, 1, 1, 1), gridError=0.017446221938578896 * 1.0 > minError=0.00714142842854285
# [maelzel.scoring:quant.py:934:quantizeBeatBinary:DEBUG] Skipping (6, 1, 1, 1), totalError=0.007348469228349534 > minError=0.00714142842854285
# [maelzel.scoring:quant.py:917:quantizeBeatBinary:DEBUG] Skipping (7, 1, 1, 1), gridError=0.013106675967822777 * 1.0 > minError=0.00714142842854285
# [maelzel.scoring:quant.py:917:quantizeBeatBinary:DEBUG] Skipping (3, 1, 1, 1, 1), gridError=0.044386863687026205 * 1.0 > minError=0.00714142842854285
# [maelzel.scoring:quant.py:908:quantizeBeatBinary:DEBUG] Skipping (5, 1, 1, 1, 1), divPenalty=0.09000000000000001 * 0.1 > minError=0.00714142842854285
# [maelzel.scoring:quant.py:917:quantizeBeatBinary:DEBUG] Skipping (3, 1, 1, 1, 1, 1), gridError=0.026932261966345888 * 1.0 > minError=0.00714142842854285
# Beat: 1 - 2 (dur: 1)
# Best 8 divisions: (quantized in 16.8ms)
# <table>
# <thead>
# <tr><th style="text-align: right;">  error</th><th>div      </th><th>snapped                                                                                                      </th><th>slots  </th><th>info                                                                                                                                                                               </th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;"> 0.0071</td><td>(8, 1, 1)</td><td>[«~4G+13 0:0.042 1/24♩», «rest 0.042:1 23/24♩»]                                                              </td><td>[0, 1] </td><td>gridError=0, rhythmComplexity=0.224 (numNotesAcrossSubdivs=1, numTies=0), divPenalty=0.01 (0.0001, divPenalty=0.01, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)     </td></tr>
# <tr><td style="text-align: right;"> 0.0152</td><td>(11, 1)  </td><td>[«~4G+13 0:0.045 1/22♩», «rest 0.045:1 21/22♩»]                                                              </td><td>[0, 1] </td><td>gridError=0.00893, rhythmComplexity=0.224 (numNotesAcrossSubdivs=1, numTies=0), divPenalty=0.1 (0.001, divPenalty=0.1, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)  </td></tr>
# <tr><td style="text-align: right;"> 0.0281</td><td>(9, 1)   </td><td>[«~4G+13 0:0.056 1/18♩», «rest 0.056:1 17/18♩»]                                                              </td><td>[0, 1] </td><td>gridError=0.0269, rhythmComplexity=0.224 (numNotesAcrossSubdivs=1, numTies=0), divPenalty=0.04 (0.0004, divPenalty=0.04, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)</td></tr>
# <tr><td style="text-align: right;"> 0.0387</td><td>(8, 1)   </td><td>[«~4G+13 0:0.062 1/16♩», «rest 0.062:1 15/16♩»]                                                              </td><td>[0, 1] </td><td>gridError=0.038, rhythmComplexity=0.224 (numNotesAcrossSubdivs=1, numTies=0), divPenalty=0.01 (0.0001, divPenalty=0.01, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0) </td></tr>
# <tr><td style="text-align: right;"> 0.0520</td><td>(7, 1)   </td><td>[«~4G+13 0:0.071 1/14♩», «rest 0.071:1 13/14♩»]                                                              </td><td>[0, 1] </td><td>gridError=0.0515, rhythmComplexity=0.224 (numNotesAcrossSubdivs=1, numTies=0), divPenalty=0.02 (0.0002, divPenalty=0.02, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)</td></tr>
# <tr><td style="text-align: right;"> 0.0526</td><td>(1,)     </td><td>[«~4G+13 0:grace properties={&#x27;.snappedGracenote&#x27;: True, &#x27;originalDuration&#x27;: Fraction(1, 24)}», «rest 0:1 1♩»]</td><td>[0, 0] </td><td>gridError=0.0526, rhythmComplexity=0 (numNotesAcrossSubdivs=0, numTies=0), divPenalty=0 (0, divPenalty=0, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)               </td></tr>
# <tr><td style="text-align: right;"> 0.0526</td><td>(2,)     </td><td>[«~4G+13 0:grace properties={&#x27;.snappedGracenote&#x27;: True, &#x27;originalDuration&#x27;: Fraction(1, 24)}», «rest 0:1 1♩»]</td><td>[0, 0] </td><td>gridError=0.0526, rhythmComplexity=0 (numNotesAcrossSubdivs=0, numTies=0), divPenalty=0 (0, divPenalty=0, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)               </td></tr>
# <tr><td style="text-align: right;"> 0.0545</td><td>(5,)     </td><td>[«~4G+13 0:grace properties={&#x27;.snappedGracenote&#x27;: True, &#x27;originalDuration&#x27;: Fraction(1, 24)}», «rest 0:1 1♩»]</td><td>[0, 0] </td><td>gridError=0.0526, rhythmComplexity=0.447 (numNotesAcrossSubdivs=0, numTies=1), divPenalty=0.02 (0.0002, divPenalty=0.02, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)</td></tr>
# </tbody>
# </table>
# [maelzel.scoring:quant.py:1611:_mergeSiblings:DEBUG] Nodes cannot merge:
# Node(3/2,
#   «4C 0:0.333 1/3♩ 3/2»
#   «5E-33 0.333:0.667 1/3♩ 3/2»
#   «4G+13~ 0.667:1 1/3♩ 3/2»
# )
# Node(3/2,
#   Node(1/1,
#     «~4G+13 1:1.042 1/24♩ 3/2»
#     «rest 1.042:1.333 7/24♩ 3/2»
#   )
#   «rest 1.333:2 2/3♩ 3/2»
# )
# ----> A Node cannot merge with a single item
# [maelzel.scoring:quant.py:1605:_mergeSiblings:DEBUG] Nodes can merge:
#     Node(1/1,
#   «rest 2:3 1♩»
# )
#     Node(1/1,
#   «rest 3:4 1♩»
# )
# [maelzel.scoring:quant.py:1608:_mergeSiblings:DEBUG] ---- Merged node:
#     Node(1/1,
#   «rest 2:4 2♩»
# )
# [maelzel.scoring:node.py:647:_splitUnnecessaryNodes:DEBUG] Did not split node Node(1/1,
#   Node(3/2,
#     «4C 0:0.333 1/3♩ 3/2»
#     «5E-33 0.333:0.667 1/3♩ 3/2»
#     «4G+13~ 0.667:1 1/3♩ 3/2»
#   )
#   Node(3/2,
#     Node(1/1,
#       «~4G+13 1:1.042 1/24♩ 3/2»
#       «rest 1.042:1.333 7/24♩ 3/2»
#     )
#     «rest 1.333:2 2/3♩ 3/2»
#   )
#   Node(1/1,
#     «rest 2:4 2♩»
#   )
# ) at 3
# DEBUG:maelzel:findLilypond: searching via shutil.which
# DEBUG:maelzel:... found! lilypond path: /usr/bin/lilypond
# [maelzel.scoring:renderlily.py:1116:write:DEBUG] Rendering lilypond '/tmp/tmpv81zbs3w.ly' to '/tmp/tmpv81zbs3w.png'
# DEBUG:maelzel:Rendering lilypond '/tmp/tmpv81zbs3w.ly' to '/tmp/tmpv81zbs3w.png'
# DEBUG:maelzel:Calling lilypond subprocess: ['/usr/bin/lilypond', '--png', '-o', '/tmp/tmpv81zbs3w', '-dresolution=200', '/tmp/tmpv81zbs3w.ly']
# DEBUG:maelzel:lilypond executed OK
# DEBUG:maelzel:stderr:
# DEBUG:maelzel: Changing working directory to: `/tmp'
#  Processing `/tmp/tmpv81zbs3w.ly'
#  Parsing...
#  Interpreting music...
#  Preprocessing graphical objects...
#  Finding the ideal number of pages...
#  Fitting music on 1 page...
#  Drawing systems...
#  Converting to PNG...
#  Layout output to `tmpv81zbs3w.cropped.eps'...
#  Converting to PNG...
#  Success: compilation successfully completed
#
# [maelzel.scoring:renderlily.py:1129:write:DEBUG] Found crop file /tmp/tmpv81zbs3w.cropped.png, using that as output
# Voice([4C:0.333♩, 5E-33:0.333♩, 4G+13:0.375♩], offset=0)

# %%
import bpf4 as bpf
dur = 12
left2 = left.cycle(totaldur=dur)

timecurve = bpf.linear(0, 1, dur, 1.5)
transposition = bpf.halfcos(0, 0, dur, -4)

items2 = [item.clone(dur=item.dur * timecurve(item.absOffset()), pitch=item.pitch+transposition(item.absOffset()))
          for item in left2.items]
left3 = Chain(items2)

with CoreConfig(quant_complexity='low'):
    left3.show()
# Out:
# [maelzel.core:mobj.py:1755:resetImageCache:INFO] Resetting image cache
# [maelzel.scoring:quant.py:1603:_mergeSiblings:DEBUG] Nodes cannot merge:
# Node(1/1,
#   «~4G+10 1:grace properties={'.snappedGracenote': True, 'originalDuration': Fraction(250199979298359, 18014398509481984)}»
#   «4C-07 1:1.375 3/8♩»
#   «5E-45 1.375:1.75 3/8♩»
#   «4G-06~ 1.75:2 1/4♩»
# )
# Node(1/1,
#   Node(3/2,
#     «~4G-06 2:2.083 1/12♩ 3/2»
#     «4C-27 2.083:2.417 1/3♩ 3/2»
#     «5D#+31~ 2.417:2.5 1/12♩ 3/2»
#   )
#   Node(5/4,
#     «~5D#+31 2.5:2.8 3/10♩ 5/4»
#     «4G-34~ 2.8:3 1/5♩ 5/4»
#   )
# )
# ----> A Node cannot merge with a single item
# [maelzel.scoring:quant.py:1603:_mergeSiblings:DEBUG] Nodes cannot merge:
# Node(1/1,
#   Node(3/2,
#     «~4G-06 2:2.083 1/12♩ 3/2»
#     «4C-27 2.083:2.417 1/3♩ 3/2»
#     «5D#+31~ 2.417:2.5 1/12♩ 3/2»
#   )
#   Node(5/4,
#     «~5D#+31 2.5:2.8 3/10♩ 5/4»
#     «4G-34~ 2.8:3 1/5♩ 5/4»
#   )
# )
# Node(1/1,
#   Node(3/2,
#     «~4G-34 3:3.167 1/6♩ 3/2»
#     «3B+41 3.167:3.5 1/3♩ 3/2»
#   )
#   Node(5/4,
#     «5Eb-04 3.5:3.9 2/5♩ 5/4»
#     «4F#+28~ 3.9:4 1/10♩ 5/4»
#   )
# )
# ----> nested tuplets cannot merge: not same durRatio
# [maelzel.scoring:node.py:510:removeUnnecessaryGracenotes:DEBUG] Removing gracenote «~4G+10 1:grace properties={'.snappedGracenote': True, 'originalDuration': Fraction(250199979298359, 18014398509481984)}» from node Node(1/1,
#   «~4G+10 1:grace properties={'.snappedGracenote': True, 'originalDuration': Fraction(250199979298359, 18014398509481984)}»
#   «4C-07 1:1.375 3/8♩»
#   «5E-45 1.375:1.75 3/8♩»
#   «4G-06~ 1.75:2 1/4♩»
# )
# [maelzel.scoring:quant.py:1597:_mergeSiblings:DEBUG] Nodes can merge:
#     Node(5/4,
#   «~4F#+28 0:0.3 3/10♩ 5/4»
#   «3B~ 0.3:0.5 1/5♩ 5/4»
# )
#     Node(5/4,
#   «~3B 0.5:0.7 1/5♩ 5/4»
#   «5Eb-48~ 0.7:1 3/10♩ 5/4»
# )
# [maelzel.scoring:quant.py:1600:_mergeSiblings:DEBUG] ---- Merged node:
#     Node(5/4,
#   «~4F#+28 0:0.3 3/10♩ 5/4»
#   «3B 0.3:0.7 2/5♩ 5/4»
#   «5Eb-48~ 0.7:1 3/10♩ 5/4»
# )
# [maelzel.scoring:quant.py:1597:_mergeSiblings:DEBUG] Nodes can merge:
#     Node(5/4,
#   «~5Eb-48 1:1.1 1/10♩ 5/4»
#   «4Gb-19 1.1:1.5 2/5♩ 5/4»
# )
#     Node(5/4,
#   «3B-48 1.5:1.9 2/5♩ 5/4»
#   «5D+02~ 1.9:2 1/10♩ 5/4»
# )
# [maelzel.scoring:quant.py:1600:_mergeSiblings:DEBUG] ---- Merged node:
#     Node(5/4,
#   «~5Eb-48 1:1.1 1/10♩ 5/4»
#   «4Gb-19 1.1:1.5 2/5♩ 5/4»
#   «3B-48 1.5:1.9 2/5♩ 5/4»
#   «5D+02~ 1.9:2 1/10♩ 5/4»
# )
# [maelzel.scoring:quant.py:1597:_mergeSiblings:DEBUG] Nodes can merge:
#     Node(1/1,
#   Node(5/4,
#     «~4F#+28 0:0.3 3/10♩ 5/4»
#     «3B 0.3:0.7 2/5♩ 5/4»
#     «5Eb-48~ 0.7:1 3/10♩ 5/4»
#   )
# )
#     Node(1/1,
#   Node(5/4,
#     «~5Eb-48 1:1.1 1/10♩ 5/4»
#     «4Gb-19 1.1:1.5 2/5♩ 5/4»
#     «3B-48 1.5:1.9 2/5♩ 5/4»
#     «5D+02~ 1.9:2 1/10♩ 5/4»
#   )
# )
# [maelzel.scoring:quant.py:1603:_mergeSiblings:DEBUG] Nodes cannot merge:
# Node(5/4,
#   «~4F#+28 0:0.3 3/10♩ 5/4»
#   «3B 0.3:0.7 2/5♩ 5/4»
#   «5Eb-48~ 0.7:1 3/10♩ 5/4»
# )
# Node(5/4,
#   «~5Eb-48 1:1.1 1/10♩ 5/4»
#   «4Gb-19 1.1:1.5 2/5♩ 5/4»
#   «3B-48 1.5:1.9 2/5♩ 5/4»
#   «5D+02~ 1.9:2 1/10♩ 5/4»
# )
# ----> Absolute duration of merged Notations across beat too short: item1=«5Eb-48~ 0.7:1 3/10♩ 5/4», item2=«~5Eb-48 1:1.1 1/10♩ 5/4», min. merged duration: 0.5, beat dur: 1
# [maelzel.scoring:quant.py:1600:_mergeSiblings:DEBUG] ---- Merged node:
#     Node(1/1,
#   Node(5/4,
#     «~4F#+28 0:0.3 3/10♩ 5/4»
#     «3B 0.3:0.7 2/5♩ 5/4»
#     «5Eb-48~ 0.7:1 3/10♩ 5/4»
#   )
#   Node(5/4,
#     «~5Eb-48 1:1.1 1/10♩ 5/4»
#     «4Gb-19 1.1:1.5 2/5♩ 5/4»
#     «3B-48 1.5:1.9 2/5♩ 5/4»
#     «5D+02~ 1.9:2 1/10♩ 5/4»
#   )
# )
# [maelzel.scoring:quant.py:1597:_mergeSiblings:DEBUG] Nodes can merge:
#     Node(5/4,
#   «~5D+02 2:2.3 3/10♩ 5/4»
#   «4F+30~ 2.3:2.5 1/5♩ 5/4»
# )
#     Node(5/4,
#   «~4F+30 2.5:2.7 1/5♩ 5/4»
#   «3A#~ 2.7:3 3/10♩ 5/4»
# )
# [maelzel.scoring:quant.py:1600:_mergeSiblings:DEBUG] ---- Merged node:
#     Node(5/4,
#   «~5D+02 2:2.3 3/10♩ 5/4»
#   «4F+30 2.3:2.7 2/5♩ 5/4»
#   «3A#~ 2.7:3 3/10♩ 5/4»
# )
# [maelzel.scoring:quant.py:1603:_mergeSiblings:DEBUG] Nodes cannot merge:
# Node(1/1,
#   Node(5/4,
#     «~4F#+28 0:0.3 3/10♩ 5/4»
#     «3B 0.3:0.7 2/5♩ 5/4»
#     «5Eb-48~ 0.7:1 3/10♩ 5/4»
#   )
#   Node(5/4,
#     «~5Eb-48 1:1.1 1/10♩ 5/4»
#     «4Gb-19 1.1:1.5 2/5♩ 5/4»
#     «3B-48 1.5:1.9 2/5♩ 5/4»
#     «5D+02~ 1.9:2 1/10♩ 5/4»
#   )
# )
# Node(1/1,
#   Node(5/4,
#     «~5D+02 2:2.3 3/10♩ 5/4»
#     «4F+30 2.3:2.7 2/5♩ 5/4»
#     «3A#~ 2.7:3 3/10♩ 5/4»
#   )
# )
# ----> nested tuplets cannot merge: Absolute duration of merged Notations across beat too short: item1=«5D+02~ 1.9:2 1/10♩ 5/4», item2=«~5D+02 2:2.3 3/10♩ 5/4», min. merged duration: 0.5, beat dur: 1
# [maelzel.scoring:quant.py:1603:_mergeSiblings:DEBUG] Nodes cannot merge:
# Node(1/1,
#   Node(5/4,
#     «~5D+02 2:2.3 3/10♩ 5/4»
#     «4F+30 2.3:2.7 2/5♩ 5/4»
#     «3A#~ 2.7:3 3/10♩ 5/4»
#   )
# )
# Node(1/1,
#   «~3A# 3:3.125 1/8♩»
#   «5D- 3.125:3.5 3/8♩»
#   «4F-22 3.5:4 1/2♩»
#   «3A+48~ 4:grace properties={'.snappedGracenote': True, 'originalDuration': Fraction(250199979298365, 9007199254740992)}»
# )
# ----> A Node cannot merge with a single item
# [maelzel.scoring:node.py:641:_splitUnnecessaryNodes:DEBUG] Splitting node Node(1/1,
#   Node(1/1,
#     Node(5/4,
#       «~4F#+28 0:0.3 3/10♩ 5/4»
#       «3B 0.3:0.7 2/5♩ 5/4»
#       «5Eb-48~ 0.7:1 3/10♩ 5/4»
#     )
#     Node(5/4,
#       «~5Eb-48 1:1.1 1/10♩ 5/4»
#       «4Gb-19 1.1:1.5 2/5♩ 5/4»
#       «3B-48 1.5:1.9 2/5♩ 5/4»
#       «5D+02~ 1.9:2 1/10♩ 5/4»
#     )
#   )
#   Node(1/1,
#     Node(5/4,
#       «~5D+02 2:2.3 3/10♩ 5/4»
#       «4F+30 2.3:2.7 2/5♩ 5/4»
#       «3A#~ 2.7:3 3/10♩ 5/4»
#     )
#   )
#   Node(1/1,
#     «~3A# 3:3.125 1/8♩»
#     «5D- 3.125:3.5 3/8♩»
#     «4F-22 3.5:4 1/2♩»
#     «3A+48~ 4:grace properties={'.snappedGracenote': True, 'originalDuration': Fraction(250199979298365, 9007199254740992)}»
#   )
# ) at 1
# [maelzel.scoring:quant.py:1326:quantizeMeasure:DEBUG] Measure 4/4 is not filled (events=[«~4D#+49 0:0.014 0.014♩», «3G#+27 0.014:0.486 0.472♩», «5C-14 0.486:0.963 0.477♩», «4D#> 0.963:1.444 0.481♩», «3G#+07 1.444:1.931 0.486♩», «5C-30 1.931:2.421 0.491♩», «4D#+14 2.421:2.917 0.495♩»]). Filling gaps with silences
# [maelzel.scoring:quant.py:1597:_mergeSiblings:DEBUG] Nodes can merge:
#     Node(5/4,
#   «~4D#> 1:1.4 2/5♩ 5/4»
#   «3G#+07~ 1.4:1.5 1/10♩ 5/4»
# )
#     Node(5/4,
#   «~3G#+07 1.5:1.9 2/5♩ 5/4»
#   «5C-30~ 1.9:2 1/10♩ 5/4»
# )
# [maelzel.scoring:quant.py:1600:_mergeSiblings:DEBUG] ---- Merged node:
#     Node(5/4,
#   «~4D#> 1:1.4 2/5♩ 5/4»
#   «3G#+07~ 1.4:1.5 1/10♩ 5/4»
#   «~3G#+07 1.5:1.9 2/5♩ 5/4»
#   «5C-30~ 1.9:2 1/10♩ 5/4»
# )
# [maelzel.scoring:quant.py:1603:_mergeSiblings:DEBUG] Nodes cannot merge:
# Node(1/1,
#   «~4D#+49 0:grace properties={'.snappedGracenote': True, 'originalDuration': Fraction(125099989649175, 9007199254740992)}»
#   «3G#+27 0:0.5 1/2♩»
#   «5C-14 0.5:1 1/2♩»
#   «4D#>~ 1:grace properties={'.snappedGracenote': True, 'originalDuration': Fraction(83399993099455, 2251799813685248)}»
# )
# Node(1/1,
#   Node(5/4,
#     «~4D#> 1:1.4 2/5♩ 5/4»
#     «3G#+07~ 1.4:1.5 1/10♩ 5/4»
#     «~3G#+07 1.5:1.9 2/5♩ 5/4»
#     «5C-30~ 1.9:2 1/10♩ 5/4»
#   )
# )
# ----> A Node cannot merge with a single item
# [maelzel.scoring:quant.py:1597:_mergeSiblings:DEBUG] Nodes can merge:
#     Node(5/4,
#   «~5C-30 2:2.4 2/5♩ 5/4»
#   «4D#+14~ 2.4:2.5 1/10♩ 5/4»
# )
#     Node(5/4,
#   «~4D#+14 2.5:2.9 2/5♩ 5/4»
#   «rest 2.9:3 1/10♩ 5/4»
# )
# [maelzel.scoring:quant.py:1600:_mergeSiblings:DEBUG] ---- Merged node:
#     Node(5/4,
#   «~5C-30 2:2.4 2/5♩ 5/4»
#   «4D#+14~ 2.4:2.5 1/10♩ 5/4»
#   «~4D#+14 2.5:2.9 2/5♩ 5/4»
#   «rest 2.9:3 1/10♩ 5/4»
# )
# [maelzel.scoring:quant.py:1597:_mergeSiblings:DEBUG] Nodes can merge:
#     Node(1/1,
#   Node(5/4,
#     «~4D#> 1:1.4 2/5♩ 5/4»
#     «3G#+07~ 1.4:1.5 1/10♩ 5/4»
#     «~3G#+07 1.5:1.9 2/5♩ 5/4»
#     «5C-30~ 1.9:2 1/10♩ 5/4»
#   )
# )
#     Node(1/1,
#   Node(5/4,
#     «~5C-30 2:2.4 2/5♩ 5/4»
#     «4D#+14~ 2.4:2.5 1/10♩ 5/4»
#     «~4D#+14 2.5:2.9 2/5♩ 5/4»
#     «rest 2.9:3 1/10♩ 5/4»
#   )
# )
# [maelzel.scoring:quant.py:1597:_mergeSiblings:DEBUG] Nodes can merge:
#     Node(5/4,
#   «~4D#> 1:1.4 2/5♩ 5/4»
#   «3G#+07~ 1.4:1.5 1/10♩ 5/4»
#   «~3G#+07 1.5:1.9 2/5♩ 5/4»
#   «5C-30~ 1.9:2 1/10♩ 5/4»
# )
#     Node(5/4,
#   «~5C-30 2:2.4 2/5♩ 5/4»
#   «4D#+14~ 2.4:2.5 1/10♩ 5/4»
#   «~4D#+14 2.5:2.9 2/5♩ 5/4»
#   «rest 2.9:3 1/10♩ 5/4»
# )
# [maelzel.scoring:quant.py:1600:_mergeSiblings:DEBUG] ---- Merged node:
#     Node(5/4,
#   «~4D#> 1:1.4 2/5♩ 5/4»
#   «3G#+07~ 1.4:1.5 1/10♩ 5/4»
#   «~3G#+07 1.5:1.9 2/5♩ 5/4»
#   «5C-30~ 1.9:2 1/10♩ 5/4»
#   «~5C-30 2:2.4 2/5♩ 5/4»
#   «4D#+14~ 2.4:2.5 1/10♩ 5/4»
#   «~4D#+14 2.5:2.9 2/5♩ 5/4»
#   «rest 2.9:3 1/10♩ 5/4»
# )
# [maelzel.scoring:quant.py:1600:_mergeSiblings:DEBUG] ---- Merged node:
#     Node(1/1,
#   Node(5/4,
#     «~4D#> 1:1.4 2/5♩ 5/4»
#     «3G#+07~ 1.4:1.5 1/10♩ 5/4»
#     «~3G#+07 1.5:1.9 2/5♩ 5/4»
#     «5C-30~ 1.9:2 1/10♩ 5/4»
#     «~5C-30 2:2.4 2/5♩ 5/4»
#     «4D#+14~ 2.4:2.5 1/10♩ 5/4»
#     «~4D#+14 2.5:2.9 2/5♩ 5/4»
#     «rest 2.9:3 1/10♩ 5/4»
#   )
# )
# [maelzel.scoring:quant.py:1597:_mergeSiblings:DEBUG] Nodes can merge:
#     Node(1/1,
#   Node(5/4,
#     «~4D#> 1:1.4 2/5♩ 5/4»
#     «3G#+07~ 1.4:1.5 1/10♩ 5/4»
#     «~3G#+07 1.5:1.9 2/5♩ 5/4»
#     «5C-30~ 1.9:2 1/10♩ 5/4»
#     «~5C-30 2:2.4 2/5♩ 5/4»
#     «4D#+14~ 2.4:2.5 1/10♩ 5/4»
#     «~4D#+14 2.5:2.9 2/5♩ 5/4»
#     «rest 2.9:3 1/10♩ 5/4»
#   )
# )
#     Node(1/1,
#   «rest 3:4 1♩»
# )
# [maelzel.scoring:quant.py:1600:_mergeSiblings:DEBUG] ---- Merged node:
#     Node(1/1,
#   Node(5/4,
#     «~4D#> 1:1.4 2/5♩ 5/4»
#     «3G#+07~ 1.4:1.5 1/10♩ 5/4»
#     «~3G#+07 1.5:1.9 2/5♩ 5/4»
#     «5C-30~ 1.9:2 1/10♩ 5/4»
#     «~5C-30 2:2.4 2/5♩ 5/4»
#     «4D#+14~ 2.4:2.5 1/10♩ 5/4»
#     «~4D#+14 2.5:2.9 2/5♩ 5/4»
#     «rest 2.9:3 1/10♩ 5/4»
#   )
#   «rest 3:4 1♩»
# )
# [maelzel.scoring:node.py:498:removeUnnecessaryGracenotes:DEBUG] Removing gracenote «4D#>~ 1:grace properties={'.snappedGracenote': True, 'originalDuration': Fraction(83399993099455, 2251799813685248)}» from node Node(1/1,
#   «~4D#+49 0:grace properties={'.snappedGracenote': True, 'originalDuration': Fraction(125099989649175, 9007199254740992)}»
#   «3G#+27 0:0.5 1/2♩»
#   «5C-14 0.5:1 1/2♩»
#   «4D#>~ 1:grace properties={'.snappedGracenote': True, 'originalDuration': Fraction(83399993099455, 2251799813685248)}»
# )
# [maelzel.scoring:quant.py:1870:removeUnnecessaryGracenotes:DEBUG] Found unnecessary grace note: «~4D#+49 0:grace properties={'.snappedGracenote': True, 'originalDuration': Fraction(125099989649175, 9007199254740992)}» at measure 3. It is tied to «4D#+49~ 3.5:4 1/2♩» from the previous measure but addsnothing to it
# [maelzel.scoring:renderlily.py:1116:write:DEBUG] Rendering lilypond '/tmp/tmpom_3ruyf.ly' to '/tmp/tmpom_3ruyf.png'
# DEBUG:maelzel:Rendering lilypond '/tmp/tmpom_3ruyf.ly' to '/tmp/tmpom_3ruyf.png'
# DEBUG:maelzel:Calling lilypond subprocess: ['/usr/bin/lilypond', '--png', '-o', '/tmp/tmpom_3ruyf', '-dresolution=200', '/tmp/tmpom_3ruyf.ly']
# DEBUG:maelzel:lilypond executed OK
# DEBUG:maelzel:stderr:
# DEBUG:maelzel: Changing working directory to: `/tmp'
#  Processing `/tmp/tmpom_3ruyf.ly'
#  Parsing...
#  Interpreting music...
#  /tmp/tmpom_3ruyf.ly:300:12: warning: unterminated tie
#        eeh'8
#             ~
#  Preprocessing graphical objects...
#  Finding the ideal number of pages...
#  Fitting music on 1 page...
#  Drawing systems...
#  Converting to PNG...
#  Layout output to `tmpom_3ruyf.cropped.eps'...
#  Converting to PNG...
#  Success: compilation successfully completed
#
# [maelzel.scoring:renderlily.py:1129:write:DEBUG] Found crop file /tmp/tmpom_3ruyf.cropped.png, using that as output
# [maelzel.core:mobj.py:1755:resetImageCache:INFO] Resetting image cache

# %%
left3.play(sustain=0.5)
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=90)
#     Synth(𝍪 preset:.piano=501.0092 start=19.401 dur=0.533 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=60 p18=0.515178 p19=0.0333333 …)
#     Synth(𝍪 preset:.piano=501.0093 start=19.434 dur=0.537 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=75.6688 p18=0.515178 p19=0.0366667 …)
#     Synth(𝍪 preset:.piano=501.0094 start=19.471 dur=0.540 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=67.1251 p18=0.515178 p19=0.04 …)
#     Synth(𝍪 preset:.piano=501.0095 start=19.511 dur=0.543 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=59.989 p18=0.515178 p19=0.0433333 …)
#     Synth(𝍪 preset:.piano=501.0096 start=19.554 dur=0.547 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=75.6505 p18=0.515178 p19=0.0466667 …)
#     Synth(𝍪 preset:.piano=501.0097 start=19.601 dur=0.550 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=67.0996 p18=0.515178 p19=0.05 …)
#     Synth(𝍪 preset:.piano=501.0098 start=19.651 dur=0.553 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=59.9563 p18=0.515178 p19=0.0533333 …)
#     Synth(𝍪 preset:.piano=501.0099 start=19.704 dur=0.557 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=75.6106 p18=0.515178 p19=0.0566667 …)
#     Synth(𝍪 preset:.piano=501.01 start=19.761 dur=0.560 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=67.0525 p18=0.515178 p19=0.06 …)
#     Synth(𝍪 preset:.piano=501.0101 start=19.821 dur=0.563 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=59.9021 p18=0.515178 p19=0.0633333 …)
#     Synth(𝍪 preset:.piano=501.0102 start=19.884 dur=0.567 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=75.5494 p18=0.515178 p19=0.0666667 …)
#     Synth(𝍪 preset:.piano=501.0103 start=19.951 dur=0.570 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=66.9844 p18=0.515178 p19=0.07 …)
#     Synth(𝍪 preset:.piano=501.0104 start=20.021 dur=0.573 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=59.8271 p18=0.515178 p19=0.0733333 …)
#     Synth(𝍪 preset:.piano=501.0105 start=20.094 dur=0.577 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=75.4676 p18=0.515178 p19=0.0766667 …)
#     Synth(𝍪 preset:.piano=501.0106 start=20.171 dur=0.580 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=66.8959 p18=0.515178 p19=0.08 …)
#     Synth(𝍪 preset:.piano=501.0107 start=20.251 dur=0.583 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=59.7321 p18=0.515178 p19=0.0833333 …)
#     Synth(𝍪 preset:.piano=501.0108 start=20.334 dur=0.587 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=75.3661 p18=0.515178 p19=0.0866667 …)
#     Synth(𝍪 preset:.piano=501.0109 start=20.421 dur=0.590 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=66.7881 p18=0.515178 p19=0.09 …)
#     Synth(𝍪 preset:.piano=501.011 start=20.511 dur=0.593 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=59.618 p18=0.515178 p19=0.0933333 …)
#     Synth(𝍪 preset:.piano=501.0111 start=20.604 dur=0.597 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=75.246 p18=0.515178 p19=0.0966667 …)
#     Synth(𝍪 preset:.piano=501.0112 start=20.701 dur=0.600 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=66.6621 p18=0.515178 p19=0.1 …)
#     Synth(𝍪 preset:.piano=501.0113 start=20.801 dur=0.603 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=59.4863 p18=0.515178 p19=0.103333 …)
#     Synth(𝍪 preset:.piano=501.0114 start=20.904 dur=0.607 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=75.1087 p18=0.515178 p19=0.106667 …)
#     Synth(𝍪 preset:.piano=501.0115 start=21.011 dur=0.610 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=66.5193 p18=0.515178 p19=0.11 …)
#     Synth(𝍪 preset:.piano=501.0116 start=21.121 dur=0.613 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=59.3383 p18=0.515178 p19=0.113333 …)
#     Synth(𝍪 preset:.piano=501.0117 start=21.234 dur=0.617 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=74.9556 p18=0.515178 p19=0.116667 …)
#     Synth(𝍪 preset:.piano=501.0118 start=21.351 dur=0.620 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=66.3613 p18=0.515178 p19=0.12 …)
#     Synth(𝍪 preset:.piano=501.0119 start=21.471 dur=0.623 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=59.1756 p18=0.515178 p19=0.123333 …)
#     Synth(𝍪 preset:.piano=501.012 start=21.594 dur=0.627 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=74.7884 p18=0.515178 p19=0.126667 …)
#     Synth(𝍪 preset:.piano=501.0121 start=21.721 dur=0.630 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=66.1898 p18=0.515178 p19=0.13 …)
#     Synth(𝍪 preset:.piano=501.0122 start=21.851 dur=0.633 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=59 p18=0.515178 p19=0.133333 …)
#     Synth(𝍪 preset:.piano=501.0123 start=21.984 dur=0.637 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=74.6089 p18=0.515178 p19=0.136667 …)
#     Synth(𝍪 preset:.piano=501.0124 start=22.121 dur=0.640 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=66.0067 p18=0.515178 p19=0.14 …)
#     Synth(𝍪 preset:.piano=501.0125 start=22.261 dur=0.643 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=58.8135 p18=0.515178 p19=0.143333 …)
#     Synth(𝍪 preset:.piano=501.0126 start=22.404 dur=0.647 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=74.4192 p18=0.515178 p19=0.146667 …)
#     Synth(𝍪 preset:.piano=501.0127 start=22.551 dur=0.650 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=65.814 p18=0.515178 p19=0.15 …)
#     Synth(𝍪 preset:.piano=501.0128 start=22.701 dur=0.653 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=58.618 p18=0.515178 p19=0.153333 …)
#     Synth(𝍪 preset:.piano=501.0129 start=22.854 dur=0.657 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=74.2213 p18=0.515178 p19=0.156667 …)
#     Synth(𝍪 preset:.piano=501.013 start=23.011 dur=0.660 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=65.6138 p18=0.515178 p19=0.16 …)
#     Synth(𝍪 preset:.piano=501.0131 start=23.171 dur=0.663 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=58.4158 p18=0.515178 p19=0.163333 …)
#     Synth(𝍪 preset:.piano=501.0132 start=23.334 dur=0.667 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=74.0173 p18=0.515178 p19=0.166667 …)
#     Synth(𝍪 preset:.piano=501.0133 start=23.501 dur=0.670 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=65.4083 p18=0.515178 p19=0.17 …)
#     Synth(𝍪 preset:.piano=501.0134 start=23.671 dur=0.673 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=58.2091 p18=0.515178 p19=0.173333 …)
#     Synth(𝍪 preset:.piano=501.0135 start=23.844 dur=0.677 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=73.8095 p18=0.515178 p19=0.176667 …)
#     Synth(𝍪 preset:.piano=501.0136 start=24.021 dur=0.680 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=65.1998 p18=0.515178 p19=0.18 …)
#     Synth(𝍪 preset:.piano=501.0137 start=24.201 dur=0.683 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=58 p18=0.515178 p19=0.183333 …)
#     Synth(𝍪 preset:.piano=501.0138 start=24.384 dur=0.687 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=73.6002 p18=0.515178 p19=0.186667 …)
#     Synth(𝍪 preset:.piano=501.0139 start=24.571 dur=0.690 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=64.9905 p18=0.515178 p19=0.19 …)
#     Synth(𝍪 preset:.piano=501.014 start=24.761 dur=0.693 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=57.7909 p18=0.515178 p19=0.193333 …)
#     Synth(𝍪 preset:.piano=501.0141 start=24.954 dur=0.697 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=73.3917 p18=0.515178 p19=0.196667 …)
#     Synth(𝍪 preset:.piano=501.0142 start=25.151 dur=0.700 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=64.7827 p18=0.515178 p19=0.2 …)
#     Synth(𝍪 preset:.piano=501.0143 start=25.351 dur=0.703 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=57.5842 p18=0.515178 p19=0.203333 …)
#     Synth(𝍪 preset:.piano=501.0144 start=25.554 dur=0.707 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=73.1862 p18=0.515178 p19=0.206667 …)
#     Synth(𝍪 preset:.piano=501.0145 start=25.761 dur=0.710 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=64.5787 p18=0.515178 p19=0.21 …)
#     Synth(𝍪 preset:.piano=501.0146 start=25.971 dur=0.713 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=57.382 p18=0.515178 p19=0.213333 …)
#     Synth(𝍪 preset:.piano=501.0147 start=26.184 dur=0.717 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=72.986 p18=0.515178 p19=0.216667 …)
#     Synth(𝍪 preset:.piano=501.0148 start=26.401 dur=0.720 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=64.3808 p18=0.515178 p19=0.22 …)
#     Synth(𝍪 preset:.piano=501.0149 start=26.621 dur=0.723 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=57.1865 p18=0.515178 p19=0.223333 …)
#     Synth(𝍪 preset:.piano=501.015 start=26.844 dur=0.727 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=72.7933 p18=0.515178 p19=0.226667 …)
#     Synth(𝍪 preset:.piano=501.0151 start=27.071 dur=0.730 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=64.1911 p18=0.515178 p19=0.23 …)
#     Synth(𝍪 preset:.piano=501.0152 start=27.301 dur=0.733 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=57 p18=0.515178 p19=0.233333 …)
#     Synth(𝍪 preset:.piano=501.0153 start=27.534 dur=0.737 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=72.6102 p18=0.515178 p19=0.236667 …)
#     Synth(𝍪 preset:.piano=501.0154 start=27.771 dur=0.740 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=64.0116 p18=0.515178 p19=0.24 …)
#     Synth(𝍪 preset:.piano=501.0155 start=28.011 dur=0.743 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=56.8244 p18=0.515178 p19=0.243333 …)
#     Synth(𝍪 preset:.piano=501.0156 start=28.254 dur=0.747 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=72.4387 p18=0.515178 p19=0.246667 …)
#     Synth(𝍪 preset:.piano=501.0157 start=28.501 dur=0.750 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=63.8444 p18=0.515178 p19=0.25 …)
#     Synth(𝍪 preset:.piano=501.0158 start=28.751 dur=0.753 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=56.6617 p18=0.515178 p19=0.253333 …)
#     Synth(𝍪 preset:.piano=501.0159 start=29.004 dur=0.757 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=72.2807 p18=0.515178 p19=0.256667 …)
#     Synth(𝍪 preset:.piano=501.016 start=29.261 dur=0.760 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=63.6913 p18=0.515178 p19=0.26 …)
#     Synth(𝍪 preset:.piano=501.0161 start=29.521 dur=0.763 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=56.5137 p18=0.515178 p19=0.263333 …)
#     Synth(𝍪 preset:.piano=501.0162 start=29.784 dur=0.767 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=72.1379 p18=0.515178 p19=0.266667 …)
#     Synth(𝍪 preset:.piano=501.0163 start=30.051 dur=0.770 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=63.554 p18=0.515178 p19=0.27 …)
#     Synth(𝍪 preset:.piano=501.0164 start=30.321 dur=0.773 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=56.382 p18=0.515178 p19=0.273333 …)
#     Synth(𝍪 preset:.piano=501.0165 start=30.594 dur=0.777 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=72.0119 p18=0.515178 p19=0.276667 …)
#     Synth(𝍪 preset:.piano=501.0166 start=30.871 dur=0.780 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=63.4339 p18=0.515178 p19=0.28 …)
#     Synth(𝍪 preset:.piano=501.0167 start=31.151 dur=0.783 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=56.2679 p18=0.515178 p19=0.283333 …)
#     Synth(𝍪 preset:.piano=501.0168 start=31.434 dur=0.787 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=71.9041 p18=0.515178 p19=0.286667 …)
#     Synth(𝍪 preset:.piano=501.0169 start=31.721 dur=0.790 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=63.3324 p18=0.515178 p19=0.29 …)
#     Synth(𝍪 preset:.piano=501.017 start=32.011 dur=0.793 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=56.1729 p18=0.515178 p19=0.293333 …)
#     Synth(𝍪 preset:.piano=501.0171 start=32.304 dur=0.797 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=71.8156 p18=0.515178 p19=0.296667 …)
#     Synth(𝍪 preset:.piano=501.0172 start=32.601 dur=0.800 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=63.2506 p18=0.515178 p19=0.3 …)
#     Synth(𝍪 preset:.piano=501.0173 start=32.901 dur=0.803 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=56.0979 p18=0.515178 p19=0.303333 …)
#     Synth(𝍪 preset:.piano=501.0174 start=33.204 dur=0.807 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=71.7475 p18=0.515178 p19=0.306667 …)
#     Synth(𝍪 preset:.piano=501.0175 start=33.511 dur=0.810 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=63.1894 p18=0.515178 p19=0.31 …)
#     Synth(𝍪 preset:.piano=501.0176 start=33.821 dur=0.813 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=56.0437 p18=0.515178 p19=0.313333 …)
#     Synth(𝍪 preset:.piano=501.0177 start=34.134 dur=0.817 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=71.7004 p18=0.515178 p19=0.316667 …)
#     Synth(𝍪 preset:.piano=501.0178 start=34.451 dur=0.820 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=63.1495 p18=0.515178 p19=0.32 …)
#     Synth(𝍪 preset:.piano=501.0179 start=34.771 dur=0.823 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=56.011 p18=0.515178 p19=0.323333 …)
#     Synth(𝍪 preset:.piano=501.018 start=35.094 dur=0.827 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=71.6749 p18=0.515178 p19=0.326667 …)
#     Synth(𝍪 preset:.piano=501.0181 start=35.421 dur=0.830 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=63.1312 p18=0.515178 p19=0.33 …)

# %%
left.dur
# Out:
# Fraction(1, 1)
