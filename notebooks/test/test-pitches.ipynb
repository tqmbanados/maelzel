# %%
from maelzel.core import *

# %%
Chain([
    Note("4Eb+13!", 1),
    Note("4D#+13!", 1),
    Chord("4E+!,4F#", 1),
    "4C+,4Db!:1",
    Note("4Gb-49!", 0.5)
])
# Out:
# Chain([4Eb+13:1♩, 4D#+13:1♩, ‹4E+ 4F# 1♩›, ‹4C+ 4Db 1♩›, 4Gb-49:0.5♩])
