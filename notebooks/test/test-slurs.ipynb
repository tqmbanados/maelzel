# %%
from maelzel.core import *

# %%
ch = Chain([
    Chain([
        "4C:0.5:p",
        "4E,4F:1"
    ]),
    Chain(["4C#:0.5:f", "4D:0.5"]),
    "4G+:3/7"
], offset=0.5)
ch.play()
# Out:
# --Csound version 6.19 (double samples) Oct 30 2023
# [commit: 79e5d31bea441e5289073319ab2b1e42d01814b9]
# libsndfile-1.2.0
# sr = 48000.0, kr = 750.000, ksmps = 64
# 0dBFS level = 1.0, A4 tuning = 442.0
# audio buffered in 512 sample-frame blocks
# reading 4096-byte blks of shorts from adc:Built-in Audio Pro: (RAW)
# writing 1024 sample blks of 64-bit floats to dac:Built-in Audio Pro:
# SECTION 1:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=6)
#     Synth(𝍪 preset:.piano=501.0002 start=2.333 dur=0.500 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=60 p18=0.114858 p19=0.5 …)
#     Synth(𝍪 preset:.piano=501.0003 start=2.833 dur=1.000 p4=0.5 kpos=0.707107 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=64 p18=0.114858 p19=1 …)
#     Synth(𝍪 preset:.piano=501.0004 start=2.833 dur=1.000 p4=0.5 kpos=0.707107 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=65 p18=0.114858 p19=1 …)
#     Synth(𝍪 preset:.piano=501.0005 start=3.833 dur=0.500 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=61 p18=0.515178 p19=0.5 …)
#     Synth(𝍪 preset:.piano=501.0006 start=4.333 dur=0.500 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=62 p18=0.515178 p19=0.5 …)
#     Synth(𝍪 preset:.piano=501.0007 start=4.833 dur=0.429 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0.02 ifadein=0.02 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=67.5 p18=0.515178 p19=0.428571 …)

# %%
ch.addSpanner('slur')
ch
# Out:
# Chain([Chain([4C:0.5♩:symbols=[Slur(anchor=ref(Note), kind=start, linetype=solid, partnerSpanner=ref(Slur), uuid=5l37ze78)], ‹4E 4F 1♩›]), Chain([4C#:0.5♩, 4D:0.5♩]), 4G+:0.429♩:symbols=[Slur(anchor=ref(Note), kind=end, linetype=solid, partnerSpanner=ref(Slur), uuid=5l37ze78)]], offset=1/2)

# %%
ch2 = ch.flat()
ch2[1].addSpanner('slur', ch2[3])
ch2
# Out:
# Chain([4C:0.5♩:offset=0:symbols=[Slur(anchor=ref(Note), kind=start, linetype=solid, partnerSpanner=ref(Slur), uuid=5l37ze78)], ‹4E 4F 1♩ offset=0.5›, 4C#:0.5♩:offset=1.5, 4D:0.5♩:offset=2:symbols=[Slur(anchor=ref(Note), kind=end, linetype=solid, partnerSpanner=ref(Slur), uuid=k6r2qjo3)], 4G+:0.429♩:offset=2.5:symbols=[Slur(anchor=ref(Note), kind=end, linetype=solid, partnerSpanner=ref(Slur), uuid=5l37ze78)]], offset=1/2)

# %%
ch.play()
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=6)
#     Synth(𝍪 preset:sin:501.0008, p4=0 idataidx_:5=17 inumbps:6=2 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 p17=0 p18=60 p19=0.114858 p20=0.5 ...)
#     Synth(𝍪 preset:sin:501.0009, p4=0 idataidx_:5=17 inumbps:6=2 ibplen:7=3 igain:8=0.707107 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 p17=0 p18=64 p19=0.114858 p20=1 ...)
#     Synth(𝍪 preset:sin:501.001, p4=0 idataidx_:5=17 inumbps:6=2 ibplen:7=3 igain:8=0.707107 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 p17=0 p18=65 p19=0.114858 p20=1 ...)
#     Synth(𝍪 preset:sin:501.0011, p4=0 idataidx_:5=17 inumbps:6=2 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 p17=0 p18=61 p19=0.515178 p20=0.5 ...)
#     Synth(𝍪 preset:sin:501.0012, p4=0 idataidx_:5=17 inumbps:6=2 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 p17=0 p18=62 p19=0.515178 p20=0.5 ...)
#     Synth(𝍪 preset:sin:501.0013, p4=0 idataidx_:5=17 inumbps:6=2 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 p17=0 p18=67.5 p19=0.515178 p20=0.428571 ...)

# %%
items = list(ch.recurse())
items[0].dynamic = 'pp'
items[0].addSpanner('<', ch[2])
ch
# Out:
# Chain([Chain([4C:0.5♩:symbols=[Slur(kind=start, uuid=42b731hc, linetype=solid), Hairpin(direction=<, kind=start, uuid=vojuuttw)], ‹4E 4F 1♩›]), Chain([4C#:0.5♩, 4D:0.5♩]), 4G+:0.429♩:symbols=[Slur(kind=end, uuid=42b731hc, linetype=solid), Hairpin(direction=<, kind=end, uuid=vojuuttw)]], offset=1/2)

# %%
ch = Chain([
    "4C:0.5:p",
    "4E,4F:1:gliss",
    "4G:0",
    "4C#:3.8:f", 
    "4D:0.5",
    "4G+:3/7"
], offset=0.5)
ch[1].addSpanner('slur', ch[3])
ch[0].addSpanner('<')
ch
# Out:
# Chain([4C:0.5♩:symbols=[Hairpin(anchor=ref(Note), direction=<, kind=start, linetype=solid, uuid=84ll8q2b)], ‹4E 4F 1♩ gliss›, 4G, 4C#:3.8♩:symbols=[Slur(anchor=ref(Note), kind=end, linetype=solid, partnerSpanner=ref(Slur), uuid=f1iwhnxh)], 4D:0.5♩, 4G+:0.429♩], offset=1/2)
# Exiting python, closing all active engines
# ... stopping maelzel.core
#  *** rtjack: connection to JACK server was lost, reconnecting...end of score.		   overall amps:  0.06138  0.05981
# 	   overall samples out of range:        0        0
# 0 errors in performance
# 3204979 1024 sample blks of 64-bit floats written to dac:Built-in Audio Pro:
