# %%
from maelzel.core import *
from maelzel.music import lilytools

# %%
lilytools.findLilypond()
# Out:
# '/home/em/.local/bin/lilypond'

# %%
resetImageCache()
ch = Chain([
    "4C:1.5",
    "4F:0.5",
    
    
])
ch[0].addSpanner('slur', ch[1])
ch
# Out:
# Chain([4C:1.5♩:symbols=[Slur(anchor=ref(Note), kind=start, linetype=solid, partnerSpanner=ref(Slur), uuid=ggz7dlyv)], 4F:0.5♩:symbols=[Slur(anchor=ref(Note), kind=end, linetype=solid, partnerSpanner=ref(Slur), uuid=ggz7dlyv)]])

# %%
resetImageCache()
ch = Chain([
    "4C:1.5:gliss",
    "4E:0:stemless",
    "4F:0.5",
    
    
])
ch[0].addSpanner('slur', ch[1])
ch
# Out:
# Chain([4C:1.5♩:gliss=True:symbols=[Slur(anchor=ref(Note), kind=start, linetype=solid, partnerSpanner=ref(Slur), uuid=6mtehju6)], 4E:symbols=[Stem(hidden=True), Slur(anchor=ref(Note), kind=end, linetype=solid, partnerSpanner=ref(Slur), uuid=6mtehju6)], 4F:0.5♩])

# %%
ch = Chain([Note(p, 0.25) for p in range(48, 72)])
ch[1].addSpanner(symbols.NoteheadLine(color='blue'), ch[3])
ch[5].addSpanner(symbols.Beam(), ch[9])
ch[10].addSpanner(symbols.Bracket(), ch[13])
ch[0].addSpanner('slur', ch[7])
ch
# Out:
# Chain([3C:0.25♩:symbols=[Slur(anchor=ref(Note), kind=start, linetype=solid, partnerSpanner=ref(Slur), uuid=0ps33go9)], 3C#:0.25♩:symbols=[NoteheadLine(anchor=ref(Note), color=blue, kind=start, linetype=solid, partnerSpanner=ref(NoteheadLine), uuid=kamf8wxw)], 3D:0.25♩, 3D#:0.25♩:symbols=[NoteheadLine(anchor=ref(Note), color=blue, kind=end, linetype=solid, partnerSpanner=ref(NoteheadLine), uuid=kamf8wxw)], 3E:0.25♩, 3F:0.25♩:symbols=[Beam(anchor=ref(Note), kind=start, linetype=solid, partnerSpanner=ref(Beam), uuid=053jjjda)], 3F#:0.25♩, 3G:0.25♩:symbols=[Slur(anchor=ref(Note), kind=end, linetype=solid, partnerSpanner=ref(Slur), uuid=0ps33go9)], 3G#:0.25♩, 3A:0.25♩:symbols=[Beam(anchor=ref(Note), kind=end, linetype=solid, partnerSpanner=ref(Beam), uuid=053jjjda)], …])

# %%
ch.eventAt((1, 0.25))
# Out:
# 4F:0.25♩
