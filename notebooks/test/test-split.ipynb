# %%
from maelzel.core import *
import logging
logger = logging.getLogger("maelzel")
logger.setLevel("DEBUG")
cfg = getConfig()
cfg['quant.minBeatFractionAcrossBeats'] = 1/8
# Out:
# [maelzel.core:mobj.py:1755:resetImageCache:INFO] Resetting image cache

# %%
ch = Chain([
    "4C:1",
    "4D:2/3",
    "4E:2/3",
    "4F:2/3",
    "4G:1",
])
resetImageCache()
r = ch.render()
r.write("~/tmp/split.ly")
ch
# Out:
# [maelzel.core:mobj.py:1755:resetImageCache:INFO] Resetting image cache
# [maelzel.scoring:quant.py:1596:_mergeSiblings:DEBUG] Nodes can merge:
#     Node(3/2,
#   «4D 1:1.667 2/3♩ 3/2»
#   «4E~ 1.667:2 1/3♩ 3/2»
# )
#     Node(3/2,
#   «~4E 2:2.333 1/3♩ 3/2»
#   «4F 2.333:3 2/3♩ 3/2»
# )
# [maelzel.scoring:quant.py:1599:_mergeSiblings:DEBUG] ---- Merged node:
#     Node(3/2,
#   «4D 1:1.667 2/3♩ 3/2»
#   «4E 1.667:2.333 2/3♩ 3/2»
#   «4F 2.333:3 2/3♩ 3/2»
# )
# [maelzel.scoring:node.py:621:_splitUnnecessaryNodes:DEBUG] Did not split node Node(1/1,
#   Node(1/1,
#     «4C 0:1 1♩»
#   )
#   Node(3/2,
#     «4D 1:1.667 2/3♩ 3/2»
#     «4E 1.667:2.333 2/3♩ 3/2»
#     «4F 2.333:3 2/3♩ 3/2»
#   )
#   Node(1/1,
#     «4G 3:4 1♩»
#   )
# ) at 2
# [maelzel.scoring:quant.py:667:breakSyncopations:DEBUG] Splitting syncopation if needed at BeatStructure(offset=Fraction(0, 1), duration=Fraction(1, 1), weight=2), minWeight=1
# [maelzel.scoring:quant.py:667:breakSyncopations:DEBUG] Splitting syncopation if needed at BeatStructure(offset=Fraction(2, 1), duration=Fraction(1, 1), weight=1), minWeight=1
# [maelzel.scoring:node.py:715:_splitNotationAtBoundary:DEBUG] Splitting node (offset=1, end=3) at offset=Fraction(2, 1)
# [maelzel.scoring:node.py:616:_splitUnnecessaryNodes:DEBUG] Splitting node Node(1/1,
#   Node(1/1,
#     «4C 0:1 1♩»
#   )
#   Node(3/2,
#     «4D 1:1.667 2/3♩ 3/2»
#     «4E~ 1.667:2 1/3♩ 3/2»
#     «~4E 2:2.333 1/3♩ 3/2 properties={'.mergeable': False}»
#     «4F 2.333:3 2/3♩ 3/2»
#   )
#   Node(1/1,
#     «4G 3:4 1♩»
#   )
# ) at 2
# DEBUG:maelzel:findLilypond: searching via shutil.which
# DEBUG:maelzel:... found! lilypond path: /usr/bin/lilypond
# [maelzel.scoring:renderlily.py:1116:write:DEBUG] Rendering lilypond '/tmp/tmpxpg1bv68.ly' to '/tmp/tmpxpg1bv68.png'
# DEBUG:maelzel:Rendering lilypond '/tmp/tmpxpg1bv68.ly' to '/tmp/tmpxpg1bv68.png'
# DEBUG:maelzel:Calling lilypond subprocess: ['/usr/bin/lilypond', '--png', '-o', '/tmp/tmpxpg1bv68', '-dresolution=200', '/tmp/tmpxpg1bv68.ly']
# DEBUG:maelzel:lilypond executed OK
# DEBUG:maelzel:stderr:
# DEBUG:maelzel: Changing working directory to: `/tmp'
#  Processing `/tmp/tmpxpg1bv68.ly'
#  Parsing...
#  Interpreting music...
#  Preprocessing graphical objects...
#  Finding the ideal number of pages...
#  Fitting music on 1 page...
#  Drawing systems...
#  Converting to PNG...
#  Layout output to `tmpxpg1bv68.cropped.eps'...
#  Converting to PNG...
#  Success: compilation successfully completed
#
# [maelzel.scoring:renderlily.py:1129:write:DEBUG] Found crop file /tmp/tmpxpg1bv68.cropped.png, using that as output
# Chain([4C:1♩, 4D:0.667♩, 4E:0.667♩, 4F:0.667♩, 4G:1♩])

# %%
ch = Chain([
    "4C:1",
    "4G:1",
    "4D:2/3",
    "4E:2/3",
    "4F:2/3",
    
])
ch
# Out:
# [maelzel.scoring:quant.py:1596:_mergeSiblings:DEBUG] Nodes can merge:
#     Node(1/1,
#   «4C 0:1 1♩»
# )
#     Node(1/1,
#   «4G 1:2 1♩»
# )
# [maelzel.scoring:quant.py:1599:_mergeSiblings:DEBUG] ---- Merged node:
#     Node(1/1,
#   «4C 0:1 1♩»
#   «4G 1:2 1♩»
# )
# [maelzel.scoring:quant.py:1596:_mergeSiblings:DEBUG] Nodes can merge:
#     Node(3/2,
#   «4D 2:2.667 2/3♩ 3/2»
#   «4E~ 2.667:3 1/3♩ 3/2»
# )
#     Node(3/2,
#   «~4E 3:3.333 1/3♩ 3/2»
#   «4F 3.333:4 2/3♩ 3/2»
# )
# [maelzel.scoring:quant.py:1599:_mergeSiblings:DEBUG] ---- Merged node:
#     Node(3/2,
#   «4D 2:2.667 2/3♩ 3/2»
#   «4E 2.667:3.333 2/3♩ 3/2»
#   «4F 3.333:4 2/3♩ 3/2»
# )
# [maelzel.scoring:node.py:616:_splitUnnecessaryNodes:DEBUG] Splitting node Node(1/1,
#   Node(1/1,
#     «4C 0:1 1♩»
#     «4G 1:2 1♩»
#   )
#   Node(3/2,
#     «4D 2:2.667 2/3♩ 3/2»
#     «4E 2.667:3.333 2/3♩ 3/2»
#     «4F 3.333:4 2/3♩ 3/2»
#   )
# ) at 1
# [maelzel.scoring:node.py:621:_splitUnnecessaryNodes:DEBUG] Did not split node Node(1/1,
#   Node(1/1,
#     «4C 0:1 1♩»
#     «4G 1:2 1♩»
#   )
#   Node(3/2,
#     «4D 2:2.667 2/3♩ 3/2»
#     «4E 2.667:3.333 2/3♩ 3/2»
#     «4F 3.333:4 2/3♩ 3/2»
#   )
# ) at 3
# [maelzel.scoring:quant.py:667:breakSyncopations:DEBUG] Splitting syncopation if needed at BeatStructure(offset=Fraction(0, 1), duration=Fraction(1, 1), weight=2), minWeight=1
# [maelzel.scoring:quant.py:667:breakSyncopations:DEBUG] Splitting syncopation if needed at BeatStructure(offset=Fraction(2, 1), duration=Fraction(1, 1), weight=1), minWeight=1
# [maelzel.scoring:node.py:621:_splitUnnecessaryNodes:DEBUG] Did not split node Node(1/1,
#   Node(1/1,
#     «4C 0:1 1♩»
#   )
#   Node(1/1,
#     «4G 1:2 1♩»
#   )
#   Node(3/2,
#     «4D 2:2.667 2/3♩ 3/2»
#     «4E 2.667:3.333 2/3♩ 3/2»
#     «4F 3.333:4 2/3♩ 3/2»
#   )
# ) at 3
# [maelzel.scoring:renderlily.py:1116:write:DEBUG] Rendering lilypond '/tmp/tmpehigf3fh.ly' to '/tmp/tmpehigf3fh.png'
# DEBUG:maelzel:Rendering lilypond '/tmp/tmpehigf3fh.ly' to '/tmp/tmpehigf3fh.png'
# DEBUG:maelzel:Calling lilypond subprocess: ['/usr/bin/lilypond', '--png', '-o', '/tmp/tmpehigf3fh', '-dresolution=200', '/tmp/tmpehigf3fh.ly']
# DEBUG:maelzel:lilypond executed OK
# DEBUG:maelzel:stderr:
# DEBUG:maelzel: Changing working directory to: `/tmp'
#  Processing `/tmp/tmpehigf3fh.ly'
#  Parsing...
#  Interpreting music...
#  Preprocessing graphical objects...
#  Finding the ideal number of pages...
#  Fitting music on 1 page...
#  Drawing systems...
#  Converting to PNG...
#  Layout output to `tmpehigf3fh.cropped.eps'...
#  Converting to PNG...
#  Success: compilation successfully completed
#
# [maelzel.scoring:renderlily.py:1129:write:DEBUG] Found crop file /tmp/tmpehigf3fh.cropped.png, using that as output
# Chain([4C:1♩, 4G:1♩, 4D:0.667♩, 4E:0.667♩, 4F:0.667♩])

# %%
ch = Chain([
    "4C:1",
    "4D:2/5",
    "4E:2/5",
    "4F:2/5",
    "4E:2/5",
    "4F:2/5",
    "4G:1",
])
resetImageCache()
r = ch.render()
r.write("~/tmp/split.ly")
ch
# Out:
# [maelzel.core:mobj.py:1755:resetImageCache:INFO] Resetting image cache
# [maelzel.scoring:quant.py:1596:_mergeSiblings:DEBUG] Nodes can merge:
#     Node(5/4,
#   «4D 1:1.4 2/5♩ 5/4»
#   «4E 1.4:1.8 2/5♩ 5/4»
#   «4F~ 1.8:2 1/5♩ 5/4»
# )
#     Node(5/4,
#   «~4F 2:2.2 1/5♩ 5/4»
#   «4E 2.2:2.6 2/5♩ 5/4»
#   «4F 2.6:3 2/5♩ 5/4»
# )
# [maelzel.scoring:quant.py:1599:_mergeSiblings:DEBUG] ---- Merged node:
#     Node(5/4,
#   «4D 1:1.4 2/5♩ 5/4»
#   «4E 1.4:1.8 2/5♩ 5/4»
#   «4F 1.8:2.2 2/5♩ 5/4»
#   «4E 2.2:2.6 2/5♩ 5/4»
#   «4F 2.6:3 2/5♩ 5/4»
# )
# [maelzel.scoring:node.py:621:_splitUnnecessaryNodes:DEBUG] Did not split node Node(1/1,
#   Node(1/1,
#     «4C 0:1 1♩»
#   )
#   Node(5/4,
#     «4D 1:1.4 2/5♩ 5/4»
#     «4E 1.4:1.8 2/5♩ 5/4»
#     «4F 1.8:2.2 2/5♩ 5/4»
#     «4E 2.2:2.6 2/5♩ 5/4»
#     «4F 2.6:3 2/5♩ 5/4»
#   )
#   Node(1/1,
#     «4G 3:4 1♩»
#   )
# ) at 2
# [maelzel.scoring:quant.py:667:breakSyncopations:DEBUG] Splitting syncopation if needed at BeatStructure(offset=Fraction(0, 1), duration=Fraction(1, 1), weight=2), minWeight=1
# [maelzel.scoring:quant.py:667:breakSyncopations:DEBUG] Splitting syncopation if needed at BeatStructure(offset=Fraction(2, 1), duration=Fraction(1, 1), weight=1), minWeight=1
# [maelzel.scoring:node.py:715:_splitNotationAtBoundary:DEBUG] Splitting node (offset=1, end=3) at offset=Fraction(2, 1)
# [maelzel.scoring:node.py:616:_splitUnnecessaryNodes:DEBUG] Splitting node Node(1/1,
#   Node(1/1,
#     «4C 0:1 1♩»
#   )
#   Node(5/4,
#     «4D 1:1.4 2/5♩ 5/4»
#     «4E 1.4:1.8 2/5♩ 5/4»
#     «4F~ 1.8:2 1/5♩ 5/4»
#     «~4F 2:2.2 1/5♩ 5/4 properties={'.mergeable': False}»
#     «4E 2.2:2.6 2/5♩ 5/4»
#     «4F 2.6:3 2/5♩ 5/4»
#   )
#   Node(1/1,
#     «4G 3:4 1♩»
#   )
# ) at 2
# [maelzel.scoring:renderlily.py:1116:write:DEBUG] Rendering lilypond '/tmp/tmpmowis04w.ly' to '/tmp/tmpmowis04w.png'
# DEBUG:maelzel:Rendering lilypond '/tmp/tmpmowis04w.ly' to '/tmp/tmpmowis04w.png'
# DEBUG:maelzel:Calling lilypond subprocess: ['/usr/bin/lilypond', '--png', '-o', '/tmp/tmpmowis04w', '-dresolution=200', '/tmp/tmpmowis04w.ly']
# DEBUG:maelzel:lilypond executed OK
# DEBUG:maelzel:stderr:
# DEBUG:maelzel: Changing working directory to: `/tmp'
#  Processing `/tmp/tmpmowis04w.ly'
#  Parsing...
#  Interpreting music...
#  Preprocessing graphical objects...
#  Finding the ideal number of pages...
#  Fitting music on 1 page...
#  Drawing systems...
#  Converting to PNG...
#  Layout output to `tmpmowis04w.cropped.eps'...
#  Converting to PNG...
#  Success: compilation successfully completed
#
# [maelzel.scoring:renderlily.py:1129:write:DEBUG] Found crop file /tmp/tmpmowis04w.cropped.png, using that as output
# Chain([4C:1♩, 4D:0.4♩, 4E:0.4♩, 4F:0.4♩, 4E:0.4♩, 4F:0.4♩, 4G:1♩])

# %%
from maelzel.core import *

ch = Chain([
    "4C:1",
    "4D:2/5",
    "4E:2/5",
    "4F:2/5",
    "4E:2/5",
    "4F:2/5",
    "4G:1",
])
resetImageCache()
with ScoreStruct(timesig="3/4"):
    ch.show()
# Out:
# [maelzel.core:mobj.py:1755:resetImageCache:INFO] Resetting image cache
# [maelzel.scoring:quant.py:1596:_mergeSiblings:DEBUG] Nodes can merge:
#     Node(5/4,
#   «4D 1:1.4 2/5♩ 5/4»
#   «4E 1.4:1.8 2/5♩ 5/4»
#   «4F~ 1.8:2 1/5♩ 5/4»
# )
#     Node(5/4,
#   «~4F 2:2.2 1/5♩ 5/4»
#   «4E 2.2:2.6 2/5♩ 5/4»
#   «4F 2.6:3 2/5♩ 5/4»
# )
# [maelzel.scoring:quant.py:1599:_mergeSiblings:DEBUG] ---- Merged node:
#     Node(5/4,
#   «4D 1:1.4 2/5♩ 5/4»
#   «4E 1.4:1.8 2/5♩ 5/4»
#   «4F 1.8:2.2 2/5♩ 5/4»
#   «4E 2.2:2.6 2/5♩ 5/4»
#   «4F 2.6:3 2/5♩ 5/4»
# )
# [maelzel.scoring:node.py:621:_splitUnnecessaryNodes:DEBUG] Did not split node Node(1/1,
#   Node(1/1,
#     «4C 0:1 1♩»
#   )
#   Node(5/4,
#     «4D 1:1.4 2/5♩ 5/4»
#     «4E 1.4:1.8 2/5♩ 5/4»
#     «4F 1.8:2.2 2/5♩ 5/4»
#     «4E 2.2:2.6 2/5♩ 5/4»
#     «4F 2.6:3 2/5♩ 5/4»
#   )
# ) at 2
# [maelzel.scoring:quant.py:1325:quantizeMeasure:DEBUG] Measure 3/4 is not filled (events=[«4G 0:1 1♩»]). Filling gaps with silences
# [maelzel.scoring:quant.py:1596:_mergeSiblings:DEBUG] Nodes can merge:
#     Node(1/1,
#   «4G 0:1 1♩»
# )
#     Node(1/1,
#   «rest 1:2 1♩»
# )
# [maelzel.scoring:quant.py:1599:_mergeSiblings:DEBUG] ---- Merged node:
#     Node(1/1,
#   «4G 0:1 1♩»
#   «rest 1:2 1♩»
# )
# [maelzel.scoring:quant.py:1596:_mergeSiblings:DEBUG] Nodes can merge:
#     Node(1/1,
#   «4G 0:1 1♩»
#   «rest 1:2 1♩»
# )
#     Node(1/1,
#   «rest 2:3 1♩»
# )
# [maelzel.scoring:quant.py:1599:_mergeSiblings:DEBUG] ---- Merged node:
#     Node(1/1,
#   «4G 0:1 1♩»
#   «rest 1:3 2♩»
# )
# [maelzel.scoring:quant.py:667:breakSyncopations:DEBUG] Splitting syncopation if needed at BeatStructure(offset=Fraction(0, 1), duration=Fraction(1, 1), weight=2), minWeight=1
# [maelzel.scoring:node.py:621:_splitUnnecessaryNodes:DEBUG] Did not split node Node(1/1,
#   Node(1/1,
#     «4C 0:1 1♩»
#   )
#   Node(5/4,
#     «4D 1:1.4 2/5♩ 5/4»
#     «4E 1.4:1.8 2/5♩ 5/4»
#     «4F 1.8:2.2 2/5♩ 5/4»
#     «4E 2.2:2.6 2/5♩ 5/4»
#     «4F 2.6:3 2/5♩ 5/4»
#   )
# ) at 2
# [maelzel.scoring:quant.py:667:breakSyncopations:DEBUG] Splitting syncopation if needed at BeatStructure(offset=Fraction(0, 1), duration=Fraction(1, 1), weight=2), minWeight=1
# [maelzel.scoring:renderlily.py:1116:write:DEBUG] Rendering lilypond '/tmp/tmp9vbfdfu7.ly' to '/tmp/tmp9vbfdfu7.png'
# DEBUG:maelzel:Rendering lilypond '/tmp/tmp9vbfdfu7.ly' to '/tmp/tmp9vbfdfu7.png'
# DEBUG:maelzel:Calling lilypond subprocess: ['/usr/bin/lilypond', '--png', '-o', '/tmp/tmp9vbfdfu7', '-dresolution=200', '/tmp/tmp9vbfdfu7.ly']
# DEBUG:maelzel:lilypond executed OK
# DEBUG:maelzel:stderr:
# DEBUG:maelzel: Changing working directory to: `/tmp'
#  Processing `/tmp/tmp9vbfdfu7.ly'
#  Parsing...
#  Interpreting music...
#  Preprocessing graphical objects...
#  Finding the ideal number of pages...
#  Fitting music on 1 page...
#  Drawing systems...
#  Converting to PNG...
#  Layout output to `tmp9vbfdfu7.cropped.eps'...
#  Converting to PNG...
#  Success: compilation successfully completed
#
# [maelzel.scoring:renderlily.py:1129:write:DEBUG] Found crop file /tmp/tmp9vbfdfu7.cropped.png, using that as output
