# %%
from maelzel.core import *

# %%
ch = Chain([
    "4C:1",
    "4D:0.5:slur",
    "4E:0.5",
    "4F:1:~slur",
    "4G:0.5"
])
ch.dump()
ch
# Out:
# <code><span style="font-size: 85%"><b>Chain</b> - beat: 0, offset: None, dur: 3.5</span></code><br><code><span style="color:#BBBBBB;font-size:85%">  location  beat   offset      dur         name      gliss dyn  playargs            info                </span></code><br><code><span style="color:#9090FF;font-size:85%">  0:0       0      (0)         1           4C        False      None                -</span></code><br><code><span style="color:#9090FF;font-size:85%">  0:1       1      (1)         0.5         4D        False      None                -</span></code><br><code>      <span style="color:#8080E0;font-size:85%">[Slur(anchor=<weakref at 0x7fcf4e0249f0; to 'Note' at 0x7fcf4e0204a0>, kind=start, linetype=solid, uuid=k1n8u3zy)]</span></code><br><code><span style="color:#9090FF;font-size:85%">  0:1.5     1.5    (3/2)       0.5         4E        False      None                -</span></code><br><code><span style="color:#9090FF;font-size:85%">  0:2       2      (2)         1          
# ...

# %%
chain2 = Chain(r"""
    3Bb:0.5
    4D:3/4
    4F#:3/4:ff:decresc
    4A:1/2
    5C:1/2
    5E:1/2:p
    5G#:1:>:slur
    5B:1:~slur
    6C#:1/3:staccato
    """)
chain2.show()

# %%
chain2.dump()
# Out:
# <code><span style="font-size: 85%"><b>Chain</b> - beat: 0, offset: None, dur: 5.833</span></code><br><code><span style="color:#BBBBBB;font-size:85%">  location  beat   offset      dur         name      gliss dyn  playargs            info                </span></code><br><code><span style="color:#9090FF;font-size:85%">  0:0       0      (0)         0.5         3A#       False      None                -</span></code><br><code><span style="color:#9090FF;font-size:85%">  0:0.5     0.5    (1/2)       0.75        4D        False      None                -</span></code><br><code><span style="color:#9090FF;font-size:85%">  0:1.25    1.25   (5/4)       0.75        4F#       False ff   None                -</span></code><br><code>      <span style="color:#8080E0;font-size:85%">[Articulation(kind=accent)]</span></code><br><code><span style="color:#9090FF;font-size:85%">  0:2       2      (2)         0.5         4A        False      None                -</span></code><br><code><span style="color
# ...

# %%
from maelzel.core import *

ch = Chain(r"""
    4C:4/9
    4D:4/9
    4E~:1/9
    4E:1/3
    r:1/3
    4F:1
    r:1/3
""")
ch.show()
ch.write("~/tmp/tuplet.ly")

# %%
from maelzel.core import *

ch = Chain(r"""
    4C:4/9
    4D:4/9
    4E~:1/9
    4E:4
    r:1/3
    4F:1
    r:1/3
""")
ch.show()
ch.write("~/tmp/tuplet.ly")
