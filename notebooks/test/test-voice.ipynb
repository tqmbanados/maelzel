# %%
from maelzel.core import *

# %%
v = Voice([
    "4C:1",
    "4D:1/3",
    "4E:2/3",
    "4C:1",
    "4D:1/3",
    "4E:2/3",
    "4C:1",
    "4D:1/3",
    "4E:2/3",
    "4C:1",
    "4D:1/3",
    "4E:2/3",
    "4C:1",
    "4D:1/3",
    "4E:2/3",
    "4C:1",
    "4D:1/3",
    "4E:2/3",
    
])
v.dump()
# Out:
# <code><span style="font-size: 85%"><b>Voice</b> - beat: 0, offset: 0, dur: 12</span></code><br><code><span style="color:#BBBBBB;font-size:85%">  location  beat   offset      dur         name      gliss dyn  playargs            info                </span></code><br><code><span style="color:#9090FF;font-size:85%">  0:0       0      (0)         1           4C        False      None                -</span></code><br><code><span style="color:#9090FF;font-size:85%">  0:1       1      (1)         0.333       4D        False      None                -</span></code><br><code><span style="color:#9090FF;font-size:85%">  0:1.333   1.333  (4/3)       0.667       4E        False      None                -</span></code><br><code><span style="color:#9090FF;font-size:85%">  0:2       2      (2)         1           4C        False      None                -</span></code><br><code><span style="color:#9090FF;font-size:85%">  0:3       3      (3)         0.333       4D        False      None             
# ...

# %%
v.play(instr='.sing', args={'kx': 0.5, 'ky': 1.0})
# Out:
# --Csound version 6.19 (double samples) May 26 2023
# [commit: 593ac80dd986b58f24e3d59242243ba6266edda7]
# libsndfile-1.2.0
# sr = 48000.0, kr = 750.000, ksmps = 64
# 0dBFS level = 1.0, A4 tuning = 442.0
# audio buffered in 1024 sample-frame blocks
# reading 8192-byte blks of shorts from adc:Built-in Audio Analogue Stereo: (RAW)
# writing 2048 sample blks of 64-bit floats to dac:Built-in Audio Analogue Stereo:
# SECTION 1:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=18)
#     Synth(𝍪 preset:.sing:501.0002, p4=0 idataidx_:5=18 inumbps:6=2 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 kx:15=0.5 ky:16=1 kvibamount:17=1 p18=0 p19=60 p20=0.515178 p21=1 ...)
# ...

# %%
v2 = v.transpose(1).timeShift(1/2)
v2.name = 'voice2'
v3 = v.transpose(0.5).timeScale(F(4, 3))
v3.name = 'voice3'
sco = Score([v, v2, v3])
sco
# Out:
# Score(3 voices)

# %%
sco.play(instr='.sing')
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=54)
#     Synth(𝍪 preset:.sing:501.0074, p4=0 idataidx_:5=18 inumbps:6=2 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 kx:15=0 ky:16=0 kvibamount:17=1 p18=0 p19=60 p20=0.515178 p21=1 ...)
#     Synth(𝍪 preset:.sing:501.0075, p4=0 idataidx_:5=18 inumbps:6=2 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 kx:15=0 ky:16=0 kvibamount:17=1 p18=0 p19=62 p20=0.515178 p21=0.333333 ...)
#     Synth(𝍪 preset:.sing:501.0076, p4=0 idataidx_:5=18 inumbps:6=2 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=-1 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 kx:15=0 ky:16=0 kvibamount:17=1 p18=0 p19=64 p20=0.515178 p21=0.666667 ...)
# ...
